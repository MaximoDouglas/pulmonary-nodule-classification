# %% [markdown]
# # Env Configuration

# %%
from google.colab import drive
drive.mount('drive', force_remount=True)
# !pip install keras_metrics

# %% [markdown]
# ## Setup

# %%
import os
import time
import gc
import numpy as np
import pandas as pd
from scipy import interp, stats
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc
from keras import backend as K
from keras import optimizers
from keras.layers import Conv3D, MaxPool3D, Flatten, Dense, Dropout, Input, concatenate
from keras.losses import binary_crossentropy
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.utils.vis_utils import plot_model, model_to_dot
import keras_metrics as km
import math
import itertools
import re
import os
import imageio
from scipy.ndimage import rotate
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
import shutil
import matplotlib.pyplot as plt

'''fixed settings'''
rotations_of_benignant    = 5
rotations_of_malignant    = 13
slices_per_nodule         = 5
number_of_folds           = 10
strategy                  = 'first'
repeat_slices             = False
base_dir                  = "/content/drive/My Drive/Pesquisa - Dicom images/data/"
images_dir                = base_dir + "images/solid-nodules-with-attributes/"
features_path             = base_dir + "features/solidNodules.csv"
images_resolution         = 64
metrics                   = {'acc': [], 'spec': [], 'sens': [], 'f1_score': [], 'auc': []}
number_of_validations     = 1
drop_random_values_gen    = stats.norm(scale=0.05, loc=0.4)
conv1_search_space        = [32, 48, 64, 96]
dense1_search_space       = [32, 64, 128]
dense2_search_space       = [16, 24, 32]

'''Flexible settings'''
convolucional_layer_units = 48
dense_layer_units_1       = 32
dense_layer_units_2       = 24
dropout_layer_1           = 0.22844677901880536
dropout_layer_2           = 0.15708398473695773
input_shape               = (64, 64, 5, 1)

feature_injection    = False
layer_to_be_injected = 'flatten'  #flatten, dense1, dense2
features_set         = 'opt'      #all, opt, margin, shape 
experiment_name      = layer_to_be_injected + ' - ' + features_set if (feature_injection)  else 'none'

def feat_input_shape():
  if (features_set == 'all'):
    return (71,)
  elif (features_set == 'opt'):
    return (38,)
  elif (features_set == 'margin'):
    return (12,)
  elif (features_set == 'shape'):
    return (8,)
  
def feat_input_subset():
  if (features_set == 'all'):
    return -1 #it shouldn't be called when feature_set is set to 'all'
  elif (features_set == 'opt'):
    return optimized_features_set
  elif (features_set == 'margin'):
    return margin_features_set
  elif (features_set == 'shape'):
    return shape_features_set

feature_input_shape       = feat_input_shape()
shape_features_set        = [16, 17, 18, 19, 20, 21, 22, 23]
margin_features_set       = [61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72]
optimized_features_set    = [2, 3, 4, 6, 9, 11, 12, 18, 19, 22, 26, 28, 29, 
                             30, 31, 32, 33, 35, 38, 40, 41, 44, 46, 47, 48, 
                             50, 53, 54, 56, 57, 59, 60, 62, 63, 65, 67, 71, 72]
  
print("Feature injection: "    + str(feature_injection))
print("Layer to be injected: " + layer_to_be_injected)
print("Features set: "         + features_set)
# Out:
# Feature injection: False
# Layer to be injected: flatten
# Features set: opt

# %% [markdown]
# ## Normalize getting the first slices (Unchanging)
# Function that normalize getting the first slices

# %%
def normalize_first(nodules, n_slices, repeat=False):
    '''Normalizes the nodule slices number:
    - A nodule with less than n slices is completed with black slices
    - A nodule with more than n slices have its n first slices selected'''
    
    normalized_slices = []

    for nodule in nodules:
        new_nodule = []

        if repeat:
            times = math.ceil(n_slices/len(nodule))
            nodule = list(itertools.chain.from_iterable(itertools.repeat(x, times) for x in nodule))

        if len(nodule) <= n_slices:
                for slice in nodule:
                    new_nodule.append(slice)
                for i in range(n_slices - len(nodule)):
                    new_nodule.append(np.zeros((images_resolution, images_resolution)))
        elif len(nodule) > n_slices:
            for i in range(0, n_slices):
                new_nodule.append(nodule[i])
        normalized_slices.append(new_nodule)
    return normalized_slices

# %% [markdown]
# ## Read images
# Function to read images from files and returns a list of numpy

# %%
def read_images(path, path_features):
    '''Reads the images files in our file structure and mounts an array
    Parameters:
        path (string): path to the nodules folders
        path_features (string): path to the features .csv
    Returns:
        list: list of nodules with slices as Numpy Arrays
        features: list of features corresponding to the nodules on list'''

    df = pd.read_csv(path_features)
    
    scaler = MinMaxScaler(copy=False)
    df[df.columns[2:74]] = scaler.fit_transform(df[df.columns[2:74]])
    
    allFeatures = df.values

    lista       = []
    features    = []

    for _, dirs, _ in os.walk(path):
        for dirname in sorted(dirs, key=str.lower):
            for _, dirs1, _ in os.walk(path + "/" + dirname):
                for dirname1 in sorted(dirs1, key=str.lower):
                    for root2, _, files2 in os.walk(path + "/" + dirname + "/" + dirname1):
                        slices = []
                        files2[:] = [re.findall('\d+', x)[0] for x in files2]

                        axis = 0 # To get the Rows indices
                        examColumn = 0 # Column of the csv where the exam code is
                        noduleColumn = 1 # Column of the csv where the nodule code is

                        # index of the rows that have the exam id equal to the exam id of the current nodule
                        indExam  = np.where(allFeatures[:,examColumn] == dirname)[axis]

                        # index of the rows that have the nodule id equal to the id of the current nodule
                        indNodule = np.where(allFeatures[:,noduleColumn] == dirname1)[axis]

                        i = np.intersect1d(indExam,indNodule)

                        # A list are returned, but there's just one value, so I used its index
                        index = 0
                        exam = allFeatures[i,examColumn][index]
                        nodule = allFeatures[i,noduleColumn][index]

                        '''Verify if there's more than one index for each nodule
                        and if there's divergence between the nodule location and the
                        csv values'''

                        if((len(i) > 1) or (str(exam) != str(dirname)) or (str(nodule) != str(dirname1))):
                            print("Features error!")
                        else:
                            '''Transform the list of index with just one value in a
                            primitive value to use as index to save the features values'''
                            i = i[0]

                        for f in sorted(files2, key=float):
                            img = imageio.imread(root2 + "/" + f + ".png", as_gray=True)
                            slices.append(img)

                        lista.append(slices)
                        
                        if (features_set == 'all'):
                          features.append(allFeatures[i,2:73].tolist())
                        else:
                          features.append(allFeatures[i,feat_input_subset()].tolist())

    return lista, features

# %% [markdown]
# ## My Kfold
# k_folder made to get balanced data between benigno and maligno

# %%
def my_kfold(ben, mal, f_ben, f_mal, n_splits, ben_rot, mal_rot):
    kf = KFold(n_splits)
    
    f_mal_train, f_mal_test = [], []
    mal_train, mal_test = [], []
    for train_index, test_index in kf.split(mal):
        mal_train.append([mal[index] for index in train_index])
        f_mal_train.append([f_mal[index] for index in train_index])

        mal_test.append([mal[index] for index in test_index])
        f_mal_test.append([f_mal[index] for index in test_index])

    ben_train, ben_test = [], []
    f_ben_train, f_ben_test = [], []
    
    # percorro o mal_test para que os folds de test tenham o mesmo número de itens
    for (train_index, test_index), mal_te, mal_tr in zip(kf.split(ben), mal_test, mal_train):
        
        sample = np.random.choice(test_index, len(mal_te), replace=False)
        sample_ = np.setdiff1d(test_index, sample)

        ben_train_ind = np.concatenate((train_index, sample_))

        '''This line guarantees that the ben and mal train batches are the same size'''
        ben_train_ind = np.random.choice(ben_train_ind, len(mal_tr), replace=False)

        ben_train.append([ben[index] for index in ben_train_ind])
        f_ben_train.append([f_ben[index] for index in ben_train_ind])
        
        ben_test.append([ben[index] for index in sample])
        f_ben_test.append([f_ben[index] for index in sample])

    X_test, Y_test = [], []
    for b, m in zip(ben_test, mal_test):
        X_test.append(np.concatenate((b, m), 0))

        y_test = len(b) * [0] + len(m) * [1]
        Y_test.append(np.array(y_test))

    f_test = []
    for f_b, f_m in zip(f_ben_test, f_mal_test):
        
        f_test.append(np.concatenate((f_b, f_m), 0))

    X_train, Y_train = [], []
    f_train = []
    for i in tqdm(range(n_splits)):
        print("INDEX: ", i)
        print("ben_train: ", len(ben_train[i]))
        print("mal_train: ", len(mal_train[i]))
        print("ben_test: ",  len(ben_test[i]))
        print("mal_test: ",  len(mal_test[i]))
        
        b, m = ben_train[i], mal_train[i]
        f_b_train, f_m_train = f_ben_train[i], f_mal_train[i]

        X_train.append(np.concatenate((b, m), 0))
        f_train.append(np.concatenate((f_b_train, f_m_train), 0))

        y_train = len(b) * [0] + len(m) * [1]
        Y_train.append(np.array(y_train))

    return X_train, X_test, f_train, f_test, Y_train, Y_test

# %% [markdown]
# ## Get folds
# Function that is called to get the folds of the cross validation

# %%
def get_folds(basedir, n_slices, strategy='first', repeat=False, features=None):
    ben_dir = basedir + "benigno"
    mal_dir = basedir + "maligno"

    ben, f_ben = read_images(ben_dir, features)
    mal, f_mal = read_images(mal_dir, features)

    if strategy == 'first':
        ben = normalize_first(ben, n_slices, repeat)
        mal = normalize_first(mal, n_slices, repeat)

    ben = np.concatenate(ben).reshape(len(ben), n_slices, images_resolution, images_resolution, 1)
    mal = np.concatenate(mal).reshape(len(mal), n_slices, images_resolution, images_resolution, 1)

    ben = np.moveaxis(ben, 1, 3)
    mal = np.moveaxis(mal, 1, 3)

    ben_zip = list(zip(ben, f_ben))
    np.random.shuffle(ben_zip)
    ben, f_ben = zip(*ben_zip)

    mal_zip = list(zip(mal, f_mal))
    np.random.shuffle(mal_zip)
    mal, f_mal = zip(*mal_zip)

    X_train, X_test, f_train, f_test, Y_train, Y_test = my_kfold(ben, mal, f_ben, 
                                                                 f_mal, number_of_folds, 
                                                                 rotations_of_benignant, 
                                                                 rotations_of_malignant)

    return X_train, X_test, f_train, f_test, Y_train, Y_test

# %% [markdown]
# # Valition code

# %%
def get_model(conv1, dense1, dense2, drop1, drop2):
    input_layer = Input(input_shape)
    
    conv_layer1 = Conv3D(conv1, kernel_size=(3, 3, 3), activation='relu')(input_layer)
    pooling_layer1 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer1)
    
    flatten_layer = Flatten()(pooling_layer1)
    
    dense_layer1 = Dense(dense1, activation='relu')(flatten_layer)
    dense_layer1 = Dropout(drop1)(dense_layer1)
    
    dense_layer2 = Dense(dense2, activation='relu')(dense_layer1)
    dense_layer2 = Dropout(drop2)(dense_layer2)
    
    output_layer = Dense(units=1, activation='sigmoid')(dense_layer2)
    
    model = Model(inputs=input_layer, outputs=output_layer)
    
    opt = optimizers.RMSprop(lr=0.0001)
    
    model.compile(loss=binary_crossentropy, optimizer=opt, metrics=['acc'])
    
    return model

# %% [markdown]
# ## Cross-validation

# %%
start = time.time()
for i in range(number_of_validations):
    X_train_, X_test_, f_train_, f_test_, Y_train_, Y_test_=  get_folds(basedir=images_dir, 
                                                                        n_slices=slices_per_nodule, 
                                                                        strategy=strategy, 
                                                                        repeat=repeat_slices,
                                                                        features=features_path)
    i = 0
    best_run = {}
    for i in range(30):
      print("Run :" + str(i))
      conv1  = np.random.choice(conv1_search_space, size=1)[0]
      dense1 = np.random.choice(dense1_search_space, size=1)[0]
      dense2 = np.random.choice(dense2_search_space, size=1)[0]
      
      drop1 = -1
      while (drop1 < 0 or drop1 > 0.5):
        drop1 = drop_random_values_gen.rvs()
        
      drop2 = -1
      while (drop2 < 0 or drop2 > 0.5):
        drop2 = drop_random_values_gen.rvs()
      
      m = {'acc': [], 'auc': []}

      model = get_model(conv1, dense1, dense2, drop1, drop2)

      for X_train, X_test, f_train, f_test, Y_train, Y_test in zip(X_train_, X_test_, f_train_, f_test_, Y_train_, Y_test_):
        model.fit(X_train, Y_train,
              batch_size=128,
              epochs=10,
              verbose=2)
    
        score, acc = model.evaluate(X_test, Y_test, verbose=0)
        
        pred = model.predict(X_test).ravel()
        fpr, tpr, thresholds_keras = roc_curve(Y_test, pred)
        auc_val = auc(fpr, tpr)
        
        print('Test accuracy: ', acc)
        print('Test AUC: ', auc_val)

        m['acc'].append(acc)
        m['auc'].append(auc_val)
      
      run_output = {'acc': np.mean(m['acc']), 'auc': np.mean(m['auc']), 'conv1': conv1, 'dense1': dense1, 'dense2': dense2, 'drop1': drop1, 'drop2': drop2}
      print(run_output)
      
      if (len(best_run) == 0 or run_output['auc'] > best_run['auc']):
        best_run = run_output
      elif (run_output['auc'] == best_run['auc'] and run_output['acc'] > best_run['acc']):
        best_run = run_output

end = time.time()

print("Time on optimization:", (end - start)/60, "minutes")

print()
print('Summary of the best model: -----------------------')
print(best_run)
c1 = best_run['conv1']
d1 = best_run['dense1']
d2 = best_run['dense2']
dr1 = best_run['drop1']
dr2 = best_run['drop2']

print('Conv 1:', c1, 'unidades')
print('Dense 1:', d1, 'unidades')
print('Dense 2:', d2, 'unidades')
print('Dropout 1:', dr1)
print('Dropout 2:', dr2)
# Out:
#  20%|██        | 2/10 [00:00<00:00, 13.57it/s]
# INDEX:  0
# ben_train:  240
# mal_train:  240
# ben_test:  27
# mal_test:  27
# INDEX:  1
# ben_train:  240
# mal_train:  240
# ben_test:  27
# mal_test:  27
# INDEX:  2
# ben_train:  240
# mal_train:  240
# ben_test:  27
# mal_test:  27
#  60%|██████    | 6/10 [00:00<00:00, 14.56it/s]
# INDEX:  3
# ben_train:  240
# mal_train:  240
# ben_test:  27
# mal_test:  27
# INDEX:  4
# ben_train:  240
# mal_train:  240
# ben_test:  27
# mal_test:  27
# INDEX:  5
# ben_train:  240
# mal_train:  240
# ben_test:  27
# mal_test:  27
# INDEX:  6
# ben_train:  240
# mal_train:  240
# ben_test:  27
# mal_test:  27
#  80%|████████  | 8/10 [00:00<00:00, 14.29it/s]
# INDEX:  7
# ben_train:  241
# mal_train:  241
# ben_test:  26
# mal_test:  26
# INDEX:  8
# ben_train:  241
# mal_train:  241
# ben_test:  26
# mal_test:  26
# INDEX:  9
# ben_train:  241
# mal_train:  241
# ben_test:  26
# mal_test:  26
# 100%|██████████| 10/10 [00:00<00:00, 13.57it/s]
# Run :
# Epoch 1/10
#  - 1s - loss: 2.3138 - acc: 0.6083
# Epoch 2/10
#  - 0s - loss: 1.2139 - acc: 0.6688
# Epoch 3/10
#  - 0s - loss: 0.9328 - acc: 0.6938
# Epoch 4/10
#  - 0s - loss: 0.7824 - acc: 0.6958
# Epoch 5/10
#  - 0s - loss: 0.7491 - acc: 0.7167
# Epoch 6/10
#  - 0s - loss: 0.7477 - acc: 0.6917
# Epoch 7/10
#  - 0s - loss: 0.6039 - acc: 0.7521
# Epoch 8/10
#  - 0s - loss: 0.6176 - acc: 0.7375
# Epoch 9/10
#  - 0s - loss: 0.5727 - acc: 0.7354
# Epoch 10/10
#  - 0s - loss: 0.5888 - acc: 0.7271
# Test accuracy: 0.6851851851851852
# Epoch 1/10
#  - 0s - loss: 0.6325 - acc: 0.6979
# Epoch 2/10
#  - 0s - loss: 0.5810 - acc: 0.7542
# Epoch 3/10
#  - 0s - loss: 0.6145 - acc: 0.7437
# Epoch 4/10
#  - 0s - loss: 0.4648 - acc: 0.7646
# Epoch 5/10
#  - 0s - loss: 0.4953 - acc: 0.7750
# Epoch 6/10
#  - 0s - loss: 0.5533 - acc: 0.7583
# Epoch 7/10
#  - 0s - loss: 0.5521 - acc: 0.7292
# Epoch 8/10
#  - 0s - loss: 0.5499 - acc: 0.7354
# Epoch 9/10
#  - 0s - loss: 0.4819 - acc: 0.7583
# Epoch 10/10
#  - 0s - loss: 0.4383 - acc: 0.8021
# Test accuracy: 0.7037037081188626
# Epoch 1/10
#  - 0s - loss: 0.5163 - acc: 0.7646
# Epoch 2/10
#  - 0s - loss: 0.5689 - acc: 0.7708
# Epoch 3/10
#  - 0s - loss: 0.6387 - acc: 0.7437
# Epoch 4/10
#  - 0s - loss: 0.5214 - acc: 0.7667
# Epoch 5/10
#  - 0s - loss: 0.5540 - acc: 0.7542
# Epoch 6/10
#  - 0s - loss: 0.5003 - acc: 0.7771
# Epoch 7/10
#  - 0s - loss: 0.5322 - acc: 0.7937
# Epoch 8/10
#  - 0s - loss: 0.4232 - acc: 0.7937
# Epoch 9/10
#  - 0s - loss: 0.4182 - acc: 0.7854
# Epoch 10/10
#  - 0s - loss: 0.4975 - acc: 0.7667
# Test accuracy: 0.7962963051266141
# Epoch 1/10
#  - 0s - loss: 0.4314 - acc: 0.8146
# Epoch 2/10
#  - 0s - loss: 0.4926 - acc: 0.7937
# Epoch 3/10
#  - 0s - loss: 0.4660 - acc: 0.8208
# Epoch 4/10
#  - 0s - loss: 0.4395 - acc: 0.8125
# Epoch 5/10
#  - 0s - loss: 0.4466 - acc: 0.8208
# Epoch 6/10
#  - 0s - loss: 0.4376 - acc: 0.8125
# Epoch 7/10
#  - 0s - loss: 0.3812 - acc: 0.8375
# Epoch 8/10
#  - 0s - loss: 0.3617 - acc: 0.8125
# Epoch 9/10
#  - 0s - loss: 0.4122 - acc: 0.8292
# Epoch 10/10
#  - 0s - loss: 0.4515 - acc: 0.8188
# Test accuracy: 0.6666666578363489
# Epoch 1/10
#  - 0s - loss: 0.4927 - acc: 0.8000
# Epoch 2/10
#  - 0s - loss: 0.4265 - acc: 0.7979
# Epoch 3/10
#  - 0s - loss: 0.4199 - acc: 0.8083
# Epoch 4/10
#  - 0s - loss: 0.4364 - acc: 0.8104
# Epoch 5/10
#  - 0s - loss: 0.4231 - acc: 0.8250
# Epoch 6/10
#  - 0s - loss: 0.4212 - acc: 0.8167
# Epoch 7/10
#  - 0s - loss: 0.3466 - acc: 0.8292
# Epoch 8/10
#  - 0s - loss: 0.4397 - acc: 0.8146
# Epoch 9/10
#  - 0s - loss: 0.3833 - acc: 0.8479
# Epoch 10/10
#  - 0s - loss: 0.3776 - acc: 0.8396
# Test accuracy: 0.8703703637476321
# Epoch 1/10
#  - 0s - loss: 0.3660 - acc: 0.8396
# Epoch 2/10
#  - 0s - loss: 0.4649 - acc: 0.8104
# Epoch 3/10
#  - 0s - loss: 0.4477 - acc: 0.8313
# Epoch 4/10
#  - 0s - loss: 0.3400 - acc: 0.8500
# Epoch 5/10
#  - 0s - loss: 0.3539 - acc: 0.8583
# Epoch 6/10
#  - 0s - loss: 0.3334 - acc: 0.8563
# Epoch 7/10
#  - 0s - loss: 0.2855 - acc: 0.8500
# Epoch 8/10
#  - 0s - loss: 0.2731 - acc: 0.8729
# Epoch 9/10
#  - 0s - loss: 0.3322 - acc: 0.8542
# Epoch 10/10
#  - 0s - loss: 0.2691 - acc: 0.8646
# Test accuracy: 0.8703703814082675
# Epoch 1/10
#  - 0s - loss: 0.3869 - acc: 0.8604
# Epoch 2/10
#  - 0s - loss: 0.3214 - acc: 0.8729
# Epoch 3/10
#  - 0s - loss: 0.3697 - acc: 0.8542
# Epoch 4/10
#  - 0s - loss: 0.3142 - acc: 0.8625
# Epoch 5/10
#  - 0s - loss: 0.3202 - acc: 0.8792
# Epoch 6/10
#  - 0s - loss: 0.3096 - acc: 0.8875
# Epoch 7/10
#  - 0s - loss: 0.3125 - acc: 0.8604
# Epoch 8/10
#  - 0s - loss: 0.2694 - acc: 0.8938
# Epoch 9/10
#  - 0s - loss: 0.2652 - acc: 0.8958
# Epoch 10/10
#  - 0s - loss: 0.2689 - acc: 0.9042
# Test accuracy: 0.8518518452291135
# Epoch 1/10
#  - 0s - loss: 0.3966 - acc: 0.8402
# Epoch 2/10
#  - 0s - loss: 0.3348 - acc: 0.8693
# Epoch 3/10
#  - 0s - loss: 0.3153 - acc: 0.8693
# Epoch 4/10
#  - 0s - loss: 0.2747 - acc: 0.8838
# Epoch 5/10
#  - 0s - loss: 0.3317 - acc: 0.8817
# Epoch 6/10
#  - 0s - loss: 0.2544 - acc: 0.9066
# Epoch 7/10
#  - 0s - loss: 0.2572 - acc: 0.9004
# Epoch 8/10
#  - 0s - loss: 0.2772 - acc: 0.8880
# Epoch 9/10
#  - 0s - loss: 0.2549 - acc: 0.9066
# Epoch 10/10
#  - 0s - loss: 0.2265 - acc: 0.9191
# Test accuracy: 0.8461538553237915
# Epoch 1/10
#  - 0s - loss: 0.2757 - acc: 0.9004
# Epoch 2/10
#  - 0s - loss: 0.2943 - acc: 0.9004
# Epoch 3/10
#  - 0s - loss: 0.2485 - acc: 0.9046
# Epoch 4/10
#  - 0s - loss: 0.2416 - acc: 0.9191
# Epoch 5/10
#  - 0s - loss: 0.2239 - acc: 0.9253
# Epoch 6/10
#  - 0s - loss: 0.2228 - acc: 0.9232
# Epoch 7/10
#  - 0s - loss: 0.2102 - acc: 0.9025
# Epoch 8/10
#  - 0s - loss: 0.2280 - acc: 0.9149
# Epoch 9/10
#  - 0s - loss: 0.2544 - acc: 0.9087
# Epoch 10/10
#  - 0s - loss: 0.2250 - acc: 0.9315
# Test accuracy: 0.9038461538461539
# Epoch 1/10
#  - 0s - loss: 0.3473 - acc: 0.8880
# Epoch 2/10
#  - 0s - loss: 0.3271 - acc: 0.8817
# Epoch 3/10
#  - 0s - loss: 0.2883 - acc: 0.8776
# Epoch 4/10
#  - 0s - loss: 0.2741 - acc: 0.8921
# Epoch 5/10
#  - 0s - loss: 0.2551 - acc: 0.9108
# Epoch 6/10
#  - 0s - loss: 0.2464 - acc: 0.9066
# Epoch 7/10
#  - 0s - loss: 0.2644 - acc: 0.9025
# Epoch 8/10
#  - 0s - loss: 0.2376 - acc: 0.9212
# Epoch 9/10
#  - 0s - loss: 0.2372 - acc: 0.9108
# Epoch 10/10
#  - 0s - loss: 0.2469 - acc: 0.9046
# Test accuracy: 0.9807692307692307
# Run :
# Epoch 1/10
#  - 1s - loss: 2.1087 - acc: 0.6062
# Epoch 2/10
#  - 0s - loss: 0.9565 - acc: 0.7042
# Epoch 3/10
#  - 0s - loss: 0.7739 - acc: 0.6687
# Epoch 4/10
#  - 0s - loss: 0.6789 - acc: 0.6917
# Epoch 5/10
#  - 0s - loss: 0.6733 - acc: 0.6729
# Epoch 6/10
#  - 0s - loss: 0.6245 - acc: 0.6771
# Epoch 7/10
#  - 0s - loss: 0.6655 - acc: 0.6292
# Epoch 8/10
#  - 0s - loss: 0.6488 - acc: 0.6208
# Epoch 9/10
#  - 0s - loss: 0.6052 - acc: 0.6229
# Epoch 10/10
#  - 0s - loss: 0.6407 - acc: 0.6354
# Test accuracy: 0.6481481536670968
# Epoch 1/10
#  - 0s - loss: 0.5843 - acc: 0.6312
# Epoch 2/10
#  - 0s - loss: 0.5289 - acc: 0.6646
# Epoch 3/10
#  - 0s - loss: 0.5782 - acc: 0.6792
# Epoch 4/10
#  - 0s - loss: 0.5716 - acc: 0.6646
# Epoch 5/10
#  - 0s - loss: 0.4769 - acc: 0.6854
# Epoch 6/10
#  - 0s - loss: 0.5825 - acc: 0.6854
# Epoch 7/10
#  - 0s - loss: 0.6017 - acc: 0.6708
# Epoch 8/10
#  - 0s - loss: 0.5660 - acc: 0.7521
# Epoch 9/10
#  - 0s - loss: 0.5994 - acc: 0.7292
# Epoch 10/10
#  - 0s - loss: 0.5583 - acc: 0.7333
# Test accuracy: 0.7592592570516798
# Epoch 1/10
#  - 0s - loss: 0.6247 - acc: 0.7521
# Epoch 2/10
#  - 0s - loss: 0.6122 - acc: 0.7583
# Epoch 3/10
#  - 0s - loss: 0.6581 - acc: 0.7479
# Epoch 4/10
#  - 0s - loss: 0.5499 - acc: 0.7146
# Epoch 5/10
#  - 0s - loss: 0.5167 - acc: 0.7563
# Epoch 6/10
#  - 0s - loss: 0.5122 - acc: 0.7188
# Epoch 7/10
#  - 0s - loss: 0.5523 - acc: 0.7563
# Epoch 8/10
#  - 0s - loss: 0.5282 - acc: 0.7667
# Epoch 9/10
#  - 0s - loss: 0.5096 - acc: 0.7458
# Epoch 10/10
#  - 0s - loss: 0.5302 - acc: 0.7417
# Test accuracy: 0.8148148126072354
# Epoch 1/10
#  - 0s - loss: 0.5757 - acc: 0.7313
# Epoch 2/10
#  - 0s - loss: 0.4997 - acc: 0.7958
# Epoch 3/10
#  - 0s - loss: 0.5305 - acc: 0.7771
# Epoch 4/10
#  - 0s - loss: 0.5549 - acc: 0.7646
# Epoch 5/10
#  - 0s - loss: 0.5899 - acc: 0.7458
# Epoch 6/10
#  - 0s - loss: 0.5564 - acc: 0.7708
# Epoch 7/10
#  - 0s - loss: 0.6506 - acc: 0.7438
# Epoch 8/10
#  - 0s - loss: 0.5323 - acc: 0.7625
# Epoch 9/10
#  - 0s - loss: 0.4565 - acc: 0.7750
# Epoch 10/10
#  - 0s - loss: 0.4888 - acc: 0.7833
# Test accuracy: 0.6666666710818255
# Epoch 1/10
#  - 0s - loss: 0.5346 - acc: 0.7667
# Epoch 2/10
#  - 0s - loss: 0.5532 - acc: 0.7521
# Epoch 3/10
#  - 0s - loss: 0.5374 - acc: 0.7521
# Epoch 4/10
#  - 0s - loss: 0.5136 - acc: 0.7792
# Epoch 5/10
#  - 0s - loss: 0.5308 - acc: 0.7667
# Epoch 6/10
#  - 0s - loss: 0.4947 - acc: 0.7896
# Epoch 7/10
#  - 0s - loss: 0.5122 - acc: 0.7812
# Epoch 8/10
#  - 0s - loss: 0.4960 - acc: 0.7687
# Epoch 9/10
#  - 0s - loss: 0.4701 - acc: 0.7729
# Epoch 10/10
#  - 0s - loss: 0.5034 - acc: 0.7708
# Test accuracy: 0.7962963007114552
# Epoch 1/10
#  - 0s - loss: 0.5467 - acc: 0.7812
# Epoch 2/10
#  - 0s - loss: 0.5346 - acc: 0.7792
# Epoch 3/10
#  - 0s - loss: 0.4825 - acc: 0.7625
# Epoch 4/10
#  - 0s - loss: 0.4563 - acc: 0.8062
# Epoch 5/10
#  - 0s - loss: 0.4794 - acc: 0.7854
# Epoch 6/10
#  - 0s - loss: 0.4552 - acc: 0.7917
# Epoch 7/10
#  - 0s - loss: 0.4725 - acc: 0.7854
# Epoch 8/10
#  - 0s - loss: 0.4492 - acc: 0.7604
# Epoch 9/10
#  - 0s - loss: 0.4616 - acc: 0.7833
# Epoch 10/10
#  - 0s - loss: 0.5095 - acc: 0.8063
# Test accuracy: 0.7962962874659786
# Epoch 1/10
#  - 0s - loss: 0.5315 - acc: 0.7958
# Epoch 2/10
#  - 0s - loss: 0.4986 - acc: 0.7812
# Epoch 3/10
#  - 0s - loss: 0.4906 - acc: 0.8000
# Epoch 4/10
#  - 0s - loss: 0.5214 - acc: 0.8042
# Epoch 5/10
#  - 0s - loss: 0.5118 - acc: 0.7979
# Epoch 6/10
#  - 0s - loss: 0.4936 - acc: 0.7854
# Epoch 7/10
#  - 0s - loss: 0.5079 - acc: 0.7833
# Epoch 8/10
#  - 0s - loss: 0.4245 - acc: 0.8292
# Epoch 9/10
#  - 0s - loss: 0.4465 - acc: 0.7813
# Epoch 10/10
#  - 0s - loss: 0.3991 - acc: 0.8229
# Test accuracy: 0.7592592504289415
# Epoch 1/10
#  - 0s - loss: 0.4222 - acc: 0.8133
# Epoch 2/10
#  - 0s - loss: 0.4406 - acc: 0.8237
# Epoch 3/10
#  - 0s - loss: 0.4548 - acc: 0.8154
# Epoch 4/10
#  - 0s - loss: 0.4294 - acc: 0.8216
# Epoch 5/10
#  - 0s - loss: 0.3860 - acc: 0.8174
# Epoch 6/10
#  - 0s - loss: 0.4187 - acc: 0.8195
# Epoch 7/10
#  - 0s - loss: 0.4020 - acc: 0.8091
# Epoch 8/10
#  - 0s - loss: 0.3975 - acc: 0.8133
# Epoch 9/10
#  - 0s - loss: 0.4257 - acc: 0.8299
# Epoch 10/10
#  - 0s - loss: 0.3976 - acc: 0.8257
# Test accuracy: 0.8076923122772803
# Epoch 1/10
#  - 0s - loss: 0.3928 - acc: 0.8154
# Epoch 2/10
#  - 0s - loss: 0.3755 - acc: 0.8361
# Epoch 3/10
#  - 0s - loss: 0.4062 - acc: 0.8257
# Epoch 4/10
#  - 0s - loss: 0.4314 - acc: 0.8237
# Epoch 5/10
#  - 0s - loss: 0.3786 - acc: 0.8174
# Epoch 6/10
#  - 0s - loss: 0.3755 - acc: 0.8257
# Epoch 7/10
#  - 0s - loss: 0.3654 - acc: 0.8320
# Epoch 8/10
#  - 0s - loss: 0.3654 - acc: 0.8568
# Epoch 9/10
#  - 0s - loss: 0.3594 - acc: 0.8714
# Epoch 10/10
#  - 0s - loss: 0.3143 - acc: 0.8631
# Test accuracy: 0.8653846153846154
# Epoch 1/10
#  - 0s - loss: 0.5026 - acc: 0.7967
# Epoch 2/10
#  - 0s - loss: 0.4514 - acc: 0.8278
# Epoch 3/10
#  - 0s - loss: 0.4353 - acc: 0.8340
# Epoch 4/10
#  - 0s - loss: 0.4280 - acc: 0.8133
# Epoch 5/10
#  - 0s - loss: 0.4196 - acc: 0.8382
# Epoch 6/10
#  - 0s - loss: 0.4007 - acc: 0.8237
# Epoch 7/10
#  - 0s - loss: 0.4265 - acc: 0.8112
# Epoch 8/10
#  - 0s - loss: 0.3457 - acc: 0.8423
# Epoch 9/10
#  - 0s - loss: 0.4141 - acc: 0.8506
# Epoch 10/10
#  - 0s - loss: 0.3591 - acc: 0.8423
# Test accuracy: 0.9423076831377469
# Run :
# Epoch 1/10
#  - 1s - loss: 2.8833 - acc: 0.6292
# Epoch 2/10
#  - 0s - loss: 1.5425 - acc: 0.7083
# Epoch 3/10
#  - 0s - loss: 0.8857 - acc: 0.7333
# Epoch 4/10
#  - 0s - loss: 0.7304 - acc: 0.7583
# Epoch 5/10
#  - 0s - loss: 0.5731 - acc: 0.7896
# Epoch 6/10
#  - 0s - loss: 0.5670 - acc: 0.8063
# Epoch 7/10
#  - 0s - loss: 0.5938 - acc: 0.7917
# Epoch 8/10
#  - 0s - loss: 0.5134 - acc: 0.7854
# Epoch 9/10
#  - 0s - loss: 0.4428 - acc: 0.8167
# Epoch 10/10
#  - 0s - loss: 0.4991 - acc: 0.7813
# Test accuracy: 0.7407407495710585
# Epoch 1/10
#  - 0s - loss: 0.5204 - acc: 0.7688
# Epoch 2/10
#  - 0s - loss: 0.4656 - acc: 0.7771
# Epoch 3/10
#  - 0s - loss: 0.4158 - acc: 0.8062
# Epoch 4/10
#  - 0s - loss: 0.4365 - acc: 0.8167
# Epoch 5/10
#  - 0s - loss: 0.4253 - acc: 0.8271
# Epoch 6/10
#  - 0s - loss: 0.4077 - acc: 0.8104
# Epoch 7/10
#  - 0s - loss: 0.3714 - acc: 0.8208
# Epoch 8/10
#  - 0s - loss: 0.3781 - acc: 0.8604
# Epoch 9/10
#  - 0s - loss: 0.4061 - acc: 0.8208
# Epoch 10/10
#  - 0s - loss: 0.4018 - acc: 0.8208
# Test accuracy: 0.8333333311257539
# Epoch 1/10
#  - 0s - loss: 0.5604 - acc: 0.7917
# Epoch 2/10
#  - 0s - loss: 0.4494 - acc: 0.8187
# Epoch 3/10
#  - 0s - loss: 0.4043 - acc: 0.8417
# Epoch 4/10
#  - 0s - loss: 0.3649 - acc: 0.8542
# Epoch 5/10
#  - 0s - loss: 0.3825 - acc: 0.8396
# Epoch 6/10
#  - 0s - loss: 0.3877 - acc: 0.8583
# Epoch 7/10
#  - 0s - loss: 0.3623 - acc: 0.8583
# Epoch 8/10
#  - 0s - loss: 0.2888 - acc: 0.8750
# Epoch 9/10
#  - 0s - loss: 0.3377 - acc: 0.8521
# Epoch 10/10
#  - 0s - loss: 0.2828 - acc: 0.8562
# Test accuracy: 0.8333333245030156
# Epoch 1/10
#  - 0s - loss: 0.3408 - acc: 0.8708
# Epoch 2/10
#  - 0s - loss: 0.3201 - acc: 0.8792
# Epoch 3/10
#  - 0s - loss: 0.3076 - acc: 0.8750
# Epoch 4/10
#  - 0s - loss: 0.2957 - acc: 0.8875
# Epoch 5/10
#  - 0s - loss: 0.2275 - acc: 0.9167
# Epoch 6/10
#  - 0s - loss: 0.3355 - acc: 0.8458
# Epoch 7/10
#  - 0s - loss: 0.2496 - acc: 0.8833
# Epoch 8/10
#  - 0s - loss: 0.2137 - acc: 0.9208
# Epoch 9/10
#  - 0s - loss: 0.2097 - acc: 0.9104
# Epoch 10/10
#  - 0s - loss: 0.1934 - acc: 0.9125
# Test accuracy: 0.7962963007114552
# Epoch 1/10
#  - 0s - loss: 0.3915 - acc: 0.8625
# Epoch 2/10
#  - 0s - loss: 0.2791 - acc: 0.8958
# Epoch 3/10
#  - 0s - loss: 0.2521 - acc: 0.9125
# Epoch 4/10
#  - 0s - loss: 0.3536 - acc: 0.8729
# Epoch 5/10
#  - 0s - loss: 0.2568 - acc: 0.9063
# Epoch 6/10
#  - 0s - loss: 0.2125 - acc: 0.9312
# Epoch 7/10
#  - 0s - loss: 0.2166 - acc: 0.9375
# Epoch 8/10
#  - 0s - loss: 0.2644 - acc: 0.9208
# Epoch 9/10
#  - 0s - loss: 0.2010 - acc: 0.9396
# Epoch 10/10
#  - 0s - loss: 0.1762 - acc: 0.9521
# Test accuracy: 0.9074074007846691
# Epoch 1/10
#  - 0s - loss: 0.3141 - acc: 0.8917
# Epoch 2/10
#  - 0s - loss: 0.1542 - acc: 0.9354
# Epoch 3/10
#  - 0s - loss: 0.2014 - acc: 0.9479
# Epoch 4/10
#  - 0s - loss: 0.1425 - acc: 0.9479
# Epoch 5/10
#  - 0s - loss: 0.1450 - acc: 0.9479
# Epoch 6/10
#  - 0s - loss: 0.1002 - acc: 0.9583
# Epoch 7/10
#  - 0s - loss: 0.1121 - acc: 0.9500
# Epoch 8/10
#  - 0s - loss: 0.1066 - acc: 0.9708
# Epoch 9/10
#  - 0s - loss: 0.0865 - acc: 0.9687
# Epoch 10/10
#  - 0s - loss: 0.0862 - acc: 0.9708
# Test accuracy: 0.9074074118225662
# Epoch 1/10
#  - 0s - loss: 0.1861 - acc: 0.9500
# Epoch 2/10
#  - 0s - loss: 0.1596 - acc: 0.9542
# Epoch 3/10
#  - 0s - loss: 0.1186 - acc: 0.9562
# Epoch 4/10
#  - 0s - loss: 0.1801 - acc: 0.9417
# Epoch 5/10
#  - 0s - loss: 0.0948 - acc: 0.9792
# Epoch 6/10
#  - 0s - loss: 0.0885 - acc: 0.9792
# Epoch 7/10
#  - 0s - loss: 0.0943 - acc: 0.9750
# Epoch 8/10
#  - 0s - loss: 0.1421 - acc: 0.9521
# Epoch 9/10
#  - 0s - loss: 0.1012 - acc: 0.9833
# Epoch 10/10
#  - 0s - loss: 0.1169 - acc: 0.9792
# Test accuracy: 0.9444444444444444
# Epoch 1/10
#  - 0s - loss: 0.1535 - acc: 0.9606
# Epoch 2/10
#  - 0s - loss: 0.1054 - acc: 0.9710
# Epoch 3/10
#  - 0s - loss: 0.0999 - acc: 0.9730
# Epoch 4/10
#  - 0s - loss: 0.2098 - acc: 0.9232
# Epoch 5/10
#  - 0s - loss: 0.0804 - acc: 0.9813
# Epoch 6/10
#  - 0s - loss: 0.0712 - acc: 0.9876
# Epoch 7/10
#  - 0s - loss: 0.0797 - acc: 0.9855
# Epoch 8/10
#  - 0s - loss: 0.0705 - acc: 0.9917
# Epoch 9/10
#  - 0s - loss: 0.0660 - acc: 0.9917
# Epoch 10/10
#  - 0s - loss: 0.0790 - acc: 0.9793
# Test accuracy: 0.9423076923076923
# Epoch 1/10
#  - 0s - loss: 0.1130 - acc: 0.9606
# Epoch 2/10
#  - 0s - loss: 0.1007 - acc: 0.9647
# Epoch 3/10
#  - 0s - loss: 0.1310 - acc: 0.9564
# Epoch 4/10
#  - 0s - loss: 0.0748 - acc: 0.9896
# Epoch 5/10
#  - 0s - loss: 0.0670 - acc: 0.9896
# Epoch 6/10
#  - 0s - loss: 0.0691 - acc: 0.9876
# Epoch 7/10
#  - 0s - loss: 0.0895 - acc: 0.9793
# Epoch 8/10
#  - 0s - loss: 0.0582 - acc: 0.9938
# Epoch 9/10
#  - 0s - loss: 0.0885 - acc: 0.9793
# Epoch 10/10
#  - 0s - loss: 0.0596 - acc: 0.9896
# Test accuracy: 0.9615384615384616
# Epoch 1/10
#  - 0s - loss: 0.1609 - acc: 0.9710
# Epoch 2/10
#  - 0s - loss: 0.1065 - acc: 0.9730
# Epoch 3/10
#  - 0s - loss: 0.1003 - acc: 0.9772
# Epoch 4/10
#  - 0s - loss: 0.0745 - acc: 0.9834
# Epoch 5/10
#  - 0s - loss: 0.0609 - acc: 0.9938
# Epoch 6/10
#  - 0s - loss: 0.0868 - acc: 0.9751
# Epoch 7/10
#  - 0s - loss: 0.0711 - acc: 0.9896
# Epoch 8/10
#  - 0s - loss: 0.0686 - acc: 0.9896
# Epoch 9/10
#  - 0s - loss: 0.0542 - acc: 0.9938
# Epoch 10/10
#  - 0s - loss: 0.0496 - acc: 0.9959
# Test accuracy: 1.0
# Run :
# Epoch 1/10
#  - 1s - loss: 1.7006 - acc: 0.6021
# Epoch 2/10
#  - 0s - loss: 0.7508 - acc: 0.7250
# Epoch 3/10
#  - 0s - loss: 0.5700 - acc: 0.7437
# Epoch 4/10
#  - 0s - loss: 0.4919 - acc: 0.7542
# Epoch 5/10
#  - 0s - loss: 0.4605 - acc: 0.7833
# Epoch 6/10
#  - 0s - loss: 0.4614 - acc: 0.7708
# Epoch 7/10
#  - 0s - loss: 0.4343 - acc: 0.7833
# Epoch 8/10
#  - 0s - loss: 0.4018 - acc: 0.8083
# Epoch 9/10
#  - 0s - loss: 0.3625 - acc: 0.8250
# Epoch 10/10
#  - 0s - loss: 0.4325 - acc: 0.8167
# Test accuracy: 0.7777777821929367
# Epoch 1/10
#  - 0s - loss: 0.4759 - acc: 0.7813
# Epoch 2/10
#  - 0s - loss: 0.4921 - acc: 0.7896
# Epoch 3/10
#  - 0s - loss: 0.4995 - acc: 0.7688
# Epoch 4/10
#  - 0s - loss: 0.4310 - acc: 0.7875
# Epoch 5/10
#  - 0s - loss: 0.3831 - acc: 0.8146
# Epoch 6/10
#  - 0s - loss: 0.3843 - acc: 0.8042
# Epoch 7/10
#  - 0s - loss: 0.3470 - acc: 0.8271
# Epoch 8/10
#  - 0s - loss: 0.3535 - acc: 0.8208
# Epoch 9/10
#  - 0s - loss: 0.3518 - acc: 0.8396
# Epoch 10/10
#  - 0s - loss: 0.3486 - acc: 0.8271
# Test accuracy: 0.8333333377484922
# Epoch 1/10
#  - 0s - loss: 0.4753 - acc: 0.8021
# Epoch 2/10
#  - 0s - loss: 0.4053 - acc: 0.8271
# Epoch 3/10
#  - 0s - loss: 0.3955 - acc: 0.8146
# Epoch 4/10
#  - 0s - loss: 0.3857 - acc: 0.8292
# Epoch 5/10
#  - 0s - loss: 0.3658 - acc: 0.8083
# Epoch 6/10
#  - 0s - loss: 0.3378 - acc: 0.8333
# Epoch 7/10
#  - 0s - loss: 0.4075 - acc: 0.7917
# Epoch 8/10
#  - 0s - loss: 0.3334 - acc: 0.8208
# Epoch 9/10
#  - 0s - loss: 0.3207 - acc: 0.8583
# Epoch 10/10
#  - 0s - loss: 0.3178 - acc: 0.8458
# Test accuracy: 0.8333333443712305
# Epoch 1/10
#  - 0s - loss: 0.3361 - acc: 0.8583
# Epoch 2/10
#  - 0s - loss: 0.2918 - acc: 0.8896
# Epoch 3/10
#  - 0s - loss: 0.2768 - acc: 0.8708
# Epoch 4/10
#  - 0s - loss: 0.2481 - acc: 0.8875
# Epoch 5/10
#  - 0s - loss: 0.3086 - acc: 0.8646
# Epoch 6/10
#  - 0s - loss: 0.2690 - acc: 0.8813
# Epoch 7/10
#  - 0s - loss: 0.2659 - acc: 0.8833
# Epoch 8/10
#  - 0s - loss: 0.2401 - acc: 0.9000
# Epoch 9/10
#  - 0s - loss: 0.2213 - acc: 0.9062
# Epoch 10/10
#  - 0s - loss: 0.2409 - acc: 0.8937
# Test accuracy: 0.7222222266373811
# Epoch 1/10
#  - 0s - loss: 0.3495 - acc: 0.8792
# Epoch 2/10
#  - 0s - loss: 0.3688 - acc: 0.8667
# Epoch 3/10
#  - 0s - loss: 0.3020 - acc: 0.8896
# Epoch 4/10
#  - 0s - loss: 0.3525 - acc: 0.8521
# Epoch 5/10
#  - 0s - loss: 0.2767 - acc: 0.9062
# Epoch 6/10
#  - 0s - loss: 0.2854 - acc: 0.9000
# Epoch 7/10
#  - 0s - loss: 0.2696 - acc: 0.9062
# Epoch 8/10
#  - 0s - loss: 0.2354 - acc: 0.9250
# Epoch 9/10
#  - 0s - loss: 0.3237 - acc: 0.8771
# Epoch 10/10
#  - 0s - loss: 0.2458 - acc: 0.9042
# Test accuracy: 0.9074074007846691
# Epoch 1/10
#  - 0s - loss: 0.2888 - acc: 0.8729
# Epoch 2/10
#  - 0s - loss: 0.2691 - acc: 0.8854
# Epoch 3/10
#  - 0s - loss: 0.2099 - acc: 0.9292
# Epoch 4/10
#  - 0s - loss: 0.2150 - acc: 0.9021
# Epoch 5/10
#  - 0s - loss: 0.1987 - acc: 0.9250
# Epoch 6/10
#  - 0s - loss: 0.2053 - acc: 0.9271
# Epoch 7/10
#  - 0s - loss: 0.2204 - acc: 0.8958
# Epoch 8/10
#  - 0s - loss: 0.1621 - acc: 0.9375
# Epoch 9/10
#  - 0s - loss: 0.1467 - acc: 0.9396
# Epoch 10/10
#  - 0s - loss: 0.1748 - acc: 0.9312
# Test accuracy: 0.8888888822661506
# Epoch 1/10
#  - 0s - loss: 0.2221 - acc: 0.9125
# Epoch 2/10
#  - 0s - loss: 0.1819 - acc: 0.9333
# Epoch 3/10
#  - 0s - loss: 0.1807 - acc: 0.9333
# Epoch 4/10
#  - 0s - loss: 0.1806 - acc: 0.9417
# Epoch 5/10
#  - 0s - loss: 0.2007 - acc: 0.9333
# Epoch 6/10
#  - 0s - loss: 0.1684 - acc: 0.9500
# Epoch 7/10
#  - 0s - loss: 0.1820 - acc: 0.9354
# Epoch 8/10
#  - 0s - loss: 0.1484 - acc: 0.9542
# Epoch 9/10
#  - 0s - loss: 0.1623 - acc: 0.9438
# Epoch 10/10
#  - 0s - loss: 0.1362 - acc: 0.9646
# Test accuracy: 0.9629629629629629
# Epoch 1/10
#  - 0s - loss: 0.2466 - acc: 0.8983
# Epoch 2/10
#  - 0s - loss: 0.1963 - acc: 0.9378
# Epoch 3/10
#  - 0s - loss: 0.1601 - acc: 0.9564
# Epoch 4/10
#  - 0s - loss: 0.1911 - acc: 0.9336
# Epoch 5/10
#  - 0s - loss: 0.1481 - acc: 0.9544
# Epoch 6/10
#  - 0s - loss: 0.1779 - acc: 0.9274
# Epoch 7/10
#  - 0s - loss: 0.1420 - acc: 0.9606
# Epoch 8/10
#  - 0s - loss: 0.1324 - acc: 0.9689
# Epoch 9/10
#  - 0s - loss: 0.1262 - acc: 0.9730
# Epoch 10/10
#  - 0s - loss: 0.1298 - acc: 0.9730
# Test accuracy: 0.8269230677531316
# Epoch 1/10
#  - 0s - loss: 0.2501 - acc: 0.9025
# Epoch 2/10
#  - 0s - loss: 0.1568 - acc: 0.9523
# Epoch 3/10
#  - 0s - loss: 0.1233 - acc: 0.9730
# Epoch 4/10
#  - 0s - loss: 0.1269 - acc: 0.9730
# Epoch 5/10
#  - 0s - loss: 0.1356 - acc: 0.9544
# Epoch 6/10
#  - 0s - loss: 0.1299 - acc: 0.9647
# Epoch 7/10
#  - 0s - loss: 0.1226 - acc: 0.9668
# Epoch 8/10
#  - 0s - loss: 0.0966 - acc: 0.9855
# Epoch 9/10
#  - 0s - loss: 0.0987 - acc: 0.9793
# Epoch 10/10
#  - 0s - loss: 0.1537 - acc: 0.9357
# Test accuracy: 0.9230769230769231
# Epoch 1/10
#  - 0s - loss: 0.2102 - acc: 0.9481
# Epoch 2/10
#  - 0s - loss: 0.1630 - acc: 0.9564
# Epoch 3/10
#  - 0s - loss: 0.1721 - acc: 0.9544
# Epoch 4/10
#  - 0s - loss: 0.1211 - acc: 0.9627
# Epoch 5/10
#  - 0s - loss: 0.1274 - acc: 0.9647
# Epoch 6/10
#  - 0s - loss: 0.1311 - acc: 0.9585
# Epoch 7/10
#  - 0s - loss: 0.1845 - acc: 0.9212
# Epoch 8/10
#  - 0s - loss: 0.1163 - acc: 0.9813
# Epoch 9/10
#  - 0s - loss: 0.1069 - acc: 0.9793
# Epoch 10/10
#  - 0s - loss: 0.1175 - acc: 0.9751
# Test accuracy: 0.9615384569534888
# Run :
# Epoch 1/10
#  - 1s - loss: 1.9082 - acc: 0.6958
# Epoch 2/10
#  - 0s - loss: 0.8545 - acc: 0.6708
# Epoch 3/10
#  - 0s - loss: 0.6264 - acc: 0.6646
# Epoch 4/10
#  - 0s - loss: 0.5464 - acc: 0.6938
# Epoch 5/10
#  - 0s - loss: 0.5766 - acc: 0.6812
# Epoch 6/10
#  - 0s - loss: 0.5409 - acc: 0.7313
# Epoch 7/10
#  - 0s - loss: 0.4910 - acc: 0.7167
# Epoch 8/10
#  - 0s - loss: 0.5109 - acc: 0.7583
# Epoch 9/10
#  - 0s - loss: 0.4701 - acc: 0.7667
# Epoch 10/10
#  - 0s - loss: 0.4658 - acc: 0.7646
# Test accuracy: 0.7407407495710585
# Epoch 1/10
#  - 0s - loss: 0.5459 - acc: 0.7500
# Epoch 2/10
#  - 0s - loss: 0.5181 - acc: 0.7500
# Epoch 3/10
#  - 0s - loss: 0.5285 - acc: 0.7708
# Epoch 4/10
#  - 0s - loss: 0.5029 - acc: 0.7500
# Epoch 5/10
#  - 0s - loss: 0.4816 - acc: 0.7479
# Epoch 6/10
#  - 0s - loss: 0.5207 - acc: 0.7521
# Epoch 7/10
#  - 0s - loss: 0.5156 - acc: 0.7688
# Epoch 8/10
#  - 0s - loss: 0.4710 - acc: 0.7979
# Epoch 9/10
#  - 0s - loss: 0.4612 - acc: 0.7688
# Epoch 10/10
#  - 0s - loss: 0.4674 - acc: 0.7604
# Test accuracy: 0.7222222200146428
# Epoch 1/10
#  - 0s - loss: 0.6549 - acc: 0.7979
# Epoch 2/10
#  - 0s - loss: 0.5228 - acc: 0.7646
# Epoch 3/10
#  - 0s - loss: 0.5830 - acc: 0.7604
# Epoch 4/10
#  - 0s - loss: 0.5197 - acc: 0.7750
# Epoch 5/10
#  - 0s - loss: 0.5276 - acc: 0.7979
# Epoch 6/10
#  - 0s - loss: 0.4819 - acc: 0.7896
# Epoch 7/10
#  - 0s - loss: 0.4399 - acc: 0.8125
# Epoch 8/10
#  - 0s - loss: 0.5246 - acc: 0.7500
# Epoch 9/10
#  - 0s - loss: 0.4603 - acc: 0.7979
# Epoch 10/10
#  - 0s - loss: 0.4524 - acc: 0.7813
# Test accuracy: 0.8333333311257539
# Epoch 1/10
#  - 0s - loss: 0.4856 - acc: 0.8125
# Epoch 2/10
#  - 0s - loss: 0.4331 - acc: 0.8167
# Epoch 3/10
#  - 0s - loss: 0.4456 - acc: 0.8271
# Epoch 4/10
#  - 0s - loss: 0.4519 - acc: 0.8229
# Epoch 5/10
#  - 0s - loss: 0.4375 - acc: 0.8250
# Epoch 6/10
#  - 0s - loss: 0.4483 - acc: 0.8229
# Epoch 7/10
#  - 0s - loss: 0.4310 - acc: 0.8104
# Epoch 8/10
#  - 0s - loss: 0.3931 - acc: 0.8521
# Epoch 9/10
#  - 0s - loss: 0.4162 - acc: 0.8375
# Epoch 10/10
#  - 0s - loss: 0.3700 - acc: 0.8625
# Test accuracy: 0.61111111552627
# Epoch 1/10
#  - 0s - loss: 0.4293 - acc: 0.8104
# Epoch 2/10
#  - 0s - loss: 0.4088 - acc: 0.8250
# Epoch 3/10
#  - 0s - loss: 0.4299 - acc: 0.7958
# Epoch 4/10
#  - 0s - loss: 0.3865 - acc: 0.8396
# Epoch 5/10
#  - 0s - loss: 0.3517 - acc: 0.8396
# Epoch 6/10
#  - 0s - loss: 0.3697 - acc: 0.8417
# Epoch 7/10
#  - 0s - loss: 0.3737 - acc: 0.8188
# Epoch 8/10
#  - 0s - loss: 0.3518 - acc: 0.8313
# Epoch 9/10
#  - 0s - loss: 0.3242 - acc: 0.8750
# Epoch 10/10
#  - 0s - loss: 0.3232 - acc: 0.8687
# Test accuracy: 0.8703703637476321
# Epoch 1/10
#  - 0s - loss: 0.4817 - acc: 0.8292
# Epoch 2/10
#  - 0s - loss: 0.4013 - acc: 0.8583
# Epoch 3/10
#  - 0s - loss: 0.3949 - acc: 0.8687
# Epoch 4/10
#  - 0s - loss: 0.3488 - acc: 0.8583
# Epoch 5/10
#  - 0s - loss: 0.3709 - acc: 0.8812
# Epoch 6/10
#  - 0s - loss: 0.4008 - acc: 0.8729
# Epoch 7/10
#  - 0s - loss: 0.3105 - acc: 0.8937
# Epoch 8/10
#  - 0s - loss: 0.2827 - acc: 0.8917
# Epoch 9/10
#  - 0s - loss: 0.2828 - acc: 0.8833
# Epoch 10/10
#  - 0s - loss: 0.2679 - acc: 0.8958
# Test accuracy: 0.8518518518518519
# Epoch 1/10
#  - 0s - loss: 0.4175 - acc: 0.8729
# Epoch 2/10
#  - 0s - loss: 0.3188 - acc: 0.8937
# Epoch 3/10
#  - 0s - loss: 0.3461 - acc: 0.8708
# Epoch 4/10
#  - 0s - loss: 0.3062 - acc: 0.9042
# Epoch 5/10
#  - 0s - loss: 0.3311 - acc: 0.8792
# Epoch 6/10
#  - 0s - loss: 0.3066 - acc: 0.9021
# Epoch 7/10
#  - 0s - loss: 0.3295 - acc: 0.8854
# Epoch 8/10
#  - 0s - loss: 0.2755 - acc: 0.9187
# Epoch 9/10
#  - 0s - loss: 0.2844 - acc: 0.9021
# Epoch 10/10
#  - 0s - loss: 0.2572 - acc: 0.9125
# Test accuracy: 0.8888888888888888
# Epoch 1/10
#  - 0s - loss: 0.3469 - acc: 0.8817
# Epoch 2/10
#  - 0s - loss: 0.2321 - acc: 0.9232
# Epoch 3/10
#  - 0s - loss: 0.2425 - acc: 0.9046
# Epoch 4/10
#  - 0s - loss: 0.1778 - acc: 0.9419
# Epoch 5/10
#  - 0s - loss: 0.1472 - acc: 0.9461
# Epoch 6/10
#  - 0s - loss: 0.2297 - acc: 0.9170
# Epoch 7/10
#  - 0s - loss: 0.1977 - acc: 0.9295
# Epoch 8/10
#  - 0s - loss: 0.1998 - acc: 0.9129
# Epoch 9/10
#  - 0s - loss: 0.1433 - acc: 0.9564
# Epoch 10/10
#  - 0s - loss: 0.1328 - acc: 0.9502
# Test accuracy: 0.8653846062146701
# Epoch 1/10
#  - 0s - loss: 0.2194 - acc: 0.9336
# Epoch 2/10
#  - 0s - loss: 0.1616 - acc: 0.9502
# Epoch 3/10
#  - 0s - loss: 0.1600 - acc: 0.9461
# Epoch 4/10
#  - 0s - loss: 0.1526 - acc: 0.9585
# Epoch 5/10
#  - 0s - loss: 0.1236 - acc: 0.9668
# Epoch 6/10
#  - 0s - loss: 0.1361 - acc: 0.9481
# Epoch 7/10
#  - 0s - loss: 0.1728 - acc: 0.9357
# Epoch 8/10
#  - 0s - loss: 0.1114 - acc: 0.9647
# Epoch 9/10
#  - 0s - loss: 0.1061 - acc: 0.9689
# Epoch 10/10
#  - 0s - loss: 0.0855 - acc: 0.9813
# Test accuracy: 0.9230769184919504
# Epoch 1/10
#  - 0s - loss: 0.2465 - acc: 0.9232
# Epoch 2/10
#  - 0s - loss: 0.1969 - acc: 0.9419
# Epoch 3/10
#  - 0s - loss: 0.1739 - acc: 0.9481
# Epoch 4/10
#  - 0s - loss: 0.1641 - acc: 0.9689
# Epoch 5/10
#  - 0s - loss: 0.1331 - acc: 0.9730
# Epoch 6/10
#  - 0s - loss: 0.1256 - acc: 0.9813
# Epoch 7/10
#  - 0s - loss: 0.1333 - acc: 0.9710
# Epoch 8/10
#  - 0s - loss: 0.1343 - acc: 0.9710
# Epoch 9/10
#  - 0s - loss: 0.1411 - acc: 0.9564
# Epoch 10/10
#  - 0s - loss: 0.1353 - acc: 0.9668
# Test accuracy: 0.9807692307692307
# Run :
# Epoch 1/10
#  - 1s - loss: 2.8308 - acc: 0.5813
# Epoch 2/10
#  - 0s - loss: 1.5795 - acc: 0.6917
# Epoch 3/10
#  - 0s - loss: 1.0907 - acc: 0.6979
# Epoch 4/10
#  - 0s - loss: 0.9692 - acc: 0.7146
# Epoch 5/10
#  - 0s - loss: 0.8780 - acc: 0.7104
# Epoch 6/10
#  - 0s - loss: 0.7142 - acc: 0.7021
# Epoch 7/10
#  - 0s - loss: 0.6356 - acc: 0.7208
# Epoch 8/10
#  - 0s - loss: 0.6062 - acc: 0.7562
# Epoch 9/10
#  - 0s - loss: 0.6045 - acc: 0.7229
# Epoch 10/10
#  - 0s - loss: 0.6309 - acc: 0.7396
# Test accuracy: 0.8148148126072354
# Epoch 1/10
#  - 0s - loss: 0.6342 - acc: 0.7354
# Epoch 2/10
#  - 0s - loss: 0.5247 - acc: 0.7458
# Epoch 3/10
#  - 0s - loss: 0.4986 - acc: 0.7208
# Epoch 4/10
#  - 0s - loss: 0.5746 - acc: 0.7333
# Epoch 5/10
#  - 0s - loss: 0.5162 - acc: 0.7521
# Epoch 6/10
#  - 0s - loss: 0.5205 - acc: 0.7729
# Epoch 7/10
#  - 0s - loss: 0.5419 - acc: 0.7312
# Epoch 8/10
#  - 0s - loss: 0.5299 - acc: 0.7646
# Epoch 9/10
#  - 0s - loss: 0.4532 - acc: 0.7604
# Epoch 10/10
#  - 0s - loss: 0.5614 - acc: 0.7417
# Test accuracy: 0.7592592570516798
# Epoch 1/10
#  - 0s - loss: 0.6015 - acc: 0.7521
# Epoch 2/10
#  - 0s - loss: 0.6483 - acc: 0.7500
# Epoch 3/10
#  - 0s - loss: 0.6112 - acc: 0.7521
# Epoch 4/10
#  - 0s - loss: 0.5922 - acc: 0.7771
# Epoch 5/10
#  - 0s - loss: 0.5403 - acc: 0.7792
# Epoch 6/10
#  - 0s - loss: 0.5200 - acc: 0.7667
# Epoch 7/10
#  - 0s - loss: 0.5771 - acc: 0.7625
# Epoch 8/10
#  - 0s - loss: 0.5363 - acc: 0.7729
# Epoch 9/10
#  - 0s - loss: 0.5274 - acc: 0.8000
# Epoch 10/10
#  - 0s - loss: 0.5084 - acc: 0.7896
# Test accuracy: 0.7777777799853572
# Epoch 1/10
#  - 0s - loss: 0.5078 - acc: 0.7937
# Epoch 2/10
#  - 0s - loss: 0.5402 - acc: 0.7688
# Epoch 3/10
#  - 0s - loss: 0.4360 - acc: 0.8188
# Epoch 4/10
#  - 0s - loss: 0.5373 - acc: 0.7958
# Epoch 5/10
#  - 0s - loss: 0.5811 - acc: 0.8063
# Epoch 6/10
#  - 0s - loss: 0.5067 - acc: 0.7979
# Epoch 7/10
#  - 0s - loss: 0.5244 - acc: 0.7979
# Epoch 8/10
#  - 0s - loss: 0.4288 - acc: 0.8021
# Epoch 9/10
#  - 0s - loss: 0.4295 - acc: 0.8438
# Epoch 10/10
#  - 0s - loss: 0.5350 - acc: 0.8146
# Test accuracy: 0.6851851763548674
# Epoch 1/10
#  - 0s - loss: 0.4364 - acc: 0.7958
# Epoch 2/10
#  - 0s - loss: 0.5449 - acc: 0.7917
# Epoch 3/10
#  - 0s - loss: 0.4557 - acc: 0.8188
# Epoch 4/10
#  - 0s - loss: 0.4249 - acc: 0.8167
# Epoch 5/10
#  - 0s - loss: 0.4725 - acc: 0.8229
# Epoch 6/10
#  - 0s - loss: 0.4869 - acc: 0.7958
# Epoch 7/10
#  - 0s - loss: 0.4305 - acc: 0.8188
# Epoch 8/10
#  - 0s - loss: 0.4986 - acc: 0.7979
# Epoch 9/10
#  - 0s - loss: 0.4170 - acc: 0.8083
# Epoch 10/10
#  - 0s - loss: 0.4075 - acc: 0.8479
# Test accuracy: 0.8703703814082675
# Epoch 1/10
#  - 0s - loss: 0.5775 - acc: 0.8021
# Epoch 2/10
#  - 0s - loss: 0.4561 - acc: 0.8208
# Epoch 3/10
#  - 0s - loss: 0.4713 - acc: 0.8271
# Epoch 4/10
#  - 0s - loss: 0.4218 - acc: 0.8271
# Epoch 5/10
#  - 0s - loss: 0.4269 - acc: 0.8188
# Epoch 6/10
#  - 0s - loss: 0.5772 - acc: 0.7917
# Epoch 7/10
#  - 0s - loss: 0.3894 - acc: 0.8292
# Epoch 8/10
#  - 0s - loss: 0.4090 - acc: 0.8208
# Epoch 9/10
#  - 0s - loss: 0.4396 - acc: 0.8146
# Epoch 10/10
#  - 0s - loss: 0.4079 - acc: 0.8167
# Test accuracy: 0.8703703747855293
# Epoch 1/10
#  - 0s - loss: 0.4045 - acc: 0.8292
# Epoch 2/10
#  - 0s - loss: 0.4401 - acc: 0.8271
# Epoch 3/10
#  - 0s - loss: 0.3919 - acc: 0.8354
# Epoch 4/10
#  - 0s - loss: 0.3986 - acc: 0.8333
# Epoch 5/10
#  - 0s - loss: 0.3861 - acc: 0.8542
# Epoch 6/10
#  - 0s - loss: 0.3705 - acc: 0.8437
# Epoch 7/10
#  - 0s - loss: 0.3868 - acc: 0.8229
# Epoch 8/10
#  - 0s - loss: 0.3892 - acc: 0.8208
# Epoch 9/10
#  - 0s - loss: 0.4254 - acc: 0.8375
# Epoch 10/10
#  - 0s - loss: 0.3675 - acc: 0.8625
# Test accuracy: 0.8148148192299737
# Epoch 1/10
#  - 0s - loss: 0.4521 - acc: 0.8278
# Epoch 2/10
#  - 0s - loss: 0.3642 - acc: 0.8485
# Epoch 3/10
#  - 0s - loss: 0.3329 - acc: 0.8693
# Epoch 4/10
#  - 0s - loss: 0.3544 - acc: 0.8402
# Epoch 5/10
#  - 0s - loss: 0.3792 - acc: 0.8320
# Epoch 6/10
#  - 0s - loss: 0.3376 - acc: 0.8465
# Epoch 7/10
#  - 0s - loss: 0.3240 - acc: 0.8631
# Epoch 8/10
#  - 0s - loss: 0.3271 - acc: 0.8423
# Epoch 9/10
#  - 0s - loss: 0.3504 - acc: 0.8340
# Epoch 10/10
#  - 0s - loss: 0.3431 - acc: 0.8465
# Test accuracy: 0.7884615292915931
# Epoch 1/10
#  - 0s - loss: 0.3313 - acc: 0.8444
# Epoch 2/10
#  - 0s - loss: 0.3350 - acc: 0.8568
# Epoch 3/10
#  - 0s - loss: 0.3063 - acc: 0.8714
# Epoch 4/10
#  - 0s - loss: 0.3261 - acc: 0.8610
# Epoch 5/10
#  - 0s - loss: 0.3091 - acc: 0.8548
# Epoch 6/10
#  - 0s - loss: 0.3417 - acc: 0.8776
# Epoch 7/10
#  - 0s - loss: 0.3070 - acc: 0.8880
# Epoch 8/10
#  - 0s - loss: 0.2942 - acc: 0.8672
# Epoch 9/10
#  - 0s - loss: 0.3008 - acc: 0.8755
# Epoch 10/10
#  - 0s - loss: 0.2769 - acc: 0.8693
# Test accuracy: 0.9038461538461539
# Epoch 1/10
#  - 0s - loss: 0.3609 - acc: 0.8506
# Epoch 2/10
#  - 0s - loss: 0.3531 - acc: 0.8485
# Epoch 3/10
#  - 0s - loss: 0.3068 - acc: 0.8672
# Epoch 4/10
#  - 0s - loss: 0.3245 - acc: 0.8589
# Epoch 5/10
#  - 0s - loss: 0.3085 - acc: 0.8506
# Epoch 6/10
#  - 0s - loss: 0.3350 - acc: 0.8610
# Epoch 7/10
#  - 0s - loss: 0.3128 - acc: 0.8734
# Epoch 8/10
#  - 0s - loss: 0.3311 - acc: 0.8631
# Epoch 9/10
#  - 0s - loss: 0.2976 - acc: 0.8672
# Epoch 10/10
#  - 0s - loss: 0.2744 - acc: 0.8631
# Test accuracy: 0.9615384569534888
# Run :
# Epoch 1/10
#  - 1s - loss: 2.8855 - acc: 0.5917
# Epoch 2/10
#  - 0s - loss: 0.9590 - acc: 0.6896
# Epoch 3/10
#  - 0s - loss: 0.7175 - acc: 0.6771
# Epoch 4/10
#  - 0s - loss: 0.7381 - acc: 0.6708
# Epoch 5/10
#  - 0s - loss: 0.6070 - acc: 0.7292
# Epoch 6/10
#  - 0s - loss: 0.5565 - acc: 0.7792
# Epoch 7/10
#  - 0s - loss: 0.6292 - acc: 0.7375
# Epoch 8/10
#  - 0s - loss: 0.5925 - acc: 0.7417
# Epoch 9/10
#  - 0s - loss: 0.5615 - acc: 0.7521
# Epoch 10/10
#  - 0s - loss: 0.5356 - acc: 0.7208
# Test accuracy: 0.7407407407407407
# Epoch 1/10
#  - 0s - loss: 0.5610 - acc: 0.7479
# Epoch 2/10
#  - 0s - loss: 0.5399 - acc: 0.7583
# Epoch 3/10
#  - 0s - loss: 0.5722 - acc: 0.7500
# Epoch 4/10
#  - 0s - loss: 0.5379 - acc: 0.7667
# Epoch 5/10
#  - 0s - loss: 0.5432 - acc: 0.7354
# Epoch 6/10
#  - 0s - loss: 0.5001 - acc: 0.7729
# Epoch 7/10
#  - 0s - loss: 0.5176 - acc: 0.7646
# Epoch 8/10
#  - 0s - loss: 0.4948 - acc: 0.7688
# Epoch 9/10
#  - 0s - loss: 0.5171 - acc: 0.7708
# Epoch 10/10
#  - 0s - loss: 0.4792 - acc: 0.7646
# Test accuracy: 0.6851851829776058
# Epoch 1/10
#  - 0s - loss: 0.5961 - acc: 0.7896
# Epoch 2/10
#  - 0s - loss: 0.5733 - acc: 0.7708
# Epoch 3/10
#  - 0s - loss: 0.5950 - acc: 0.7792
# Epoch 4/10
#  - 0s - loss: 0.6035 - acc: 0.7667
# Epoch 5/10
#  - 0s - loss: 0.5164 - acc: 0.7792
# Epoch 6/10
#  - 0s - loss: 0.5355 - acc: 0.7937
# Epoch 7/10
#  - 0s - loss: 0.4992 - acc: 0.8000
# Epoch 8/10
#  - 0s - loss: 0.4987 - acc: 0.7833
# Epoch 9/10
#  - 0s - loss: 0.5227 - acc: 0.7896
# Epoch 10/10
#  - 0s - loss: 0.4907 - acc: 0.7833
# Test accuracy: 0.8333333311257539
# Epoch 1/10
#  - 0s - loss: 0.5525 - acc: 0.7875
# Epoch 2/10
#  - 0s - loss: 0.5121 - acc: 0.8062
# Epoch 3/10
#  - 0s - loss: 0.5223 - acc: 0.7812
# Epoch 4/10
#  - 0s - loss: 0.4747 - acc: 0.8125
# Epoch 5/10
#  - 0s - loss: 0.4609 - acc: 0.7958
# Epoch 6/10
#  - 0s - loss: 0.3999 - acc: 0.8146
# Epoch 7/10
#  - 0s - loss: 0.4353 - acc: 0.8000
# Epoch 8/10
#  - 0s - loss: 0.3938 - acc: 0.8396
# Epoch 9/10
#  - 0s - loss: 0.3871 - acc: 0.8313
# Epoch 10/10
#  - 0s - loss: 0.4017 - acc: 0.8333
# Test accuracy: 0.6851851940155029
# Epoch 1/10
#  - 0s - loss: 0.4562 - acc: 0.7833
# Epoch 2/10
#  - 0s - loss: 0.4478 - acc: 0.8146
# Epoch 3/10
#  - 0s - loss: 0.4419 - acc: 0.8146
# Epoch 4/10
#  - 0s - loss: 0.4288 - acc: 0.8208
# Epoch 5/10
#  - 0s - loss: 0.3944 - acc: 0.8312
# Epoch 6/10
#  - 0s - loss: 0.4267 - acc: 0.8062
# Epoch 7/10
#  - 0s - loss: 0.3833 - acc: 0.8458
# Epoch 8/10
#  - 0s - loss: 0.3852 - acc: 0.8292
# Epoch 9/10
#  - 0s - loss: 0.4084 - acc: 0.8083
# Epoch 10/10
#  - 0s - loss: 0.4346 - acc: 0.8250
# Test accuracy: 0.8333333377484922
# Epoch 1/10
#  - 0s - loss: 0.4577 - acc: 0.8146
# Epoch 2/10
#  - 0s - loss: 0.4058 - acc: 0.8146
# Epoch 3/10
#  - 0s - loss: 0.3911 - acc: 0.8292
# Epoch 4/10
#  - 0s - loss: 0.3528 - acc: 0.8333
# Epoch 5/10
#  - 0s - loss: 0.3637 - acc: 0.8396
# Epoch 6/10
#  - 0s - loss: 0.3309 - acc: 0.8438
# Epoch 7/10
#  - 0s - loss: 0.3073 - acc: 0.8479
# Epoch 8/10
#  - 0s - loss: 0.3700 - acc: 0.8292
# Epoch 9/10
#  - 0s - loss: 0.3041 - acc: 0.8687
# Epoch 10/10
#  - 0s - loss: 0.2799 - acc: 0.8667
# Test accuracy: 0.7962963073341934
# Epoch 1/10
#  - 0s - loss: 0.3615 - acc: 0.8563
# Epoch 2/10
#  - 0s - loss: 0.3215 - acc: 0.8500
# Epoch 3/10
#  - 0s - loss: 0.3328 - acc: 0.8646
# Epoch 4/10
#  - 0s - loss: 0.2899 - acc: 0.8625
# Epoch 5/10
#  - 0s - loss: 0.2816 - acc: 0.8750
# Epoch 6/10
#  - 0s - loss: 0.2827 - acc: 0.8896
# Epoch 7/10
#  - 0s - loss: 0.2719 - acc: 0.8958
# Epoch 8/10
#  - 0s - loss: 0.2698 - acc: 0.8937
# Epoch 9/10
#  - 0s - loss: 0.2742 - acc: 0.8792
# Epoch 10/10
#  - 0s - loss: 0.2420 - acc: 0.8833
# Test accuracy: 0.8518518452291135
# Epoch 1/10
#  - 0s - loss: 0.3592 - acc: 0.8817
# Epoch 2/10
#  - 0s - loss: 0.3030 - acc: 0.8921
# Epoch 3/10
#  - 0s - loss: 0.2832 - acc: 0.8817
# Epoch 4/10
#  - 0s - loss: 0.2523 - acc: 0.9004
# Epoch 5/10
#  - 0s - loss: 0.2852 - acc: 0.8880
# Epoch 6/10
#  - 0s - loss: 0.2283 - acc: 0.9025
# Epoch 7/10
#  - 0s - loss: 0.2105 - acc: 0.9108
# Epoch 8/10
#  - 0s - loss: 0.2267 - acc: 0.9066
# Epoch 9/10
#  - 0s - loss: 0.2313 - acc: 0.9191
# Epoch 10/10
#  - 0s - loss: 0.2220 - acc: 0.9129
# Test accuracy: 0.8076923168622531
# Epoch 1/10
#  - 0s - loss: 0.2690 - acc: 0.8776
# Epoch 2/10
#  - 0s - loss: 0.2166 - acc: 0.9046
# Epoch 3/10
#  - 0s - loss: 0.2482 - acc: 0.8963
# Epoch 4/10
#  - 0s - loss: 0.2499 - acc: 0.8942
# Epoch 5/10
#  - 0s - loss: 0.1946 - acc: 0.9253
# Epoch 6/10
#  - 0s - loss: 0.2097 - acc: 0.9191
# Epoch 7/10
#  - 0s - loss: 0.2103 - acc: 0.9170
# Epoch 8/10
#  - 0s - loss: 0.2080 - acc: 0.9170
# Epoch 9/10
#  - 0s - loss: 0.1840 - acc: 0.9295
# Epoch 10/10
#  - 0s - loss: 0.2361 - acc: 0.9087
# Test accuracy: 0.9038461538461539
# Epoch 1/10
#  - 0s - loss: 0.2680 - acc: 0.9108
# Epoch 2/10
#  - 0s - loss: 0.2413 - acc: 0.9087
# Epoch 3/10
#  - 0s - loss: 0.2388 - acc: 0.9191
# Epoch 4/10
#  - 0s - loss: 0.1919 - acc: 0.9336
# Epoch 5/10
#  - 0s - loss: 0.1695 - acc: 0.9419
# Epoch 6/10
#  - 0s - loss: 0.1608 - acc: 0.9461
# Epoch 7/10
#  - 0s - loss: 0.1727 - acc: 0.9481
# Epoch 8/10
#  - 0s - loss: 0.1711 - acc: 0.9357
# Epoch 9/10
#  - 0s - loss: 0.1811 - acc: 0.9481
# Epoch 10/10
#  - 0s - loss: 0.1691 - acc: 0.9461
# Test accuracy: 0.9615384615384616
# Run :
# Epoch 1/10
#  - 1s - loss: 1.2646 - acc: 0.6437
# Epoch 2/10
#  - 0s - loss: 0.8028 - acc: 0.6688
# Epoch 3/10
#  - 0s - loss: 0.5980 - acc: 0.6875
# Epoch 4/10
#  - 0s - loss: 0.7149 - acc: 0.6500
# Epoch 5/10
#  - 0s - loss: 0.6717 - acc: 0.6979
# Epoch 6/10
#  - 0s - loss: 0.6374 - acc: 0.6917
# Epoch 7/10
#  - 0s - loss: 0.5480 - acc: 0.6875
# Epoch 8/10
#  - 0s - loss: 0.5907 - acc: 0.6500
# Epoch 9/10
#  - 0s - loss: 0.5512 - acc: 0.7187
# Epoch 10/10
#  - 0s - loss: 0.6238 - acc: 0.6562
# Test accuracy: 0.666666673289405
# Epoch 1/10
#  - 0s - loss: 0.5879 - acc: 0.6687
# Epoch 2/10
#  - 0s - loss: 0.5630 - acc: 0.6667
# Epoch 3/10
#  - 0s - loss: 0.5609 - acc: 0.6500
# Epoch 4/10
#  - 0s - loss: 0.5670 - acc: 0.7021
# Epoch 5/10
#  - 0s - loss: 0.5178 - acc: 0.6938
# Epoch 6/10
#  - 0s - loss: 0.5235 - acc: 0.7042
# Epoch 7/10
#  - 0s - loss: 0.5670 - acc: 0.6792
# Epoch 8/10
#  - 0s - loss: 0.5411 - acc: 0.6917
# Epoch 9/10
#  - 0s - loss: 0.4708 - acc: 0.7021
# Epoch 10/10
#  - 0s - loss: 0.4951 - acc: 0.7062
# Test accuracy: 0.7222222222222222
# Epoch 1/10
#  - 0s - loss: 0.6290 - acc: 0.6583
# Epoch 2/10
#  - 0s - loss: 0.5575 - acc: 0.6417
# Epoch 3/10
#  - 0s - loss: 0.6019 - acc: 0.6542
# Epoch 4/10
#  - 0s - loss: 0.5591 - acc: 0.6562
# Epoch 5/10
#  - 0s - loss: 0.5001 - acc: 0.7146
# Epoch 6/10
#  - 0s - loss: 0.5624 - acc: 0.6771
# Epoch 7/10
#  - 0s - loss: 0.5348 - acc: 0.6938
# Epoch 8/10
#  - 0s - loss: 0.5466 - acc: 0.7292
# Epoch 9/10
#  - 0s - loss: 0.5213 - acc: 0.7104
# Epoch 10/10
#  - 0s - loss: 0.5036 - acc: 0.6750
# Test accuracy: 0.8148148236451326
# Epoch 1/10
#  - 0s - loss: 0.5443 - acc: 0.6500
# Epoch 2/10
#  - 0s - loss: 0.5646 - acc: 0.6750
# Epoch 3/10
#  - 0s - loss: 0.5617 - acc: 0.6792
# Epoch 4/10
#  - 0s - loss: 0.5380 - acc: 0.7354
# Epoch 5/10
#  - 0s - loss: 0.5217 - acc: 0.6833
# Epoch 6/10
#  - 0s - loss: 0.4743 - acc: 0.6771
# Epoch 7/10
#  - 0s - loss: 0.4483 - acc: 0.7458
# Epoch 8/10
#  - 0s - loss: 0.4669 - acc: 0.7333
# Epoch 9/10
#  - 0s - loss: 0.4999 - acc: 0.7229
# Epoch 10/10
#  - 0s - loss: 0.4874 - acc: 0.7312
# Test accuracy: 0.5740740696589152
# Epoch 1/10
#  - 0s - loss: 0.4880 - acc: 0.7000
# Epoch 2/10
#  - 0s - loss: 0.4697 - acc: 0.7146
# Epoch 3/10
#  - 0s - loss: 0.4685 - acc: 0.7521
# Epoch 4/10
#  - 0s - loss: 0.4794 - acc: 0.7562
# Epoch 5/10
#  - 0s - loss: 0.4471 - acc: 0.7583
# Epoch 6/10
#  - 0s - loss: 0.4382 - acc: 0.7875
# Epoch 7/10
#  - 0s - loss: 0.4427 - acc: 0.8167
# Epoch 8/10
#  - 0s - loss: 0.4749 - acc: 0.7937
# Epoch 9/10
#  - 0s - loss: 0.4283 - acc: 0.7979
# Epoch 10/10
#  - 0s - loss: 0.4533 - acc: 0.7875
# Test accuracy: 0.8333333443712305
# Epoch 1/10
#  - 0s - loss: 0.5257 - acc: 0.7917
# Epoch 2/10
#  - 0s - loss: 0.4673 - acc: 0.8104
# Epoch 3/10
#  - 0s - loss: 0.5740 - acc: 0.7604
# Epoch 4/10
#  - 0s - loss: 0.4365 - acc: 0.7979
# Epoch 5/10
#  - 0s - loss: 0.4576 - acc: 0.8125
# Epoch 6/10
#  - 0s - loss: 0.4398 - acc: 0.8021
# Epoch 7/10
#  - 0s - loss: 0.4491 - acc: 0.8021
# Epoch 8/10
#  - 0s - loss: 0.4197 - acc: 0.8208
# Epoch 9/10
#  - 0s - loss: 0.4133 - acc: 0.8271
# Epoch 10/10
#  - 0s - loss: 0.4484 - acc: 0.7917
# Test accuracy: 0.833333326710595
# Epoch 1/10
#  - 0s - loss: 0.5106 - acc: 0.8271
# Epoch 2/10
#  - 0s - loss: 0.4639 - acc: 0.8229
# Epoch 3/10
#  - 0s - loss: 0.5023 - acc: 0.8167
# Epoch 4/10
#  - 0s - loss: 0.4273 - acc: 0.8375
# Epoch 5/10
#  - 0s - loss: 0.4405 - acc: 0.8083
# Epoch 6/10
#  - 0s - loss: 0.5366 - acc: 0.8354
# Epoch 7/10
#  - 0s - loss: 0.4505 - acc: 0.8354
# Epoch 8/10
#  - 0s - loss: 0.4659 - acc: 0.8375
# Epoch 9/10
#  - 0s - loss: 0.4204 - acc: 0.8250
# Epoch 10/10
#  - 0s - loss: 0.4770 - acc: 0.8313
# Test accuracy: 0.8333333443712305
# Epoch 1/10
#  - 0s - loss: 0.4417 - acc: 0.8320
# Epoch 2/10
#  - 0s - loss: 0.4179 - acc: 0.8091
# Epoch 3/10
#  - 0s - loss: 0.3842 - acc: 0.8548
# Epoch 4/10
#  - 0s - loss: 0.3828 - acc: 0.8423
# Epoch 5/10
#  - 0s - loss: 0.3869 - acc: 0.8506
# Epoch 6/10
#  - 0s - loss: 0.3930 - acc: 0.8154
# Epoch 7/10
#  - 0s - loss: 0.3959 - acc: 0.8465
# Epoch 8/10
#  - 0s - loss: 0.3455 - acc: 0.8320
# Epoch 9/10
#  - 0s - loss: 0.3818 - acc: 0.8320
# Epoch 10/10
#  - 0s - loss: 0.3762 - acc: 0.8485
# Test accuracy: 0.8076923168622531
# Epoch 1/10
#  - 0s - loss: 0.3319 - acc: 0.8485
# Epoch 2/10
#  - 0s - loss: 0.3394 - acc: 0.8527
# Epoch 3/10
#  - 0s - loss: 0.2735 - acc: 0.8817
# Epoch 4/10
#  - 0s - loss: 0.3439 - acc: 0.8568
# Epoch 5/10
#  - 0s - loss: 0.3925 - acc: 0.8257
# Epoch 6/10
#  - 0s - loss: 0.3659 - acc: 0.8589
# Epoch 7/10
#  - 0s - loss: 0.3331 - acc: 0.8651
# Epoch 8/10
#  - 0s - loss: 0.2901 - acc: 0.8817
# Epoch 9/10
#  - 0s - loss: 0.3354 - acc: 0.8506
# Epoch 10/10
#  - 0s - loss: 0.3106 - acc: 0.8859
# Test accuracy: 0.8269230723381042
# Epoch 1/10
#  - 0s - loss: 0.4252 - acc: 0.8506
# Epoch 2/10
#  - 0s - loss: 0.4146 - acc: 0.8133
# Epoch 3/10
#  - 0s - loss: 0.4486 - acc: 0.8444
# Epoch 4/10
#  - 0s - loss: 0.4607 - acc: 0.8382
# Epoch 5/10
#  - 0s - loss: 0.3707 - acc: 0.8631
# Epoch 6/10
#  - 0s - loss: 0.3915 - acc: 0.8257
# Epoch 7/10
#  - 0s - loss: 0.3753 - acc: 0.8506
# Epoch 8/10
#  - 0s - loss: 0.3478 - acc: 0.8548
# Epoch 9/10
#  - 0s - loss: 0.3770 - acc: 0.8548
# Epoch 10/10
#  - 0s - loss: 0.3118 - acc: 0.8693
# Test accuracy: 0.9615384569534888
# Run :
# Epoch 1/10
#  - 1s - loss: 1.3600 - acc: 0.6021
# Epoch 2/10
#  - 0s - loss: 0.7267 - acc: 0.6625
# Epoch 3/10
#  - 0s - loss: 0.6552 - acc: 0.6771
# Epoch 4/10
#  - 0s - loss: 0.5860 - acc: 0.6875
# Epoch 5/10
#  - 0s - loss: 0.5187 - acc: 0.6854
# Epoch 6/10
#  - 0s - loss: 0.5513 - acc: 0.7104
# Epoch 7/10
#  - 0s - loss: 0.5307 - acc: 0.7167
# Epoch 8/10
#  - 0s - loss: 0.4730 - acc: 0.7167
# Epoch 9/10
#  - 0s - loss: 0.4964 - acc: 0.7354
# Epoch 10/10
#  - 0s - loss: 0.5274 - acc: 0.7146
# Test accuracy: 0.7222222133919045
# Epoch 1/10
#  - 0s - loss: 0.5249 - acc: 0.7042
# Epoch 2/10
#  - 0s - loss: 0.5601 - acc: 0.6854
# Epoch 3/10
#  - 0s - loss: 0.4916 - acc: 0.7000
# Epoch 4/10
#  - 0s - loss: 0.4751 - acc: 0.7104
# Epoch 5/10
#  - 0s - loss: 0.4849 - acc: 0.7104
# Epoch 6/10
#  - 0s - loss: 0.4554 - acc: 0.7375
# Epoch 7/10
#  - 0s - loss: 0.4460 - acc: 0.7396
# Epoch 8/10
#  - 0s - loss: 0.4415 - acc: 0.7562
# Epoch 9/10
#  - 0s - loss: 0.4576 - acc: 0.7646
# Epoch 10/10
#  - 0s - loss: 0.4294 - acc: 0.7604
# Test accuracy: 0.7777777755701983
# Epoch 1/10
#  - 0s - loss: 0.5370 - acc: 0.7396
# Epoch 2/10
#  - 0s - loss: 0.4987 - acc: 0.7167
# Epoch 3/10
#  - 0s - loss: 0.5093 - acc: 0.7208
# Epoch 4/10
#  - 0s - loss: 0.4501 - acc: 0.7500
# Epoch 5/10
#  - 0s - loss: 0.4632 - acc: 0.7688
# Epoch 6/10
#  - 0s - loss: 0.4472 - acc: 0.7417
# Epoch 7/10
#  - 0s - loss: 0.4191 - acc: 0.7875
# Epoch 8/10
#  - 0s - loss: 0.4235 - acc: 0.7854
# Epoch 9/10
#  - 0s - loss: 0.4389 - acc: 0.7479
# Epoch 10/10
#  - 0s - loss: 0.4063 - acc: 0.7875
# Test accuracy: 0.8148148236451326
# Epoch 1/10
#  - 0s - loss: 0.4442 - acc: 0.7812
# Epoch 2/10
#  - 0s - loss: 0.4040 - acc: 0.8000
# Epoch 3/10
#  - 0s - loss: 0.4173 - acc: 0.8125
# Epoch 4/10
#  - 0s - loss: 0.3818 - acc: 0.8187
# Epoch 5/10
#  - 0s - loss: 0.3718 - acc: 0.7875
# Epoch 6/10
#  - 0s - loss: 0.4373 - acc: 0.7917
# Epoch 7/10
#  - 0s - loss: 0.3760 - acc: 0.8104
# Epoch 8/10
#  - 0s - loss: 0.3937 - acc: 0.7833
# Epoch 9/10
#  - 0s - loss: 0.3288 - acc: 0.8188
# Epoch 10/10
#  - 0s - loss: 0.3587 - acc: 0.8104
# Test accuracy: 0.6666666600439284
# Epoch 1/10
#  - 0s - loss: 0.4872 - acc: 0.8125
# Epoch 2/10
#  - 0s - loss: 0.4526 - acc: 0.7812
# Epoch 3/10
#  - 0s - loss: 0.4160 - acc: 0.8375
# Epoch 4/10
#  - 0s - loss: 0.4407 - acc: 0.7812
# Epoch 5/10
#  - 0s - loss: 0.4376 - acc: 0.7938
# Epoch 6/10
#  - 0s - loss: 0.4107 - acc: 0.8188
# Epoch 7/10
#  - 0s - loss: 0.3833 - acc: 0.8208
# Epoch 8/10
#  - 0s - loss: 0.4000 - acc: 0.7917
# Epoch 9/10
#  - 0s - loss: 0.4126 - acc: 0.8271
# Epoch 10/10
#  - 0s - loss: 0.3833 - acc: 0.8021
# Test accuracy: 0.8148148126072354
# Epoch 1/10
#  - 0s - loss: 0.4518 - acc: 0.7958
# Epoch 2/10
#  - 0s - loss: 0.3793 - acc: 0.8146
# Epoch 3/10
#  - 0s - loss: 0.3636 - acc: 0.7938
# Epoch 4/10
#  - 0s - loss: 0.3136 - acc: 0.8188
# Epoch 5/10
#  - 0s - loss: 0.3136 - acc: 0.8167
# Epoch 6/10
#  - 0s - loss: 0.3457 - acc: 0.8000
# Epoch 7/10
#  - 0s - loss: 0.3324 - acc: 0.7958
# Epoch 8/10
#  - 0s - loss: 0.3416 - acc: 0.8146
# Epoch 9/10
#  - 0s - loss: 0.3156 - acc: 0.8417
# Epoch 10/10
#  - 0s - loss: 0.3157 - acc: 0.8312
# Test accuracy: 0.8703703814082675
# Epoch 1/10
#  - 0s - loss: 0.3227 - acc: 0.8417
# Epoch 2/10
#  - 0s - loss: 0.3417 - acc: 0.8187
# Epoch 3/10
#  - 0s - loss: 0.3114 - acc: 0.8375
# Epoch 4/10
#  - 0s - loss: 0.3072 - acc: 0.8396
# Epoch 5/10
#  - 0s - loss: 0.3542 - acc: 0.8417
# Epoch 6/10
#  - 0s - loss: 0.3395 - acc: 0.8333
# Epoch 7/10
#  - 0s - loss: 0.3102 - acc: 0.8375
# Epoch 8/10
#  - 0s - loss: 0.3163 - acc: 0.8458
# Epoch 9/10
#  - 0s - loss: 0.3209 - acc: 0.8437
# Epoch 10/10
#  - 0s - loss: 0.2914 - acc: 0.8583
# Test accuracy: 0.8888888999267861
# Epoch 1/10
#  - 0s - loss: 0.3592 - acc: 0.8299
# Epoch 2/10
#  - 0s - loss: 0.3039 - acc: 0.8527
# Epoch 3/10
#  - 0s - loss: 0.3721 - acc: 0.8257
# Epoch 4/10
#  - 0s - loss: 0.3016 - acc: 0.8610
# Epoch 5/10
#  - 0s - loss: 0.2992 - acc: 0.8527
# Epoch 6/10
#  - 0s - loss: 0.2949 - acc: 0.8402
# Epoch 7/10
#  - 0s - loss: 0.2892 - acc: 0.8506
# Epoch 8/10
#  - 0s - loss: 0.2899 - acc: 0.8714
# Epoch 9/10
#  - 0s - loss: 0.2917 - acc: 0.8568
# Epoch 10/10
#  - 0s - loss: 0.3058 - acc: 0.8589
# Test accuracy: 0.8461538507388189
# Epoch 1/10
#  - 0s - loss: 0.2963 - acc: 0.8506
# Epoch 2/10
#  - 0s - loss: 0.2717 - acc: 0.8693
# Epoch 3/10
#  - 0s - loss: 0.2659 - acc: 0.8651
# Epoch 4/10
#  - 0s - loss: 0.2621 - acc: 0.8734
# Epoch 5/10
#  - 0s - loss: 0.2761 - acc: 0.8548
# Epoch 6/10
#  - 0s - loss: 0.2943 - acc: 0.8548
# Epoch 7/10
#  - 0s - loss: 0.2507 - acc: 0.8693
# Epoch 8/10
#  - 0s - loss: 0.2451 - acc: 0.8900
# Epoch 9/10
#  - 0s - loss: 0.2368 - acc: 0.8921
# Epoch 10/10
#  - 0s - loss: 0.2599 - acc: 0.8734
# Test accuracy: 0.8461538415688735
# Epoch 1/10
#  - 0s - loss: 0.3434 - acc: 0.8610
# Epoch 2/10
#  - 0s - loss: 0.2727 - acc: 0.8693
# Epoch 3/10
#  - 0s - loss: 0.2923 - acc: 0.8548
# Epoch 4/10
#  - 0s - loss: 0.2815 - acc: 0.8797
# Epoch 5/10
#  - 0s - loss: 0.2866 - acc: 0.8838
# Epoch 6/10
#  - 0s - loss: 0.2939 - acc: 0.8672
# Epoch 7/10
#  - 0s - loss: 0.3177 - acc: 0.8340
# Epoch 8/10
#  - 0s - loss: 0.2752 - acc: 0.8631
# Epoch 9/10
#  - 0s - loss: 0.2685 - acc: 0.8838
# Epoch 10/10
#  - 0s - loss: 0.2555 - acc: 0.8797
# Test accuracy: 0.9038461630160992
# Run :
# Epoch 1/10
#  - 1s - loss: 2.2887 - acc: 0.6083
# Epoch 2/10
#  - 0s - loss: 0.9466 - acc: 0.7021
# Epoch 3/10
#  - 0s - loss: 0.6105 - acc: 0.7458
# Epoch 4/10
#  - 0s - loss: 0.6988 - acc: 0.6917
# Epoch 5/10
#  - 0s - loss: 0.6085 - acc: 0.7375
# Epoch 6/10
#  - 0s - loss: 0.5980 - acc: 0.7375
# Epoch 7/10
#  - 0s - loss: 0.5984 - acc: 0.7354
# Epoch 8/10
#  - 0s - loss: 0.5260 - acc: 0.7875
# Epoch 9/10
#  - 0s - loss: 0.5733 - acc: 0.7542
# Epoch 10/10
#  - 0s - loss: 0.5229 - acc: 0.7521
# Test accuracy: 0.8703703703703703
# Epoch 1/10
#  - 0s - loss: 0.5483 - acc: 0.7375
# Epoch 2/10
#  - 0s - loss: 0.5693 - acc: 0.7646
# Epoch 3/10
#  - 0s - loss: 0.5241 - acc: 0.7688
# Epoch 4/10
#  - 0s - loss: 0.5167 - acc: 0.7542
# Epoch 5/10
#  - 0s - loss: 0.4960 - acc: 0.7521
# Epoch 6/10
#  - 0s - loss: 0.4936 - acc: 0.7792
# Epoch 7/10
#  - 0s - loss: 0.4874 - acc: 0.7583
# Epoch 8/10
#  - 0s - loss: 0.4775 - acc: 0.7521
# Epoch 9/10
#  - 0s - loss: 0.5089 - acc: 0.7542
# Epoch 10/10
#  - 0s - loss: 0.4487 - acc: 0.7646
# Test accuracy: 0.685185189600344
# Epoch 1/10
#  - 0s - loss: 0.6296 - acc: 0.7437
# Epoch 2/10
#  - 0s - loss: 0.4908 - acc: 0.7937
# Epoch 3/10
#  - 0s - loss: 0.5019 - acc: 0.7667
# Epoch 4/10
#  - 0s - loss: 0.4945 - acc: 0.7792
# Epoch 5/10
#  - 0s - loss: 0.4966 - acc: 0.7771
# Epoch 6/10
#  - 0s - loss: 0.4756 - acc: 0.7771
# Epoch 7/10
#  - 0s - loss: 0.5073 - acc: 0.7854
# Epoch 8/10
#  - 0s - loss: 0.4465 - acc: 0.7667
# Epoch 9/10
#  - 0s - loss: 0.4430 - acc: 0.7896
# Epoch 10/10
#  - 0s - loss: 0.4638 - acc: 0.7979
# Test accuracy: 0.7962962874659786
# Epoch 1/10
#  - 0s - loss: 0.4969 - acc: 0.8187
# Epoch 2/10
#  - 0s - loss: 0.4426 - acc: 0.7875
# Epoch 3/10
#  - 0s - loss: 0.4120 - acc: 0.8021
# Epoch 4/10
#  - 0s - loss: 0.5165 - acc: 0.7917
# Epoch 5/10
#  - 0s - loss: 0.4258 - acc: 0.8208
# Epoch 6/10
#  - 0s - loss: 0.4436 - acc: 0.8062
# Epoch 7/10
#  - 0s - loss: 0.4640 - acc: 0.8146
# Epoch 8/10
#  - 0s - loss: 0.4545 - acc: 0.8021
# Epoch 9/10
#  - 0s - loss: 0.4140 - acc: 0.8313
# Epoch 10/10
#  - 0s - loss: 0.4330 - acc: 0.8146
# Test accuracy: 0.6481481459405687
# Epoch 1/10
#  - 0s - loss: 0.5073 - acc: 0.7854
# Epoch 2/10
#  - 0s - loss: 0.5110 - acc: 0.8000
# Epoch 3/10
#  - 0s - loss: 0.4795 - acc: 0.7958
# Epoch 4/10
#  - 0s - loss: 0.4859 - acc: 0.8000
# Epoch 5/10
#  - 0s - loss: 0.4489 - acc: 0.8229
# Epoch 6/10
#  - 0s - loss: 0.4731 - acc: 0.8104
# Epoch 7/10
#  - 0s - loss: 0.4347 - acc: 0.8021
# Epoch 8/10
#  - 0s - loss: 0.4476 - acc: 0.8062
# Epoch 9/10
#  - 0s - loss: 0.4561 - acc: 0.8125
# Epoch 10/10
#  - 0s - loss: 0.4438 - acc: 0.8083
# Test accuracy: 0.8703703814082675
# Epoch 1/10
#  - 0s - loss: 0.4304 - acc: 0.8417
# ...
# Epoch 6/10
#  - 0s - loss: 0.2701 - acc: 0.8859
# Epoch 7/10
#  - 0s - loss: 0.2619 - acc: 0.8589
# Epoch 8/10
#  - 0s - loss: 0.2524 - acc: 0.8776
# Epoch 9/10
#  - 0s - loss: 0.2355 - acc: 0.8963
# Epoch 10/10
#  - 0s - loss: 0.2547 - acc: 0.8900
# Test accuracy: 0.8269230677531316
# Epoch 1/10
#  - 0s - loss: 0.3268 - acc: 0.8610
# Epoch 2/10
#  - 0s - loss: 0.3350 - acc: 0.8423
# Epoch 3/10
#  - 0s - loss: 0.3153 - acc: 0.8693
# Epoch 4/10
#  - 0s - loss: 0.2841 - acc: 0.8693
# Epoch 5/10
#  - 0s - loss: 0.2996 - acc: 0.8755
# Epoch 6/10
#  - 0s - loss: 0.2736 - acc: 0.8734
# Epoch 7/10
#  - 0s - loss: 0.2685 - acc: 0.8797
# Epoch 8/10
#  - 0s - loss: 0.2820 - acc: 0.8734
# Epoch 9/10
#  - 0s - loss: 0.2697 - acc: 0.8797
# Epoch 10/10
#  - 0s - loss: 0.2200 - acc: 0.8651
# Test accuracy: 0.9423076877227197
# Run :
# Epoch 1/10
#  - 3s - loss: 2.1572 - acc: 0.5979
# Epoch 2/10
#  - 0s - loss: 1.3630 - acc: 0.6854
# Epoch 3/10
#  - 0s - loss: 0.6441 - acc: 0.7417
# Epoch 4/10
#  - 0s - loss: 0.5571 - acc: 0.7458
# Epoch 5/10
#  - 0s - loss: 0.5429 - acc: 0.7271
# Epoch 6/10
#  - 0s - loss: 0.4187 - acc: 0.7917
# Epoch 7/10
#  - 0s - loss: 0.4589 - acc: 0.7625
# Epoch 8/10
#  - 0s - loss: 0.3926 - acc: 0.8042
# Epoch 9/10
#  - 0s - loss: 0.4193 - acc: 0.8042
# Epoch 10/10
#  - 0s - loss: 0.4366 - acc: 0.7812
# Test accuracy: 0.7037037014961243
# Epoch 1/10
#  - 0s - loss: 0.5047 - acc: 0.7729
# Epoch 2/10
#  - 0s - loss: 0.4752 - acc: 0.7917
# Epoch 3/10
#  - 0s - loss: 0.4212 - acc: 0.7854
# Epoch 4/10
#  - 0s - loss: 0.3832 - acc: 0.8083
# Epoch 5/10
#  - 0s - loss: 0.3824 - acc: 0.8125
# Epoch 6/10
#  - 0s - loss: 0.3558 - acc: 0.7833
# Epoch 7/10
#  - 0s - loss: 0.3738 - acc: 0.7979
# Epoch 8/10
#  - 0s - loss: 0.3469 - acc: 0.8229
# Epoch 9/10
#  - 0s - loss: 0.3890 - acc: 0.7917
# Epoch 10/10
#  - 0s - loss: 0.3136 - acc: 0.8312
# Test accuracy: 0.7407407407407407
# Epoch 1/10
#  - 0s - loss: 0.4221 - acc: 0.7937
# Epoch 2/10
#  - 0s - loss: 0.4079 - acc: 0.7917
# Epoch 3/10
#  - 0s - loss: 0.3575 - acc: 0.8500
# Epoch 4/10
#  - 0s - loss: 0.3315 - acc: 0.8271
# Epoch 5/10
#  - 0s - loss: 0.3067 - acc: 0.8646
# Epoch 6/10
#  - 0s - loss: 0.3067 - acc: 0.8500
# Epoch 7/10
#  - 0s - loss: 0.3628 - acc: 0.8292
# Epoch 8/10
#  - 0s - loss: 0.2823 - acc: 0.8750
# Epoch 9/10
#  - 0s - loss: 0.2594 - acc: 0.8667
# Epoch 10/10
#  - 0s - loss: 0.1990 - acc: 0.9021
# Test accuracy: 0.8518518496442724
# Epoch 1/10
#  - 0s - loss: 0.2801 - acc: 0.8729
# Epoch 2/10
#  - 0s - loss: 0.2035 - acc: 0.9250
# Epoch 3/10
#  - 0s - loss: 0.2428 - acc: 0.9042
# Epoch 4/10
#  - 0s - loss: 0.2242 - acc: 0.8917
# Epoch 5/10
#  - 0s - loss: 0.2088 - acc: 0.9062
# Epoch 6/10
#  - 0s - loss: 0.1907 - acc: 0.9271
# Epoch 7/10
#  - 0s - loss: 0.2512 - acc: 0.8958
# Epoch 8/10
#  - 0s - loss: 0.1710 - acc: 0.9312
# Epoch 9/10
#  - 0s - loss: 0.1274 - acc: 0.9500
# Epoch 10/10
#  - 0s - loss: 0.1517 - acc: 0.9375
# Test accuracy: 0.6481481481481481
# Epoch 1/10
#  - 0s - loss: 0.3257 - acc: 0.8938
# Epoch 2/10
#  - 0s - loss: 0.2574 - acc: 0.9292
# Epoch 3/10
#  - 0s - loss: 0.2643 - acc: 0.9104
# Epoch 4/10
#  - 0s - loss: 0.2306 - acc: 0.9250
# Epoch 5/10
#  - 0s - loss: 0.2118 - acc: 0.9417
# Epoch 6/10
#  - 0s - loss: 0.2049 - acc: 0.9500
# Epoch 7/10
#  - 0s - loss: 0.1974 - acc: 0.9396
# Epoch 8/10
#  - 0s - loss: 0.2033 - acc: 0.9438
# Epoch 9/10
#  - 0s - loss: 0.1490 - acc: 0.9771
# Epoch 10/10
#  - 0s - loss: 0.1514 - acc: 0.9687
# Test accuracy: 0.8518518496442724
# Epoch 1/10
#  - 0s - loss: 0.2613 - acc: 0.8917
# Epoch 2/10
#  - 0s - loss: 0.1636 - acc: 0.9417
# Epoch 3/10
#  - 0s - loss: 0.0998 - acc: 0.9729
# Epoch 4/10
#  - 0s - loss: 0.0931 - acc: 0.9771
# Epoch 5/10
#  - 0s - loss: 0.0857 - acc: 0.9750
# Epoch 6/10
#  - 0s - loss: 0.0925 - acc: 0.9625
# Epoch 7/10
#  - 0s - loss: 0.0651 - acc: 0.9875
# Epoch 8/10
#  - 0s - loss: 0.0601 - acc: 0.9854
# Epoch 9/10
#  - 0s - loss: 0.1669 - acc: 0.9250
# Epoch 10/10
#  - 0s - loss: 0.1011 - acc: 0.9708
# Test accuracy: 0.9444444444444444
# Epoch 1/10
#  - 0s - loss: 0.1626 - acc: 0.9521
# Epoch 2/10
#  - 0s - loss: 0.1277 - acc: 0.9583
# Epoch 3/10
#  - 0s - loss: 0.1370 - acc: 0.9562
# Epoch 4/10
#  - 0s - loss: 0.1078 - acc: 0.9792
# Epoch 5/10
#  - 0s - loss: 0.1678 - acc: 0.9437
# Epoch 6/10
#  - 0s - loss: 0.1396 - acc: 0.9563
# Epoch 7/10
#  - 0s - loss: 0.0994 - acc: 0.9771
# Epoch 8/10
#  - 0s - loss: 0.0761 - acc: 0.9958
# Epoch 9/10
#  - 0s - loss: 0.0897 - acc: 0.9812
# Epoch 10/10
#  - 0s - loss: 0.0969 - acc: 0.9792
# Test accuracy: 0.9814814814814815
# Epoch 1/10
#  - 0s - loss: 0.1210 - acc: 0.9751
# Epoch 2/10
#  - 0s - loss: 0.1672 - acc: 0.9419
# Epoch 3/10
#  - 0s - loss: 0.1459 - acc: 0.9564
# Epoch 4/10
#  - 0s - loss: 0.0824 - acc: 0.9896
# Epoch 5/10
#  - 0s - loss: 0.0635 - acc: 0.9938
# Epoch 6/10
#  - 0s - loss: 0.1086 - acc: 0.9606
# Epoch 7/10
#  - 0s - loss: 0.0917 - acc: 0.9834
# Epoch 8/10
#  - 0s - loss: 0.0794 - acc: 0.9896
# Epoch 9/10
#  - 0s - loss: 0.0653 - acc: 0.9896
# Epoch 10/10
#  - 0s - loss: 0.0724 - acc: 0.9855
# Test accuracy: 1.0
# Epoch 1/10
#  - 0s - loss: 0.1055 - acc: 0.9710
# Epoch 2/10
#  - 0s - loss: 0.0832 - acc: 0.9855
# Epoch 3/10
#  - 0s - loss: 0.0736 - acc: 0.9876
# Epoch 4/10
#  - 0s - loss: 0.0711 - acc: 0.9876
# Epoch 5/10
#  - 0s - loss: 0.0753 - acc: 0.9917
# Epoch 6/10
#  - 0s - loss: 0.1037 - acc: 0.9710
# Epoch 7/10
#  - 0s - loss: 0.0567 - acc: 0.9938
# Epoch 8/10
#  - 0s - loss: 0.0573 - acc: 0.9938
# Epoch 9/10
#  - 0s - loss: 0.0544 - acc: 0.9938
# Epoch 10/10
#  - 0s - loss: 0.0633 - acc: 0.9896
# Test accuracy: 0.9615384615384616
# Epoch 1/10
#  - 0s - loss: 0.1419 - acc: 0.9585
# Epoch 2/10
#  - 0s - loss: 0.0809 - acc: 0.9834
# Epoch 3/10
#  - 0s - loss: 0.0798 - acc: 0.9876
# Epoch 4/10
#  - 0s - loss: 0.0713 - acc: 0.9813
# Epoch 5/10
#  - 0s - loss: 0.0622 - acc: 0.9938
# Epoch 6/10
#  - 0s - loss: 0.0708 - acc: 0.9896
# Epoch 7/10
#  - 0s - loss: 0.0601 - acc: 0.9896
# Epoch 8/10
#  - 0s - loss: 0.0551 - acc: 0.9959
# Epoch 9/10
#  - 0s - loss: 0.0630 - acc: 0.9959
# Epoch 10/10
#  - 0s - loss: 0.0624 - acc: 0.9938
# Test accuracy: 0.9807692261842581
# Run :
# Epoch 1/10
#  - 2s - loss: 2.2784 - acc: 0.5958
# Epoch 2/10
#  - 0s - loss: 0.9652 - acc: 0.6750
# Epoch 3/10
#  - 0s - loss: 0.7075 - acc: 0.6896
# Epoch 4/10
#  - 0s - loss: 0.6588 - acc: 0.7104
# Epoch 5/10
#  - 0s - loss: 0.6729 - acc: 0.7250
# Epoch 6/10
#  - 0s - loss: 0.5984 - acc: 0.7354
# Epoch 7/10
#  - 0s - loss: 0.5584 - acc: 0.7063
# Epoch 8/10
#  - 0s - loss: 0.5811 - acc: 0.7187
# Epoch 9/10
#  - 0s - loss: 0.6308 - acc: 0.7250
# Epoch 10/10
#  - 0s - loss: 0.5747 - acc: 0.7542
# Test accuracy: 0.6851851851851852
# Epoch 1/10
#  - 0s - loss: 0.5873 - acc: 0.6979
# Epoch 2/10
#  - 0s - loss: 0.5136 - acc: 0.7292
# Epoch 3/10
#  - 0s - loss: 0.5255 - acc: 0.7354
# Epoch 4/10
#  - 0s - loss: 0.5132 - acc: 0.7167
# Epoch 5/10
#  - 0s - loss: 0.5110 - acc: 0.7417
# Epoch 6/10
#  - 0s - loss: 0.5148 - acc: 0.7354
# Epoch 7/10
#  - 0s - loss: 0.4968 - acc: 0.7271
# Epoch 8/10
#  - 0s - loss: 0.5453 - acc: 0.7312
# Epoch 9/10
#  - 0s - loss: 0.4853 - acc: 0.7500
# Epoch 10/10
#  - 0s - loss: 0.5189 - acc: 0.7167
# Test accuracy: 0.7592592504289415
# Epoch 1/10
#  - 0s - loss: 0.5378 - acc: 0.7333
# Epoch 2/10
#  - 0s - loss: 0.6210 - acc: 0.7417
# Epoch 3/10
#  - 0s - loss: 0.5229 - acc: 0.7312
# Epoch 4/10
#  - 0s - loss: 0.5338 - acc: 0.7458
# Epoch 5/10
#  - 0s - loss: 0.5121 - acc: 0.7500
# Epoch 6/10
#  - 0s - loss: 0.5289 - acc: 0.7188
# Epoch 7/10
#  - 0s - loss: 0.4625 - acc: 0.7667
# Epoch 8/10
#  - 0s - loss: 0.4984 - acc: 0.7521
# Epoch 9/10
#  - 0s - loss: 0.4671 - acc: 0.7750
# Epoch 10/10
#  - 0s - loss: 0.5337 - acc: 0.7771
# Test accuracy: 0.8333333311257539
# Epoch 1/10
#  - 0s - loss: 0.4708 - acc: 0.8042
# Epoch 2/10
#  - 0s - loss: 0.4066 - acc: 0.8229
# Epoch 3/10
#  - 0s - loss: 0.4372 - acc: 0.7875
# Epoch 4/10
#  - 0s - loss: 0.4834 - acc: 0.8104
# Epoch 5/10
#  - 0s - loss: 0.4464 - acc: 0.7875
# Epoch 6/10
#  - 0s - loss: 0.4048 - acc: 0.8292
# Epoch 7/10
#  - 0s - loss: 0.3797 - acc: 0.8292
# Epoch 8/10
#  - 0s - loss: 0.3971 - acc: 0.8417
# Epoch 9/10
#  - 0s - loss: 0.3681 - acc: 0.8313
# Epoch 10/10
#  - 0s - loss: 0.4429 - acc: 0.8125
# Test accuracy: 0.7222222200146428
# Epoch 1/10
#  - 0s - loss: 0.4613 - acc: 0.8146
# Epoch 2/10
#  - 0s - loss: 0.4822 - acc: 0.7937
# Epoch 3/10
#  - 0s - loss: 0.4850 - acc: 0.8167
# Epoch 4/10
#  - 0s - loss: 0.4510 - acc: 0.8125
# Epoch 5/10
#  - 0s - loss: 0.4631 - acc: 0.8125
# Epoch 6/10
#  - 0s - loss: 0.4369 - acc: 0.8188
# Epoch 7/10
#  - 0s - loss: 0.3897 - acc: 0.8250
# Epoch 8/10
#  - 0s - loss: 0.4501 - acc: 0.8125
# Epoch 9/10
#  - 0s - loss: 0.4108 - acc: 0.8458
# Epoch 10/10
#  - 0s - loss: 0.3817 - acc: 0.8479
# Test accuracy: 0.851851862889749
# Epoch 1/10
#  - 0s - loss: 0.4698 - acc: 0.8458
# Epoch 2/10
#  - 0s - loss: 0.4626 - acc: 0.8000
# Epoch 3/10
#  - 0s - loss: 0.3685 - acc: 0.8354
# Epoch 4/10
#  - 0s - loss: 0.3593 - acc: 0.8271
# Epoch 5/10
#  - 0s - loss: 0.3790 - acc: 0.8271
# Epoch 6/10
#  - 0s - loss: 0.3224 - acc: 0.8604
# Epoch 7/10
#  - 0s - loss: 0.3522 - acc: 0.8562
# Epoch 8/10
#  - 0s - loss: 0.3666 - acc: 0.8583
# Epoch 9/10
#  - 0s - loss: 0.3240 - acc: 0.8771
# Epoch 10/10
#  - 0s - loss: 0.3459 - acc: 0.8521
# Test accuracy: 0.7962962874659786
# Epoch 1/10
#  - 0s - loss: 0.3609 - acc: 0.8646
# Epoch 2/10
#  - 0s - loss: 0.3340 - acc: 0.8604
# Epoch 3/10
#  - 0s - loss: 0.3149 - acc: 0.8562
# Epoch 4/10
#  - 0s - loss: 0.3241 - acc: 0.8521
# Epoch 5/10
#  - 0s - loss: 0.3069 - acc: 0.8688
# Epoch 6/10
#  - 0s - loss: 0.2800 - acc: 0.8833
# Epoch 7/10
#  - 0s - loss: 0.3378 - acc: 0.8604
# Epoch 8/10
#  - 0s - loss: 0.3062 - acc: 0.8667
# Epoch 9/10
#  - 0s - loss: 0.2794 - acc: 0.8854
# Epoch 10/10
#  - 0s - loss: 0.2457 - acc: 0.8958
# Test accuracy: 0.9074074007846691
# Epoch 1/10
#  - 0s - loss: 0.3435 - acc: 0.8838
# Epoch 2/10
#  - 0s - loss: 0.3349 - acc: 0.8672
# Epoch 3/10
#  - 0s - loss: 0.3003 - acc: 0.8880
# Epoch 4/10
#  - 0s - loss: 0.2885 - acc: 0.8838
# Epoch 5/10
#  - 0s - loss: 0.2866 - acc: 0.9004
# Epoch 6/10
#  - 0s - loss: 0.2633 - acc: 0.9108
# Epoch 7/10
#  - 0s - loss: 0.2771 - acc: 0.8817
# Epoch 8/10
#  - 0s - loss: 0.2793 - acc: 0.8838
# Epoch 9/10
#  - 0s - loss: 0.2090 - acc: 0.9253
# Epoch 10/10
#  - 0s - loss: 0.2410 - acc: 0.9046
# Test accuracy: 0.8269230769230769
# Epoch 1/10
#  - 0s - loss: 0.2750 - acc: 0.8859
# Epoch 2/10
#  - 0s - loss: 0.2300 - acc: 0.9025
# Epoch 3/10
#  - 0s - loss: 0.2222 - acc: 0.9295
# Epoch 4/10
#  - 0s - loss: 0.2007 - acc: 0.9108
# Epoch 5/10
#  - 0s - loss: 0.1971 - acc: 0.9232
# Epoch 6/10
#  - 0s - loss: 0.2149 - acc: 0.9108
# Epoch 7/10
#  - 0s - loss: 0.2165 - acc: 0.9087
# Epoch 8/10
#  - 0s - loss: 0.2082 - acc: 0.9129
# Epoch 9/10
#  - 0s - loss: 0.2363 - acc: 0.9149
# Epoch 10/10
#  - 0s - loss: 0.1480 - acc: 0.9440
# Test accuracy: 0.8846153754454392
# Epoch 1/10
#  - 0s - loss: 0.2638 - acc: 0.9004
# Epoch 2/10
#  - 0s - loss: 0.2354 - acc: 0.9025
# Epoch 3/10
#  - 0s - loss: 0.2485 - acc: 0.9087
# Epoch 4/10
#  - 0s - loss: 0.2313 - acc: 0.8942
# Epoch 5/10
#  - 0s - loss: 0.2108 - acc: 0.9212
# Epoch 6/10
#  - 0s - loss: 0.2213 - acc: 0.9170
# Epoch 7/10
#  - 0s - loss: 0.1663 - acc: 0.9253
# Epoch 8/10
#  - 0s - loss: 0.1948 - acc: 0.9066
# Epoch 9/10
#  - 0s - loss: 0.1779 - acc: 0.9336
# Epoch 10/10
#  - 0s - loss: 0.1417 - acc: 0.9440
# Test accuracy: 0.9615384615384616
# Run :
# Epoch 1/10
#  - 3s - loss: 1.5784 - acc: 0.5937
# Epoch 2/10
#  - 0s - loss: 0.8452 - acc: 0.7083
# Epoch 3/10
#  - 0s - loss: 0.6212 - acc: 0.7104
# Epoch 4/10
#  - 0s - loss: 0.5454 - acc: 0.7312
# Epoch 5/10
#  - 0s - loss: 0.5257 - acc: 0.7875
# Epoch 6/10
#  - 0s - loss: 0.4988 - acc: 0.7750
# Epoch 7/10
#  - 0s - loss: 0.4876 - acc: 0.7771
# Epoch 8/10
#  - 0s - loss: 0.4755 - acc: 0.7792
# Epoch 9/10
#  - 0s - loss: 0.4904 - acc: 0.7687
# Epoch 10/10
#  - 0s - loss: 0.4631 - acc: 0.7896
# Test accuracy: 0.7222222266373811
# Epoch 1/10
#  - 0s - loss: 0.4944 - acc: 0.7938
# Epoch 2/10
#  - 0s - loss: 0.4379 - acc: 0.8042
# Epoch 3/10
#  - 0s - loss: 0.4700 - acc: 0.8083
# Epoch 4/10
#  - 0s - loss: 0.4786 - acc: 0.7646
# Epoch 5/10
#  - 0s - loss: 0.4415 - acc: 0.8146
# Epoch 6/10
#  - 0s - loss: 0.4286 - acc: 0.8021
# Epoch 7/10
#  - 0s - loss: 0.3975 - acc: 0.7979
# Epoch 8/10
#  - 0s - loss: 0.4058 - acc: 0.8062
# Epoch 9/10
#  - 0s - loss: 0.4182 - acc: 0.8146
# Epoch 10/10
#  - 0s - loss: 0.4260 - acc: 0.8104
# Test accuracy: 0.7592592504289415
# Epoch 1/10
#  - 0s - loss: 0.4693 - acc: 0.7979
# Epoch 2/10
#  - 0s - loss: 0.4538 - acc: 0.7958
# Epoch 3/10
#  - 0s - loss: 0.4629 - acc: 0.8104
# Epoch 4/10
#  - 0s - loss: 0.4864 - acc: 0.8062
# Epoch 5/10
#  - 0s - loss: 0.4562 - acc: 0.7958
# Epoch 6/10
#  - 0s - loss: 0.4161 - acc: 0.8083
# Epoch 7/10
#  - 0s - loss: 0.3824 - acc: 0.8146
# Epoch 8/10
#  - 0s - loss: 0.3832 - acc: 0.8250
# Epoch 9/10
#  - 0s - loss: 0.3839 - acc: 0.8167
# Epoch 10/10
#  - 0s - loss: 0.4154 - acc: 0.7979
# Test accuracy: 0.8148148059844971
# Epoch 1/10
#  - 0s - loss: 0.3993 - acc: 0.8354
# Epoch 2/10
#  - 0s - loss: 0.3597 - acc: 0.8313
# Epoch 3/10
#  - 0s - loss: 0.3688 - acc: 0.8417
# Epoch 4/10
#  - 0s - loss: 0.3350 - acc: 0.8437
# Epoch 5/10
#  - 0s - loss: 0.3402 - acc: 0.8417
# Epoch 6/10
#  - 0s - loss: 0.3836 - acc: 0.8208
# Epoch 7/10
#  - 0s - loss: 0.3342 - acc: 0.8417
# Epoch 8/10
#  - 0s - loss: 0.3424 - acc: 0.8396
# Epoch 9/10
#  - 0s - loss: 0.3124 - acc: 0.8375
# Epoch 10/10
#  - 0s - loss: 0.2993 - acc: 0.8583
# Test accuracy: 0.6666666644590872
# Epoch 1/10
#  - 0s - loss: 0.4143 - acc: 0.8333
# Epoch 2/10
#  - 0s - loss: 0.4048 - acc: 0.8208
# Epoch 3/10
#  - 0s - loss: 0.3990 - acc: 0.8313
# Epoch 4/10
#  - 0s - loss: 0.4203 - acc: 0.8146
# Epoch 5/10
#  - 0s - loss: 0.4272 - acc: 0.8479
# Epoch 6/10
#  - 0s - loss: 0.3774 - acc: 0.8438
# Epoch 7/10
#  - 0s - loss: 0.3691 - acc: 0.8354
# Epoch 8/10
#  - 0s - loss: 0.3712 - acc: 0.8375
# Epoch 9/10
#  - 0s - loss: 0.3412 - acc: 0.8667
# Epoch 10/10
#  - 0s - loss: 0.3176 - acc: 0.8687
# Test accuracy: 0.8518518452291135
# Epoch 1/10
#  - 0s - loss: 0.3782 - acc: 0.8396
# Epoch 2/10
#  - 0s - loss: 0.3169 - acc: 0.8479
# Epoch 3/10
#  - 0s - loss: 0.2971 - acc: 0.8417
# Epoch 4/10
#  - 0s - loss: 0.2762 - acc: 0.8708
# Epoch 5/10
#  - 0s - loss: 0.3098 - acc: 0.8542
# Epoch 6/10
#  - 0s - loss: 0.3040 - acc: 0.8417
# Epoch 7/10
#  - 0s - loss: 0.2701 - acc: 0.8604
# Epoch 8/10
#  - 0s - loss: 0.2811 - acc: 0.8729
# Epoch 9/10
#  - 0s - loss: 0.2807 - acc: 0.8563
# Epoch 10/10
#  - 0s - loss: 0.2610 - acc: 0.8729
# Test accuracy: 0.8888888999267861
# Epoch 1/10
#  - 0s - loss: 0.3139 - acc: 0.8646
# Epoch 2/10
#  - 0s - loss: 0.3023 - acc: 0.8792
# Epoch 3/10
#  - 0s - loss: 0.3074 - acc: 0.8813
# Epoch 4/10
#  - 0s - loss: 0.2873 - acc: 0.8813
# Epoch 5/10
#  - 0s - loss: 0.2976 - acc: 0.8875
# Epoch 6/10
#  - 0s - loss: 0.2786 - acc: 0.8813
# Epoch 7/10
#  - 0s - loss: 0.2667 - acc: 0.8917
# Epoch 8/10
#  - 0s - loss: 0.2724 - acc: 0.8854
# Epoch 9/10
#  - 0s - loss: 0.2798 - acc: 0.8813
# Epoch 10/10
#  - 0s - loss: 0.2442 - acc: 0.9000
# Test accuracy: 0.851851862889749
# Epoch 1/10
#  - 0s - loss: 0.2964 - acc: 0.8776
# Epoch 2/10
#  - 0s - loss: 0.3027 - acc: 0.8714
# Epoch 3/10
#  - 0s - loss: 0.2973 - acc: 0.8859
# Epoch 4/10
#  - 0s - loss: 0.2802 - acc: 0.8838
# Epoch 5/10
#  - 0s - loss: 0.2677 - acc: 0.8838
# Epoch 6/10
#  - 0s - loss: 0.2510 - acc: 0.9025
# Epoch 7/10
#  - 0s - loss: 0.2428 - acc: 0.8983
# Epoch 8/10
#  - 0s - loss: 0.2573 - acc: 0.8963
# Epoch 9/10
#  - 0s - loss: 0.2477 - acc: 0.8859
# Epoch 10/10
#  - 0s - loss: 0.2556 - acc: 0.9046
# Test accuracy: 0.8653846062146701
# Epoch 1/10
#  - 0s - loss: 0.2653 - acc: 0.8900
# Epoch 2/10
#  - 0s - loss: 0.2534 - acc: 0.8880
# Epoch 3/10
#  - 0s - loss: 0.2590 - acc: 0.9087
# Epoch 4/10
#  - 0s - loss: 0.2439 - acc: 0.9129
# Epoch 5/10
#  - 0s - loss: 0.2409 - acc: 0.8880
# Epoch 6/10
#  - 0s - loss: 0.2604 - acc: 0.8921
# Epoch 7/10
#  - 0s - loss: 0.2211 - acc: 0.9087
# Epoch 8/10
#  - 0s - loss: 0.2128 - acc: 0.9087
# Epoch 9/10
#  - 0s - loss: 0.2221 - acc: 0.9191
# Epoch 10/10
#  - 0s - loss: 0.1974 - acc: 0.9295
# Test accuracy: 0.9038461538461539
# Epoch 1/10
#  - 0s - loss: 0.2725 - acc: 0.8983
# Epoch 2/10
#  - 0s - loss: 0.2445 - acc: 0.9046
# Epoch 3/10
#  - 0s - loss: 0.2707 - acc: 0.8859
# Epoch 4/10
#  - 0s - loss: 0.2531 - acc: 0.8983
# Epoch 5/10
#  - 0s - loss: 0.2584 - acc: 0.8983
# Epoch 6/10
#  - 0s - loss: 0.2306 - acc: 0.9087
# Epoch 7/10
#  - 0s - loss: 0.2260 - acc: 0.9046
# Epoch 8/10
#  - 0s - loss: 0.2479 - acc: 0.8983
# Epoch 9/10
#  - 0s - loss: 0.2163 - acc: 0.9149
# Epoch 10/10
#  - 0s - loss: 0.2206 - acc: 0.9149
# Test accuracy: 0.9615384615384616
# Time on optimization: 15.38204673131307 minutes
#
# Summary of the best model: -----------------------
# {'acc': 0.8866809116809117, 'auc': 0.9428279802923678, 'conv1': 64, 'dense1': 128, 'dense2': 32, 'drop1': 0.04405684447985118, 'drop2': 0.1491796394828513}
# Conv 1: 64 unidades
# Dense 1: 128 unidades
# Dense 2: 32 unidades
# Dropout 1: 0.04405684447985118
# Dropout 2: 0.1491796394828513
