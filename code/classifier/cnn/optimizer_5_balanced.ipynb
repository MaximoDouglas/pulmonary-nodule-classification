# %% [markdown]
# # Colab config

# %%
from google.colab import drive
drive.mount('drive', force_remount=True)

# %%
# !pip install hyperas

# %% [markdown]
# ## Imports

# %%
import os

import time

import gc

import numpy as np

from scipy import interp

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, roc_curve, auc

from keras import backend as K
from keras import optimizers
from keras.layers import Conv3D, MaxPool3D, Flatten, Dense, Dropout, Input
from keras.losses import binary_crossentropy
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.utils.vis_utils import plot_model, model_to_dot

# %% [markdown]
# ## GPU configuration

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 1
set_session(tf.Session(config=config))
session = tf.Session(config=config)

# %% [markdown]
# # Hyperparameters optimization
#
# Func **data()** required by Hyperas. It must return 4 arrays X_train, Y_train, X_test, Y_test.
#
# The data for optimization are on four numpy files, generated with the notebook **import_images.ipynb**.

# %%
'''5-balanced'''

def data():
  prefix = "/content/drive/My Drive/Pesquisa - Dicom images/data"
  X_train = np.load(prefix + "/nps/solid-nodules/data-5-balanced/X_train.npy")
  X_test = np.load(prefix + "/nps/solid-nodules/data-5-balanced/X_test.npy")
  Y_train = np.load(prefix + "/nps/solid-nodules/data-5-balanced/Y_train.npy")
  Y_test = np.load(prefix + "/nps/solid-nodules/data-5-balanced/Y_test.npy")
  
  return X_train, Y_train, X_test, Y_test

# %% [markdown]
# ## Space of search definition
#
# * **conv_layer1**: [32, 48, 64, 96] unities
# * **dense_layer1**: [32, 64, 128, 256] unities
# * **dense_layer2**: [8, 16, 24, 32] unities
# * **dropout** on dense layers: between 0 and 0.5

# %%
conv1 = [32, 48, 64, 96]
dense1 = [64, 96, 128]
dense2 = [16, 24, 32]
    
def model(X_train, Y_train, X_test, Y_test):
    conv1 = {{choice([32, 48, 64, 96])}}
    dense1 = {{choice([32, 64, 128])}}
    dense2 = {{choice([16, 24, 32])}}
    
    input_layer = Input(X_train.shape[1:5])
    
    conv_layer1 = Conv3D(conv1, kernel_size=(3, 3, 3), activation='relu')(input_layer)
    pooling_layer1 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer1)
    
    flatten_layer = Flatten()(pooling_layer1)
    
    dense_layer1 = Dense(dense1, activation='relu')(flatten_layer)
    dense_layer1 = Dropout({{uniform(0, .5)}})(dense_layer1)
    
    dense_layer2 = Dense(dense2, activation='relu')(dense_layer1)
    dense_layer2 = Dropout({{uniform(0, .5)}})(dense_layer2)
    
    output_layer = Dense(units=1, activation='sigmoid')(dense_layer2)
    
    model = Model(inputs=input_layer, outputs=output_layer)
    
    opt = optimizers.RMSprop(lr=0.0001)
    
    model.compile(loss=binary_crossentropy, optimizer=opt, metrics=['acc'])
    
    model.fit(X_train, Y_train,
              batch_size=128,
              epochs=10,
              verbose=2,
              validation_data=(X_test, Y_test)
              )
    
    score, acc = model.evaluate(X_test, Y_test, verbose=0)
    
    print('Test accuracy:', acc)
    
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %% [markdown]
# ## Otimization

# %%
X_train, Y_train, X_test, Y_test = data()

start = time.time()

best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=30,
                                      trials=Trials(),
                                      verbose=False,
                                      notebook_name='drive/My Drive/Pesquisa - Dicom images/notebooks/optimizer_5_balanced')
end = time.time()

print("Time on optimization:", (end - start)/60, "minutos")

print()
print('Summary of the best model: -----------------------')

print("Evalutation of best performing model:")
print(best_model.evaluate(X_test, Y_test))

print(best_model.summary())

c1 = conv1[best_run['conv1']]
d1 = dense1[best_run['dense1']]
d2 = dense2[best_run['dense2']]
drop1 = best_run['Dropout']
drop2 = best_run['Dropout_1']

print('Conv 1:', c1, 'unidades')
print('Dense 1:', d1, 'unidades')
print('Dense 2:', d2, 'unidades')
print('Dropout 1:', drop1)
print('Dropout 2:', drop2)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.8543 - acc: 0.6994 - val_loss: 0.3992 - val_acc: 0.8200
#
# Epoch 2/10
#  - 3s - loss: 0.6105 - acc: 0.7209 - val_loss: 0.4679 - val_acc: 0.7700
#
# Epoch 3/10
#  - 3s - loss: 0.5742 - acc: 0.7368 - val_loss: 0.4508 - val_acc: 0.8100
#
# Epoch 4/10
#  - 3s - loss: 0.5429 - acc: 0.7685 - val_loss: 0.4632 - val_acc: 0.7700
#
# Epoch 5/10
#  - 3s - loss: 0.5403 - acc: 0.7759 - val_loss: 0.4386 - val_acc: 0.8300
#
# Epoch 6/10
#  - 3s - loss: 0.5363 - acc: 0.7777 - val_loss: 0.4157 - val_acc: 0.8000
#
# Epoch 7/10
#  - 3s - loss: 0.5139 - acc: 0.7857 - val_loss: 0.4196 - val_acc: 0.8200
#
# Epoch 8/10
#  - 3s - loss: 0.5005 - acc: 0.7866 - val_loss: 0.4227 - val_acc: 0.8400
#
# Epoch 9/10
#  - 3s - loss: 0.4846 - acc: 0.7869 - val_loss: 0.4388 - val_acc: 0.8000
#
# Epoch 10/10
#  - 3s - loss: 0.4737 - acc: 0.7908 - val_loss: 0.4697 - val_acc: 0.8200
#
# Test accuracy:
# 0.82
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.7465 - acc: 0.7035 - val_loss: 0.5314 - val_acc: 0.8100
#
# Epoch 2/10
#  - 4s - loss: 0.5684 - acc: 0.7490 - val_loss: 0.4148 - val_acc: 0.7800
#
# Epoch 3/10
#  - 4s - loss: 0.5316 - acc: 0.7650 - val_loss: 0.4796 - val_acc: 0.7600
#
# Epoch 4/10
#  - 4s - loss: 0.5120 - acc: 0.7772 - val_loss: 0.5012 - val_acc: 0.8000
#
# Epoch 5/10
#  - 4s - loss: 0.4946 - acc: 0.7712 - val_loss: 0.4498 - val_acc: 0.7900
#
# Epoch 6/10
#  - 4s - loss: 0.4688 - acc: 0.7813 - val_loss: 0.5036 - val_acc: 0.7800
#
# Epoch 7/10
#  - 4s - loss: 0.4647 - acc: 0.7844 - val_loss: 0.4563 - val_acc: 0.8000
#
# Epoch 8/10
#  - 4s - loss: 0.4478 - acc: 0.7995 - val_loss: 0.4612 - val_acc: 0.7800
#
# Epoch 9/10
#  - 4s - loss: 0.4330 - acc: 0.8002 - val_loss: 0.4810 - val_acc: 0.8000
#
# Epoch 10/10
#  - 4s - loss: 0.4235 - acc: 0.8034 - val_loss: 0.4960 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 1.0128 - acc: 0.6915 - val_loss: 0.4624 - val_acc: 0.7800
#
# Epoch 2/10
#  - 5s - loss: 0.6156 - acc: 0.7267 - val_loss: 0.4125 - val_acc: 0.7500
#
# Epoch 3/10
#  - 5s - loss: 0.5637 - acc: 0.7519 - val_loss: 0.4605 - val_acc: 0.7900
#
# Epoch 4/10
#  - 5s - loss: 0.5491 - acc: 0.7673 - val_loss: 0.4524 - val_acc: 0.7900
#
# Epoch 5/10
#  - 5s - loss: 0.5104 - acc: 0.7715 - val_loss: 0.4282 - val_acc: 0.8100
#
# Epoch 6/10
#  - 5s - loss: 0.4859 - acc: 0.7809 - val_loss: 0.4265 - val_acc: 0.8100
#
# Epoch 7/10
#  - 5s - loss: 0.4812 - acc: 0.7814 - val_loss: 0.4803 - val_acc: 0.7800
#
# Epoch 8/10
#  - 5s - loss: 0.4702 - acc: 0.7954 - val_loss: 0.4747 - val_acc: 0.8300
#
# Epoch 9/10
#  - 5s - loss: 0.4540 - acc: 0.7981 - val_loss: 0.4597 - val_acc: 0.8400
#
# Epoch 10/10
#  - 5s - loss: 0.4289 - acc: 0.8032 - val_loss: 0.4631 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.9183 - acc: 0.7262 - val_loss: 0.4160 - val_acc: 0.8300
#
# Epoch 2/10
#  - 4s - loss: 0.5621 - acc: 0.7565 - val_loss: 0.4865 - val_acc: 0.8100
#
# Epoch 3/10
#  - 4s - loss: 0.5441 - acc: 0.7740 - val_loss: 0.4693 - val_acc: 0.7600
#
# Epoch 4/10
#  - 4s - loss: 0.5120 - acc: 0.7758 - val_loss: 0.4410 - val_acc: 0.7800
#
# Epoch 5/10
#  - 4s - loss: 0.4831 - acc: 0.7866 - val_loss: 0.5015 - val_acc: 0.8100
#
# Epoch 6/10
#  - 4s - loss: 0.4961 - acc: 0.7896 - val_loss: 0.5758 - val_acc: 0.7700
#
# Epoch 7/10
#  - 4s - loss: 0.4713 - acc: 0.7976 - val_loss: 0.5172 - val_acc: 0.7600
#
# Epoch 8/10
#  - 4s - loss: 0.4549 - acc: 0.8011 - val_loss: 0.5559 - val_acc: 0.7800
#
# Epoch 9/10
#  - 4s - loss: 0.4551 - acc: 0.7976 - val_loss: 0.4621 - val_acc: 0.8100
#
# Epoch 10/10
#  - 4s - loss: 0.4429 - acc: 0.8112 - val_loss: 0.4776 - val_acc: 0.8200
#
# Test accuracy:
# 0.82
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 9s - loss: 0.7675 - acc: 0.7453 - val_loss: 0.5562 - val_acc: 0.7600
#
# Epoch 2/10
#  - 8s - loss: 0.4662 - acc: 0.7772 - val_loss: 1.1036 - val_acc: 0.7300
#
# Epoch 3/10
#  - 8s - loss: 0.4486 - acc: 0.7814 - val_loss: 0.4794 - val_acc: 0.8000
#
# Epoch 4/10
#  - 8s - loss: 0.4289 - acc: 0.7970 - val_loss: 0.5173 - val_acc: 0.7500
#
# Epoch 5/10
#  - 8s - loss: 0.4162 - acc: 0.8062 - val_loss: 0.5281 - val_acc: 0.7600
#
# Epoch 6/10
#  - 8s - loss: 0.4032 - acc: 0.8101 - val_loss: 0.4197 - val_acc: 0.8400
#
# Epoch 7/10
#  - 8s - loss: 0.3894 - acc: 0.8105 - val_loss: 0.5070 - val_acc: 0.8300
#
# Epoch 8/10
#  - 8s - loss: 0.3788 - acc: 0.8147 - val_loss: 0.4835 - val_acc: 0.8000
#
# Epoch 9/10
#  - 8s - loss: 0.3652 - acc: 0.8266 - val_loss: 0.5135 - val_acc: 0.8100
#
# Epoch 10/10
#  - 8s - loss: 0.3526 - acc: 0.8287 - val_loss: 0.5246 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 1.2223 - acc: 0.7271 - val_loss: 0.4879 - val_acc: 0.8100
#
# Epoch 2/10
#  - 5s - loss: 0.6689 - acc: 0.7485 - val_loss: 0.4432 - val_acc: 0.7900
#
# Epoch 3/10
#  - 5s - loss: 0.6138 - acc: 0.7623 - val_loss: 0.4666 - val_acc: 0.7900
#
# Epoch 4/10
#  - 5s - loss: 0.5731 - acc: 0.7740 - val_loss: 0.4275 - val_acc: 0.8200
#
# Epoch 5/10
#  - 5s - loss: 0.5578 - acc: 0.7726 - val_loss: 0.4350 - val_acc: 0.7800
#
# Epoch 6/10
#  - 5s - loss: 0.5217 - acc: 0.7910 - val_loss: 0.5089 - val_acc: 0.7600
#
# Epoch 7/10
#  - 5s - loss: 0.5008 - acc: 0.7885 - val_loss: 0.4478 - val_acc: 0.7800
#
# Epoch 8/10
#  - 5s - loss: 0.4936 - acc: 0.7868 - val_loss: 0.4351 - val_acc: 0.7900
#
# Epoch 9/10
#  - 5s - loss: 0.4936 - acc: 0.7905 - val_loss: 0.5058 - val_acc: 0.8100
#
# Epoch 10/10
#  - 5s - loss: 0.4689 - acc: 0.7999 - val_loss: 0.4714 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.7130 - acc: 0.7152 - val_loss: 0.8455 - val_acc: 0.8000
#
# Epoch 2/10
#  - 5s - loss: 0.5949 - acc: 0.7515 - val_loss: 0.5111 - val_acc: 0.7500
#
# Epoch 3/10
#  - 5s - loss: 0.5425 - acc: 0.7589 - val_loss: 0.5184 - val_acc: 0.7400
#
# Epoch 4/10
#  - 5s - loss: 0.5251 - acc: 0.7630 - val_loss: 0.4247 - val_acc: 0.8100
#
# Epoch 5/10
#  - 5s - loss: 0.5015 - acc: 0.7721 - val_loss: 0.4859 - val_acc: 0.7800
#
# Epoch 6/10
#  - 5s - loss: 0.4826 - acc: 0.7775 - val_loss: 0.4403 - val_acc: 0.7900
#
# Epoch 7/10
#  - 5s - loss: 0.4725 - acc: 0.7802 - val_loss: 0.4385 - val_acc: 0.7700
#
# Epoch 8/10
#  - 5s - loss: 0.4555 - acc: 0.7860 - val_loss: 0.4443 - val_acc: 0.7700
#
# Epoch 9/10
#  - 5s - loss: 0.4482 - acc: 0.7857 - val_loss: 0.5586 - val_acc: 0.7400
#
# Epoch 10/10
#  - 5s - loss: 0.4397 - acc: 0.7914 - val_loss: 0.4581 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 9s - loss: 0.8582 - acc: 0.7465 - val_loss: 0.5430 - val_acc: 0.7700
#
# Epoch 2/10
#  - 8s - loss: 0.5036 - acc: 0.7715 - val_loss: 0.4285 - val_acc: 0.8400
#
# Epoch 3/10
#  - 8s - loss: 0.4604 - acc: 0.7844 - val_loss: 0.4323 - val_acc: 0.7400
#
# Epoch 4/10
#  - 8s - loss: 0.4455 - acc: 0.7938 - val_loss: 0.9001 - val_acc: 0.5400
#
# Epoch 5/10
#  - 8s - loss: 0.4283 - acc: 0.8002 - val_loss: 0.4451 - val_acc: 0.7300
#
# Epoch 6/10
#  - 8s - loss: 0.4031 - acc: 0.8084 - val_loss: 0.4582 - val_acc: 0.7900
#
# Epoch 7/10
#  - 8s - loss: 0.3788 - acc: 0.8185 - val_loss: 0.4989 - val_acc: 0.7900
#
# Epoch 8/10
#  - 8s - loss: 0.3580 - acc: 0.8271 - val_loss: 0.4718 - val_acc: 0.7600
#
# Epoch 9/10
#  - 8s - loss: 0.3500 - acc: 0.8362 - val_loss: 0.4625 - val_acc: 0.7600
#
# Epoch 10/10
#  - 8s - loss: 0.3249 - acc: 0.8463 - val_loss: 0.6257 - val_acc: 0.7200
#
# Test accuracy:
# 0.72
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.6819 - acc: 0.7368 - val_loss: 0.4611 - val_acc: 0.7600
#
# Epoch 2/10
#  - 5s - loss: 0.5107 - acc: 0.7788 - val_loss: 0.4729 - val_acc: 0.8100
#
# Epoch 3/10
#  - 5s - loss: 0.4841 - acc: 0.7868 - val_loss: 0.4632 - val_acc: 0.7900
#
# Epoch 4/10
#  - 5s - loss: 0.4570 - acc: 0.7912 - val_loss: 0.4620 - val_acc: 0.8200
#
# Epoch 5/10
#  - 5s - loss: 0.4318 - acc: 0.7953 - val_loss: 0.4840 - val_acc: 0.8000
#
# Epoch 6/10
#  - 5s - loss: 0.4182 - acc: 0.8034 - val_loss: 0.4186 - val_acc: 0.8100
#
# Epoch 7/10
#  - 5s - loss: 0.4137 - acc: 0.8023 - val_loss: 0.4776 - val_acc: 0.8000
#
# Epoch 8/10
#  - 5s - loss: 0.3980 - acc: 0.8121 - val_loss: 0.4363 - val_acc: 0.8100
#
# Epoch 9/10
#  - 5s - loss: 0.3897 - acc: 0.8098 - val_loss: 0.4223 - val_acc: 0.8300
#
# Epoch 10/10
#  - 5s - loss: 0.3716 - acc: 0.8204 - val_loss: 0.4187 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 8s - loss: 0.7309 - acc: 0.7380 - val_loss: 0.4631 - val_acc: 0.7300
#
# Epoch 2/10
#  - 8s - loss: 0.4856 - acc: 0.7722 - val_loss: 0.4658 - val_acc: 0.7900
#
# Epoch 3/10
#  - 8s - loss: 0.4564 - acc: 0.7868 - val_loss: 0.4663 - val_acc: 0.8000
#
# Epoch 4/10
#  - 8s - loss: 0.4441 - acc: 0.7961 - val_loss: 0.4626 - val_acc: 0.8200
#
# Epoch 5/10
#  - 8s - loss: 0.4356 - acc: 0.7947 - val_loss: 0.4910 - val_acc: 0.7800
#
# Epoch 6/10
#  - 8s - loss: 0.4249 - acc: 0.7990 - val_loss: 0.5746 - val_acc: 0.7800
#
# Epoch 7/10
#  - 8s - loss: 0.4133 - acc: 0.8087 - val_loss: 0.5458 - val_acc: 0.7800
#
# Epoch 8/10
#  - 8s - loss: 0.4084 - acc: 0.8107 - val_loss: 0.5123 - val_acc: 0.7900
#
# Epoch 9/10
#  - 8s - loss: 0.4049 - acc: 0.8158 - val_loss: 0.4737 - val_acc: 0.7800
#
# Epoch 10/10
#  - 8s - loss: 0.3973 - acc: 0.8124 - val_loss: 0.4185 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 1.0845 - acc: 0.7340 - val_loss: 0.4497 - val_acc: 0.6900
#
# Epoch 2/10
#  - 5s - loss: 0.5862 - acc: 0.7465 - val_loss: 0.4939 - val_acc: 0.7600
#
# Epoch 3/10
#  - 5s - loss: 0.5390 - acc: 0.7593 - val_loss: 0.4950 - val_acc: 0.7800
#
# Epoch 4/10
#  - 5s - loss: 0.5104 - acc: 0.7827 - val_loss: 0.4657 - val_acc: 0.7900
#
# Epoch 5/10
#  - 5s - loss: 0.4734 - acc: 0.7798 - val_loss: 0.4717 - val_acc: 0.7800
#
# Epoch 6/10
#  - 5s - loss: 0.4576 - acc: 0.7922 - val_loss: 0.4724 - val_acc: 0.8000
#
# Epoch 7/10
#  - 5s - loss: 0.4327 - acc: 0.8057 - val_loss: 0.5574 - val_acc: 0.8000
#
# Epoch 8/10
#  - 5s - loss: 0.4334 - acc: 0.7981 - val_loss: 0.4186 - val_acc: 0.7900
#
# Epoch 9/10
#  - 5s - loss: 0.4051 - acc: 0.8190 - val_loss: 0.5012 - val_acc: 0.7700
#
# Epoch 10/10
#  - 5s - loss: 0.3897 - acc: 0.8174 - val_loss: 0.4412 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.8048 - acc: 0.7216 - val_loss: 0.4215 - val_acc: 0.8100
#
# Epoch 2/10
#  - 3s - loss: 0.5217 - acc: 0.7692 - val_loss: 0.5061 - val_acc: 0.7300
#
# Epoch 3/10
#  - 3s - loss: 0.5013 - acc: 0.7526 - val_loss: 0.3877 - val_acc: 0.7900
#
# Epoch 4/10
#  - 3s - loss: 0.4910 - acc: 0.7687 - val_loss: 0.4473 - val_acc: 0.8000
#
# Epoch 5/10
#  - 3s - loss: 0.4783 - acc: 0.7770 - val_loss: 0.4347 - val_acc: 0.8200
#
# Epoch 6/10
#  - 3s - loss: 0.4568 - acc: 0.7891 - val_loss: 0.4773 - val_acc: 0.8000
#
# Epoch 7/10
#  - 3s - loss: 0.4484 - acc: 0.7970 - val_loss: 0.5468 - val_acc: 0.7600
#
# Epoch 8/10
#  - 3s - loss: 0.4427 - acc: 0.7976 - val_loss: 0.4888 - val_acc: 0.7700
#
# Epoch 9/10
#  - 3s - loss: 0.4297 - acc: 0.8030 - val_loss: 0.4992 - val_acc: 0.8300
#
# Epoch 10/10
#  - 3s - loss: 0.4179 - acc: 0.8091 - val_loss: 0.4922 - val_acc: 0.7600
#
# Test accuracy:
# 0.76
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 9s - loss: 0.9499 - acc: 0.7453 - val_loss: 0.4660 - val_acc: 0.7800
#
# Epoch 2/10
#  - 8s - loss: 0.4991 - acc: 0.7809 - val_loss: 0.6430 - val_acc: 0.7800
#
# Epoch 3/10
#  - 8s - loss: 0.4729 - acc: 0.7906 - val_loss: 0.7270 - val_acc: 0.7400
#
# Epoch 4/10
#  - 8s - loss: 0.4459 - acc: 0.7986 - val_loss: 0.4655 - val_acc: 0.7800
#
# Epoch 5/10
#  - 8s - loss: 0.4196 - acc: 0.7977 - val_loss: 0.5953 - val_acc: 0.7800
#
# Epoch 6/10
#  - 8s - loss: 0.4074 - acc: 0.8082 - val_loss: 0.4407 - val_acc: 0.7700
#
# Epoch 7/10
#  - 8s - loss: 0.3960 - acc: 0.8130 - val_loss: 0.4713 - val_acc: 0.7600
#
# Epoch 8/10
#  - 8s - loss: 0.3854 - acc: 0.8177 - val_loss: 0.6558 - val_acc: 0.7600
#
# Epoch 9/10
#  - 8s - loss: 0.3632 - acc: 0.8262 - val_loss: 0.7113 - val_acc: 0.7600
#
# Epoch 10/10
#  - 8s - loss: 0.3517 - acc: 0.8346 - val_loss: 0.5227 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.7909 - acc: 0.6973 - val_loss: 0.4606 - val_acc: 0.7600
#
# Epoch 2/10
#  - 3s - loss: 0.5642 - acc: 0.7455 - val_loss: 0.5036 - val_acc: 0.8200
#
# Epoch 3/10
#  - 3s - loss: 0.5351 - acc: 0.7527 - val_loss: 0.4628 - val_acc: 0.8100
#
# Epoch 4/10
#  - 3s - loss: 0.5144 - acc: 0.7565 - val_loss: 0.4951 - val_acc: 0.8000
#
# Epoch 5/10
#  - 3s - loss: 0.5188 - acc: 0.7719 - val_loss: 0.5786 - val_acc: 0.7600
#
# Epoch 6/10
#  - 3s - loss: 0.4954 - acc: 0.7635 - val_loss: 0.4535 - val_acc: 0.8000
#
# Epoch 7/10
#  - 3s - loss: 0.4791 - acc: 0.7751 - val_loss: 0.4707 - val_acc: 0.7700
#
# Epoch 8/10
#  - 3s - loss: 0.4694 - acc: 0.7795 - val_loss: 0.4507 - val_acc: 0.8100
#
# Epoch 9/10
#  - 3s - loss: 0.4547 - acc: 0.7899 - val_loss: 0.4276 - val_acc: 0.8000
#
# Epoch 10/10
#  - 3s - loss: 0.4390 - acc: 0.8029 - val_loss: 0.4542 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.7699 - acc: 0.6897 - val_loss: 0.5543 - val_acc: 0.8000
#
# Epoch 2/10
#  - 4s - loss: 0.5882 - acc: 0.7574 - val_loss: 0.4422 - val_acc: 0.7900
#
# Epoch 3/10
#  - 4s - loss: 0.5790 - acc: 0.7586 - val_loss: 0.4977 - val_acc: 0.7700
#
# Epoch 4/10
#  - 4s - loss: 0.5453 - acc: 0.7809 - val_loss: 0.5320 - val_acc: 0.7800
#
# Epoch 5/10
#  - 4s - loss: 0.5177 - acc: 0.7797 - val_loss: 0.4572 - val_acc: 0.7900
#
# Epoch 6/10
#  - 4s - loss: 0.5028 - acc: 0.7866 - val_loss: 0.4777 - val_acc: 0.7800
#
# Epoch 7/10
#  - 4s - loss: 0.4903 - acc: 0.7914 - val_loss: 0.5131 - val_acc: 0.7900
#
# Epoch 8/10
#  - 4s - loss: 0.4781 - acc: 0.7988 - val_loss: 0.4632 - val_acc: 0.8100
#
# Epoch 9/10
#  - 4s - loss: 0.4674 - acc: 0.7919 - val_loss: 0.4371 - val_acc: 0.8100
#
# Epoch 10/10
#  - 4s - loss: 0.4526 - acc: 0.7990 - val_loss: 0.5305 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.8042 - acc: 0.7357 - val_loss: 0.4500 - val_acc: 0.7700
#
# Epoch 2/10
#  - 3s - loss: 0.5932 - acc: 0.7455 - val_loss: 0.5158 - val_acc: 0.7800
#
# Epoch 3/10
#  - 3s - loss: 0.5586 - acc: 0.7623 - val_loss: 0.4717 - val_acc: 0.8100
#
# Epoch 4/10
#  - 3s - loss: 0.5207 - acc: 0.7680 - val_loss: 0.4902 - val_acc: 0.7300
#
# Epoch 5/10
#  - 3s - loss: 0.4971 - acc: 0.7768 - val_loss: 0.5030 - val_acc: 0.8000
#
# Epoch 6/10
#  - 3s - loss: 0.4746 - acc: 0.7855 - val_loss: 0.6149 - val_acc: 0.7500
#
# Epoch 7/10
#  - 3s - loss: 0.4632 - acc: 0.7866 - val_loss: 0.5210 - val_acc: 0.7500
#
# Epoch 8/10
#  - 3s - loss: 0.4632 - acc: 0.7903 - val_loss: 0.4462 - val_acc: 0.7400
#
# Epoch 9/10
#  - 3s - loss: 0.4509 - acc: 0.7919 - val_loss: 0.5195 - val_acc: 0.7400
#
# Epoch 10/10
#  - 3s - loss: 0.4386 - acc: 0.7967 - val_loss: 0.4616 - val_acc: 0.7400
#
# Test accuracy:
# 0.74
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.7319 - acc: 0.7164 - val_loss: 0.5202 - val_acc: 0.7700
#
# Epoch 2/10
#  - 4s - loss: 0.5842 - acc: 0.7388 - val_loss: 0.6877 - val_acc: 0.7900
#
# Epoch 3/10
#  - 4s - loss: 0.5567 - acc: 0.7552 - val_loss: 0.4717 - val_acc: 0.7700
#
# Epoch 4/10
#  - 4s - loss: 0.5331 - acc: 0.7655 - val_loss: 0.4245 - val_acc: 0.7600
#
# Epoch 5/10
#  - 4s - loss: 0.5281 - acc: 0.7701 - val_loss: 0.4821 - val_acc: 0.7800
#
# Epoch 6/10
#  - 4s - loss: 0.5022 - acc: 0.7697 - val_loss: 0.4455 - val_acc: 0.7800
#
# Epoch 7/10
#  - 4s - loss: 0.4815 - acc: 0.7829 - val_loss: 0.5178 - val_acc: 0.8000
#
# Epoch 8/10
#  - 4s - loss: 0.4631 - acc: 0.7883 - val_loss: 0.4666 - val_acc: 0.7600
#
# Epoch 9/10
#  - 4s - loss: 0.4502 - acc: 0.7933 - val_loss: 0.4245 - val_acc: 0.8100
#
# Epoch 10/10
#  - 4s - loss: 0.4553 - acc: 0.7988 - val_loss: 0.5265 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.8697 - acc: 0.7241 - val_loss: 0.5057 - val_acc: 0.7800
#
# Epoch 2/10
#  - 4s - loss: 0.5385 - acc: 0.7586 - val_loss: 0.4319 - val_acc: 0.8000
#
# Epoch 3/10
#  - 4s - loss: 0.5105 - acc: 0.7747 - val_loss: 0.4520 - val_acc: 0.7900
#
# Epoch 4/10
#  - 4s - loss: 0.4783 - acc: 0.7830 - val_loss: 0.4964 - val_acc: 0.8100
#
# Epoch 5/10
#  - 4s - loss: 0.4726 - acc: 0.7878 - val_loss: 0.4586 - val_acc: 0.7800
#
# Epoch 6/10
#  - 4s - loss: 0.4439 - acc: 0.7995 - val_loss: 0.4755 - val_acc: 0.7600
#
# Epoch 7/10
#  - 4s - loss: 0.4428 - acc: 0.8002 - val_loss: 0.4568 - val_acc: 0.7800
#
# Epoch 8/10
#  - 4s - loss: 0.4383 - acc: 0.7995 - val_loss: 0.4716 - val_acc: 0.8100
#
# Epoch 9/10
#  - 4s - loss: 0.4278 - acc: 0.8009 - val_loss: 0.5076 - val_acc: 0.8000
#
# Epoch 10/10
#  - 4s - loss: 0.4132 - acc: 0.8139 - val_loss: 0.5221 - val_acc: 0.7500
#
# Test accuracy:
# 0.75
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.7081 - acc: 0.7453 - val_loss: 0.4958 - val_acc: 0.7600
#
# Epoch 2/10
#  - 5s - loss: 0.5364 - acc: 0.7703 - val_loss: 0.7086 - val_acc: 0.7500
#
# Epoch 3/10
#  - 5s - loss: 0.5071 - acc: 0.7738 - val_loss: 0.4471 - val_acc: 0.7400
#
# Epoch 4/10
#  - 5s - loss: 0.5123 - acc: 0.7797 - val_loss: 0.4267 - val_acc: 0.7900
#
# Epoch 5/10
#  - 5s - loss: 0.5176 - acc: 0.7779 - val_loss: 0.4733 - val_acc: 0.8200
#
# Epoch 6/10
#  - 5s - loss: 0.4800 - acc: 0.7891 - val_loss: 0.4802 - val_acc: 0.7800
#
# Epoch 7/10
#  - 5s - loss: 0.4557 - acc: 0.7901 - val_loss: 0.4270 - val_acc: 0.8000
#
# Epoch 8/10
#  - 5s - loss: 0.4435 - acc: 0.7930 - val_loss: 0.4322 - val_acc: 0.8200
#
# Epoch 9/10
#  - 5s - loss: 0.4352 - acc: 0.7896 - val_loss: 0.5236 - val_acc: 0.7900
#
# Epoch 10/10
#  - 5s - loss: 0.4370 - acc: 0.7988 - val_loss: 0.4720 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.8248 - acc: 0.7607 - val_loss: 0.6386 - val_acc: 0.6600
#
# Epoch 2/10
#  - 3s - loss: 0.4741 - acc: 0.7850 - val_loss: 0.4936 - val_acc: 0.7500
#
# Epoch 3/10
#  - 3s - loss: 0.4360 - acc: 0.8000 - val_loss: 0.4459 - val_acc: 0.7600
#
# Epoch 4/10
#  - 3s - loss: 0.4411 - acc: 0.8022 - val_loss: 0.5904 - val_acc: 0.7700
#
# Epoch 5/10
#  - 3s - loss: 0.3978 - acc: 0.8146 - val_loss: 0.4557 - val_acc: 0.8200
#
# Epoch 6/10
#  - 3s - loss: 0.3927 - acc: 0.8154 - val_loss: 0.4097 - val_acc: 0.8400
#
# Epoch 7/10
#  - 3s - loss: 0.3719 - acc: 0.8227 - val_loss: 0.5310 - val_acc: 0.7900
#
# Epoch 8/10
#  - 3s - loss: 0.3591 - acc: 0.8335 - val_loss: 0.4159 - val_acc: 0.8200
#
# Epoch 9/10
#  - 3s - loss: 0.3453 - acc: 0.8351 - val_loss: 0.5751 - val_acc: 0.7700
#
# Epoch 10/10
#  - 3s - loss: 0.3319 - acc: 0.8443 - val_loss: 0.4612 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 1.0777 - acc: 0.7138 - val_loss: 0.4710 - val_acc: 0.7600
#
# Epoch 2/10
#  - 4s - loss: 0.6375 - acc: 0.7340 - val_loss: 0.5266 - val_acc: 0.7400
#
# Epoch 3/10
#  - 4s - loss: 0.6035 - acc: 0.7671 - val_loss: 0.4988 - val_acc: 0.8000
#
# Epoch 4/10
#  - 4s - loss: 0.5888 - acc: 0.7623 - val_loss: 0.4708 - val_acc: 0.7900
#
# Epoch 5/10
#  - 4s - loss: 0.5513 - acc: 0.7754 - val_loss: 0.4600 - val_acc: 0.8300
#
# Epoch 6/10
#  - 4s - loss: 0.5446 - acc: 0.7871 - val_loss: 0.4218 - val_acc: 0.8000
#
# Epoch 7/10
#  - 4s - loss: 0.5401 - acc: 0.7853 - val_loss: 0.4529 - val_acc: 0.7900
#
# Epoch 8/10
#  - 4s - loss: 0.5304 - acc: 0.7843 - val_loss: 0.4782 - val_acc: 0.8000
#
# Epoch 9/10
#  - 4s - loss: 0.4933 - acc: 0.7942 - val_loss: 0.4356 - val_acc: 0.7900
#
# Epoch 10/10
#  - 4s - loss: 0.5028 - acc: 0.7931 - val_loss: 0.5548 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.0486 - acc: 0.7032 - val_loss: 0.4570 - val_acc: 0.7300
#
# Epoch 2/10
#  - 3s - loss: 0.6364 - acc: 0.7379 - val_loss: 0.4781 - val_acc: 0.7300
#
# Epoch 3/10
#  - 3s - loss: 0.5871 - acc: 0.7497 - val_loss: 0.6843 - val_acc: 0.7300
#
# Epoch 4/10
#  - 3s - loss: 0.5797 - acc: 0.7635 - val_loss: 0.4360 - val_acc: 0.7800
#
# Epoch 5/10
#  - 3s - loss: 0.5386 - acc: 0.7795 - val_loss: 0.5444 - val_acc: 0.7300
#
# Epoch 6/10
#  - 3s - loss: 0.5276 - acc: 0.7759 - val_loss: 0.5241 - val_acc: 0.7500
#
# Epoch 7/10
#  - 3s - loss: 0.5153 - acc: 0.7783 - val_loss: 0.4592 - val_acc: 0.7900
#
# Epoch 8/10
#  - 3s - loss: 0.5078 - acc: 0.7829 - val_loss: 0.5180 - val_acc: 0.7800
#
# Epoch 9/10
#  - 3s - loss: 0.4971 - acc: 0.7825 - val_loss: 0.5189 - val_acc: 0.7800
#
# Epoch 10/10
#  - 3s - loss: 0.4874 - acc: 0.7940 - val_loss: 0.5272 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.9684 - acc: 0.7217 - val_loss: 0.4906 - val_acc: 0.7300
#
# Epoch 2/10
#  - 3s - loss: 0.6177 - acc: 0.7465 - val_loss: 0.4199 - val_acc: 0.7800
#
# Epoch 3/10
#  - 3s - loss: 0.5685 - acc: 0.7605 - val_loss: 0.4198 - val_acc: 0.8300
#
# Epoch 4/10
#  - 3s - loss: 0.5547 - acc: 0.7678 - val_loss: 0.4047 - val_acc: 0.7500
#
# Epoch 5/10
#  - 3s - loss: 0.5221 - acc: 0.7889 - val_loss: 0.4481 - val_acc: 0.8100
#
# Epoch 6/10
#  - 3s - loss: 0.4946 - acc: 0.7891 - val_loss: 0.4301 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.4830 - acc: 0.7945 - val_loss: 0.4415 - val_acc: 0.8000
#
# Epoch 8/10
#  - 3s - loss: 0.4699 - acc: 0.8016 - val_loss: 0.4735 - val_acc: 0.8100
#
# Epoch 9/10
#  - 3s - loss: 0.4680 - acc: 0.8061 - val_loss: 0.5294 - val_acc: 0.7900
#
# Epoch 10/10
#  - 3s - loss: 0.4703 - acc: 0.8053 - val_loss: 0.4689 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.8800 - acc: 0.6936 - val_loss: 0.4243 - val_acc: 0.7600
#
# Epoch 2/10
#  - 4s - loss: 0.6302 - acc: 0.6644 - val_loss: 0.4474 - val_acc: 0.7800
#
# Epoch 3/10
#  - 4s - loss: 0.6149 - acc: 0.7037 - val_loss: 0.3940 - val_acc: 0.8200
#
# Epoch 4/10
#  - 4s - loss: 0.5865 - acc: 0.6989 - val_loss: 0.4697 - val_acc: 0.7000
#
# Epoch 5/10
#  - 4s - loss: 0.5361 - acc: 0.7545 - val_loss: 0.5351 - val_acc: 0.7700
#
# Epoch 6/10
#  - 4s - loss: 0.5472 - acc: 0.7713 - val_loss: 0.4617 - val_acc: 0.7900
#
# Epoch 7/10
#  - 4s - loss: 0.5429 - acc: 0.7726 - val_loss: 0.4364 - val_acc: 0.8000
#
# Epoch 8/10
#  - 4s - loss: 0.5382 - acc: 0.7788 - val_loss: 0.4328 - val_acc: 0.7900
#
# Epoch 9/10
#  - 4s - loss: 0.5186 - acc: 0.7820 - val_loss: 0.4479 - val_acc: 0.7900
#
# Epoch 10/10
#  - 4s - loss: 0.4988 - acc: 0.7770 - val_loss: 0.4445 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.9430 - acc: 0.7210 - val_loss: 0.4265 - val_acc: 0.8100
#
# Epoch 2/10
#  - 4s - loss: 0.5734 - acc: 0.7680 - val_loss: 0.4844 - val_acc: 0.7800
#
# Epoch 3/10
#  - 4s - loss: 0.5656 - acc: 0.7719 - val_loss: 0.4184 - val_acc: 0.8000
#
# Epoch 4/10
#  - 4s - loss: 0.5199 - acc: 0.7736 - val_loss: 0.4237 - val_acc: 0.7700
#
# Epoch 5/10
#  - 4s - loss: 0.5170 - acc: 0.7839 - val_loss: 0.4517 - val_acc: 0.7900
#
# Epoch 6/10
#  - 4s - loss: 0.5022 - acc: 0.7993 - val_loss: 0.4664 - val_acc: 0.7900
#
# Epoch 7/10
#  - 4s - loss: 0.4926 - acc: 0.7910 - val_loss: 0.4703 - val_acc: 0.7600
#
# Epoch 8/10
#  - 4s - loss: 0.4722 - acc: 0.8013 - val_loss: 0.4563 - val_acc: 0.8100
#
# Epoch 9/10
#  - 4s - loss: 0.4713 - acc: 0.8025 - val_loss: 0.4736 - val_acc: 0.7900
#
# Epoch 10/10
#  - 4s - loss: 0.4583 - acc: 0.8025 - val_loss: 0.4794 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.1345 - acc: 0.6881 - val_loss: 0.4271 - val_acc: 0.8000
#
# Epoch 2/10
#  - 3s - loss: 0.7233 - acc: 0.7260 - val_loss: 0.4174 - val_acc: 0.8100
#
# Epoch 3/10
#  - 3s - loss: 0.5990 - acc: 0.7545 - val_loss: 0.4813 - val_acc: 0.7800
#
# Epoch 4/10
#  - 3s - loss: 0.5652 - acc: 0.7607 - val_loss: 0.4130 - val_acc: 0.8000
#
# Epoch 5/10
#  - 3s - loss: 0.5535 - acc: 0.7713 - val_loss: 0.4132 - val_acc: 0.8400
#
# Epoch 6/10
#  - 3s - loss: 0.5377 - acc: 0.7682 - val_loss: 0.4470 - val_acc: 0.7800
#
# Epoch 7/10
#  - 3s - loss: 0.5220 - acc: 0.7804 - val_loss: 0.5300 - val_acc: 0.7700
#
# Epoch 8/10
#  - 3s - loss: 0.5133 - acc: 0.7841 - val_loss: 0.5154 - val_acc: 0.7900
#
# Epoch 9/10
#  - 3s - loss: 0.4968 - acc: 0.7869 - val_loss: 0.4645 - val_acc: 0.8000
#
# Epoch 10/10
#  - 3s - loss: 0.4835 - acc: 0.7875 - val_loss: 0.4445 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.1561 - acc: 0.6622 - val_loss: 0.4774 - val_acc: 0.7600
#
# Epoch 2/10
#  - 3s - loss: 0.6780 - acc: 0.6619 - val_loss: 0.4923 - val_acc: 0.7200
#
# Epoch 3/10
#  - 3s - loss: 0.6397 - acc: 0.6612 - val_loss: 0.4469 - val_acc: 0.7900
#
# Epoch 4/10
#  - 3s - loss: 0.5952 - acc: 0.6654 - val_loss: 0.4342 - val_acc: 0.8100
#
# Epoch 5/10
#  - 3s - loss: 0.5998 - acc: 0.6769 - val_loss: 0.4835 - val_acc: 0.7400
#
# Epoch 6/10
#  - 3s - loss: 0.5686 - acc: 0.6973 - val_loss: 0.4915 - val_acc: 0.7500
#
# Epoch 7/10
#  - 3s - loss: 0.5616 - acc: 0.6796 - val_loss: 0.5052 - val_acc: 0.7400
#
# Epoch 8/10
#  - 3s - loss: 0.5525 - acc: 0.7003 - val_loss: 0.4805 - val_acc: 0.7600
#
# Epoch 9/10
#  - 3s - loss: 0.5379 - acc: 0.6952 - val_loss: 0.5423 - val_acc: 0.7400
#
# Epoch 10/10
#  - 3s - loss: 0.5171 - acc: 0.7694 - val_loss: 0.4851 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 7s - loss: 1.1031 - acc: 0.7159 - val_loss: 0.4502 - val_acc: 0.7700
#
# Epoch 2/10
#  - 4s - loss: 0.6135 - acc: 0.7565 - val_loss: 0.4114 - val_acc: 0.7400
#
# Epoch 3/10
#  - 4s - loss: 0.5759 - acc: 0.7659 - val_loss: 0.5164 - val_acc: 0.7900
#
# Epoch 4/10
#  - 4s - loss: 0.5768 - acc: 0.7736 - val_loss: 0.4741 - val_acc: 0.7600
#
# Epoch 5/10
#  - 4s - loss: 0.5570 - acc: 0.7804 - val_loss: 0.4454 - val_acc: 0.7900
#
# Epoch 6/10
#  - 4s - loss: 0.5708 - acc: 0.7791 - val_loss: 0.4567 - val_acc: 0.7900
#
# Epoch 7/10
#  - 4s - loss: 0.5237 - acc: 0.7857 - val_loss: 0.4726 - val_acc: 0.7700
#
# Epoch 8/10
#  - 4s - loss: 0.5089 - acc: 0.7846 - val_loss: 0.5017 - val_acc: 0.7800
#
# Epoch 9/10
#  - 4s - loss: 0.4969 - acc: 0.7924 - val_loss: 0.4371 - val_acc: 0.8200
#
# Epoch 10/10
#  - 4s - loss: 0.4928 - acc: 0.7880 - val_loss: 0.5457 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 7s - loss: 1.1402 - acc: 0.7109 - val_loss: 0.5088 - val_acc: 0.7700
#
# Epoch 2/10
#  - 4s - loss: 0.5759 - acc: 0.7324 - val_loss: 0.4512 - val_acc: 0.7700
#
# Epoch 3/10
#  - 4s - loss: 0.5654 - acc: 0.7113 - val_loss: 0.4651 - val_acc: 0.8000
#
# Epoch 4/10
#  - 4s - loss: 0.5386 - acc: 0.7279 - val_loss: 0.4817 - val_acc: 0.7600
#
# Epoch 5/10
#  - 4s - loss: 0.5316 - acc: 0.7620 - val_loss: 0.4261 - val_acc: 0.7800
#
# Epoch 6/10
#  - 4s - loss: 0.5197 - acc: 0.7791 - val_loss: 0.4609 - val_acc: 0.8000
#
# Epoch 7/10
#  - 4s - loss: 0.5141 - acc: 0.7860 - val_loss: 0.5835 - val_acc: 0.7600
#
# Epoch 8/10
#  - 4s - loss: 0.5229 - acc: 0.7862 - val_loss: 0.5739 - val_acc: 0.7500
#
# Epoch 9/10
#  - 4s - loss: 0.5015 - acc: 0.7901 - val_loss: 0.5159 - val_acc: 0.7800
#
# Epoch 10/10
#  - 4s - loss: 0.5038 - acc: 0.7866 - val_loss: 0.4547 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.9363 - acc: 0.7141 - val_loss: 0.4234 - val_acc: 0.7900
#
# Epoch 2/10
#  - 3s - loss: 0.6367 - acc: 0.7373 - val_loss: 0.4534 - val_acc: 0.7200
#
# Epoch 3/10
#  - 3s - loss: 0.5557 - acc: 0.7512 - val_loss: 0.4843 - val_acc: 0.7700
#
# Epoch 4/10
#  - 3s - loss: 0.5306 - acc: 0.7565 - val_loss: 0.4625 - val_acc: 0.7900
#
# Epoch 5/10
#  - 3s - loss: 0.5187 - acc: 0.7605 - val_loss: 0.4430 - val_acc: 0.7900
#
# Epoch 6/10
#  - 3s - loss: 0.5158 - acc: 0.7678 - val_loss: 0.5229 - val_acc: 0.7700
#
# Epoch 7/10
#  - 3s - loss: 0.4766 - acc: 0.7809 - val_loss: 0.5200 - val_acc: 0.8200
#
# Epoch 8/10
#  - 3s - loss: 0.4691 - acc: 0.7855 - val_loss: 0.4594 - val_acc: 0.8400
#
# Epoch 9/10
#  - 3s - loss: 0.4482 - acc: 0.7944 - val_loss: 0.4431 - val_acc: 0.8400
#
# Epoch 10/10
#  - 3s - loss: 0.4558 - acc: 0.7965 - val_loss: 0.4715 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# 100%|██████████| 30/30 [23:18<00:00, 38.70s/it, best loss: -0.82]
# Time on optimization: 23.35222528775533 minutos
#
# Summary of the best model: -----------------------
# Evalutation of best performing model:
# 100/100 [==============================] - 0s 366us/step
# [0.46970322608947757, 0.82]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 5, 1)      0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 62, 62, 3, 32)     896
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 31, 31, 1, 32)     0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30752)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                1968192
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,971,201
# Trainable params: 1,971,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Conv 1: 32 unidades
# Dense 1: 96 unidades
# Dense 2: 32 unidades
# Dropout 1: 0.3671073489296299
# Dropout 2: 0.3462695171578595
