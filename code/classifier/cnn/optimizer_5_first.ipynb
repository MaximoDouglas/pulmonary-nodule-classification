# %% [markdown]
# # Colab config

# %%
from google.colab import drive
drive.mount('drive', force_remount=True)

# %%
# !pip install hyperas

# %% [markdown]
# ## Imports

# %%
import os

import time

import gc

import numpy as np

from scipy import interp

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, roc_curve, auc

from keras import backend as K
from keras import optimizers
from keras.layers import Conv3D, MaxPool3D, Flatten, Dense, Dropout, Input
from keras.losses import binary_crossentropy
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.utils.vis_utils import plot_model, model_to_dot

# %% [markdown]
# ## GPU configuration

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 1
set_session(tf.Session(config=config))
session = tf.Session(config=config)

# %% [markdown]
# # Hyperparameters optimization
#
# Func **data()** required by Hyperas. It must return 4 arrays X_train, Y_train, X_test, Y_test.
#
# The data for optimization are on four numpy files, generated with the notebook **import_images.ipynb**.

# %%
'''5-first'''

def data():
  prefix = "/content/drive/My Drive/Pesquisa - Dicom images/data"
  X_train = np.load(prefix + "/nps/solid-nodules/data-5-first/X_train.npy")
  X_test = np.load(prefix + "/nps/solid-nodules/data-5-first/X_test.npy")
  Y_train = np.load(prefix + "/nps/solid-nodules/data-5-first/Y_train.npy")
  Y_test = np.load(prefix + "/nps/solid-nodules/data-5-first/Y_test.npy")
  
  return X_train, Y_train, X_test, Y_test

# %% [markdown]
# ## Space of search definition
#
# * **conv_layer1**: [32, 48, 64, 96] unities
# * **dense_layer1**: [32, 64, 128, 256] unities
# * **dense_layer2**: [8, 16, 24, 32] unities
# * **dropout** on dense layers: between 0 and 0.5

# %%
conv1 = [32, 48, 64, 96]
dense1 = [64, 96, 128]
dense2 = [16, 24, 32]
    
def model(X_train, Y_train, X_test, Y_test):
    conv1 = {{choice([32, 48, 64, 96])}}
    dense1 = {{choice([32, 64, 128])}}
    dense2 = {{choice([16, 24, 32])}}
    
    input_layer = Input(X_train.shape[1:5])
    
    conv_layer1 = Conv3D(conv1, kernel_size=(3, 3, 3), activation='relu')(input_layer)
    pooling_layer1 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer1)
    
    flatten_layer = Flatten()(pooling_layer1)
    
    dense_layer1 = Dense(dense1, activation='relu')(flatten_layer)
    dense_layer1 = Dropout({{uniform(0, .5)}})(dense_layer1)
    
    dense_layer2 = Dense(dense2, activation='relu')(dense_layer1)
    dense_layer2 = Dropout({{uniform(0, .5)}})(dense_layer2)
    
    output_layer = Dense(units=1, activation='sigmoid')(dense_layer2)
    
    model = Model(inputs=input_layer, outputs=output_layer)
    
    opt = optimizers.RMSprop(lr=0.0001)
    
    model.compile(loss=binary_crossentropy, optimizer=opt, metrics=['acc'])
    
    model.fit(X_train, Y_train,
              batch_size=128,
              epochs=10,
              verbose=2,
              validation_data=(X_test, Y_test)
              )
    
    score, acc = model.evaluate(X_test, Y_test, verbose=0)
    
    print('Test accuracy:', acc)
    
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %% [markdown]
# ## Otimization

# %%
X_train, Y_train, X_test, Y_test = data()

start = time.time()

best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=30,
                                      trials=Trials(),
                                      verbose=False,
                                      notebook_name='drive/My Drive/Pesquisa - Dicom images/notebooks/optimizer_5_first')
end = time.time()

print("Time on optimization:", (end - start)/60, "minutes")

print()
print('Summary of the best model: -----------------------')

print("Evalutation of best performing model:")
print(best_model.evaluate(X_test, Y_test))

print(best_model.summary())

c1 = conv1[best_run['conv1']]
d1 = dense1[best_run['dense1']]
d2 = dense2[best_run['dense2']]
drop1 = best_run['Dropout']
drop2 = best_run['Dropout_1']

print('Conv 1:', c1, 'unidades')
print('Dense 1:', d1, 'unidades')
print('Dense 2:', d2, 'unidades')
print('Dropout 1:', drop1)
print('Dropout 2:', drop2)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 1.1680 - acc: 0.6948 - val_loss: 0.4278 - val_acc: 0.7700
#
# Epoch 2/10
#  - 3s - loss: 0.6457 - acc: 0.7117 - val_loss: 0.4646 - val_acc: 0.7800
#
# Epoch 3/10
#  - 3s - loss: 0.5888 - acc: 0.7478 - val_loss: 0.4625 - val_acc: 0.7700
#
# Epoch 4/10
#  - 3s - loss: 0.5543 - acc: 0.7685 - val_loss: 0.4483 - val_acc: 0.7900
#
# Epoch 5/10
#  - 3s - loss: 0.5235 - acc: 0.7728 - val_loss: 0.4902 - val_acc: 0.8100
#
# Epoch 6/10
#  - 3s - loss: 0.5188 - acc: 0.7853 - val_loss: 0.4331 - val_acc: 0.8100
#
# Epoch 7/10
#  - 3s - loss: 0.4987 - acc: 0.7894 - val_loss: 0.4499 - val_acc: 0.7900
#
# Epoch 8/10
#  - 3s - loss: 0.4875 - acc: 0.7930 - val_loss: 0.4313 - val_acc: 0.8100
#
# Epoch 9/10
#  - 3s - loss: 0.4799 - acc: 0.7961 - val_loss: 0.5226 - val_acc: 0.7900
#
# Epoch 10/10
#  - 3s - loss: 0.4785 - acc: 0.7961 - val_loss: 0.4373 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.8844 - acc: 0.7051 - val_loss: 0.4770 - val_acc: 0.7300
#
# Epoch 2/10
#  - 4s - loss: 0.6371 - acc: 0.7301 - val_loss: 0.4259 - val_acc: 0.7500
#
# Epoch 3/10
#  - 4s - loss: 0.5874 - acc: 0.7488 - val_loss: 0.4633 - val_acc: 0.7900
#
# Epoch 4/10
#  - 4s - loss: 0.5554 - acc: 0.7598 - val_loss: 0.5627 - val_acc: 0.7700
#
# Epoch 5/10
#  - 4s - loss: 0.5295 - acc: 0.7666 - val_loss: 0.4600 - val_acc: 0.7600
#
# Epoch 6/10
#  - 4s - loss: 0.5249 - acc: 0.7667 - val_loss: 0.4500 - val_acc: 0.7700
#
# Epoch 7/10
#  - 4s - loss: 0.4950 - acc: 0.7802 - val_loss: 0.4660 - val_acc: 0.8000
#
# Epoch 8/10
#  - 4s - loss: 0.4671 - acc: 0.7834 - val_loss: 0.4803 - val_acc: 0.7500
#
# Epoch 9/10
#  - 4s - loss: 0.4536 - acc: 0.7800 - val_loss: 0.4684 - val_acc: 0.8100
#
# Epoch 10/10
#  - 4s - loss: 0.4399 - acc: 0.7903 - val_loss: 0.4465 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.8688 - acc: 0.7097 - val_loss: 0.4636 - val_acc: 0.7800
#
# Epoch 2/10
#  - 5s - loss: 0.5927 - acc: 0.7655 - val_loss: 0.4910 - val_acc: 0.7900
#
# Epoch 3/10
#  - 5s - loss: 0.5669 - acc: 0.7664 - val_loss: 0.4996 - val_acc: 0.7900
#
# Epoch 4/10
#  - 5s - loss: 0.5362 - acc: 0.7744 - val_loss: 0.4423 - val_acc: 0.8200
#
# Epoch 5/10
#  - 5s - loss: 0.5423 - acc: 0.7726 - val_loss: 0.4755 - val_acc: 0.7800
#
# Epoch 6/10
#  - 5s - loss: 0.5133 - acc: 0.7873 - val_loss: 0.4738 - val_acc: 0.7800
#
# Epoch 7/10
#  - 5s - loss: 0.4829 - acc: 0.7938 - val_loss: 0.4912 - val_acc: 0.8300
#
# Epoch 8/10
#  - 5s - loss: 0.4766 - acc: 0.7869 - val_loss: 0.4952 - val_acc: 0.8100
#
# Epoch 9/10
#  - 5s - loss: 0.4752 - acc: 0.7860 - val_loss: 0.4314 - val_acc: 0.8100
#
# Epoch 10/10
#  - 5s - loss: 0.4421 - acc: 0.7984 - val_loss: 0.4702 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.8277 - acc: 0.7072 - val_loss: 0.4589 - val_acc: 0.7600
#
# Epoch 2/10
#  - 4s - loss: 0.5526 - acc: 0.7524 - val_loss: 0.4700 - val_acc: 0.7500
#
# Epoch 3/10
#  - 4s - loss: 0.5141 - acc: 0.7733 - val_loss: 0.4561 - val_acc: 0.8100
#
# Epoch 4/10
#  - 4s - loss: 0.4889 - acc: 0.7855 - val_loss: 0.4436 - val_acc: 0.7900
#
# Epoch 5/10
#  - 4s - loss: 0.4832 - acc: 0.7905 - val_loss: 0.4517 - val_acc: 0.8100
#
# Epoch 6/10
#  - 4s - loss: 0.4778 - acc: 0.7905 - val_loss: 0.4406 - val_acc: 0.7700
#
# Epoch 7/10
#  - 4s - loss: 0.4577 - acc: 0.7965 - val_loss: 0.4398 - val_acc: 0.8100
#
# Epoch 8/10
#  - 4s - loss: 0.4540 - acc: 0.8038 - val_loss: 0.4154 - val_acc: 0.8000
#
# Epoch 9/10
#  - 4s - loss: 0.4368 - acc: 0.8029 - val_loss: 0.4611 - val_acc: 0.8000
#
# Epoch 10/10
#  - 4s - loss: 0.4222 - acc: 0.8027 - val_loss: 0.4945 - val_acc: 0.7600
#
# Test accuracy:
# 0.76
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 10s - loss: 1.0634 - acc: 0.7347 - val_loss: 0.6289 - val_acc: 0.8000
#
# Epoch 2/10
#  - 8s - loss: 0.4805 - acc: 0.7637 - val_loss: 0.4692 - val_acc: 0.7100
#
# Epoch 3/10
#  - 8s - loss: 0.4693 - acc: 0.7806 - val_loss: 0.4973 - val_acc: 0.8000
#
# Epoch 4/10
#  - 8s - loss: 0.4616 - acc: 0.7798 - val_loss: 0.4375 - val_acc: 0.7900
#
# Epoch 5/10
#  - 8s - loss: 0.4407 - acc: 0.7790 - val_loss: 0.6396 - val_acc: 0.7600
#
# Epoch 6/10
#  - 8s - loss: 0.4181 - acc: 0.7896 - val_loss: 0.4422 - val_acc: 0.7700
#
# Epoch 7/10
#  - 8s - loss: 0.4069 - acc: 0.8022 - val_loss: 0.6550 - val_acc: 0.7200
#
# Epoch 8/10
#  - 8s - loss: 0.3847 - acc: 0.8094 - val_loss: 0.5808 - val_acc: 0.8100
#
# Epoch 9/10
#  - 8s - loss: 0.3801 - acc: 0.8075 - val_loss: 0.4564 - val_acc: 0.7800
#
# Epoch 10/10
#  - 8s - loss: 0.3703 - acc: 0.8133 - val_loss: 0.4998 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 1.4195 - acc: 0.6941 - val_loss: 0.4915 - val_acc: 0.7200
#
# Epoch 2/10
#  - 5s - loss: 0.6844 - acc: 0.7265 - val_loss: 0.4621 - val_acc: 0.7800
#
# Epoch 3/10
#  - 5s - loss: 0.6539 - acc: 0.7341 - val_loss: 0.4404 - val_acc: 0.7700
#
# Epoch 4/10
#  - 5s - loss: 0.5848 - acc: 0.7388 - val_loss: 0.5817 - val_acc: 0.7200
#
# Epoch 5/10
#  - 5s - loss: 0.5691 - acc: 0.7492 - val_loss: 0.4432 - val_acc: 0.7400
#
# Epoch 6/10
#  - 5s - loss: 0.5395 - acc: 0.7538 - val_loss: 0.4521 - val_acc: 0.8000
#
# Epoch 7/10
#  - 5s - loss: 0.5108 - acc: 0.7648 - val_loss: 0.5272 - val_acc: 0.7500
#
# Epoch 8/10
#  - 5s - loss: 0.5130 - acc: 0.7752 - val_loss: 0.4677 - val_acc: 0.7800
#
# Epoch 9/10
#  - 5s - loss: 0.4839 - acc: 0.7853 - val_loss: 0.4637 - val_acc: 0.7800
#
# Epoch 10/10
#  - 5s - loss: 0.4711 - acc: 0.7928 - val_loss: 0.4241 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.7107 - acc: 0.7347 - val_loss: 0.5461 - val_acc: 0.7800
#
# Epoch 2/10
#  - 5s - loss: 0.5248 - acc: 0.7597 - val_loss: 0.8037 - val_acc: 0.7200
#
# Epoch 3/10
#  - 5s - loss: 0.5169 - acc: 0.7595 - val_loss: 0.4408 - val_acc: 0.7600
#
# Epoch 4/10
#  - 5s - loss: 0.4951 - acc: 0.7628 - val_loss: 0.4517 - val_acc: 0.7700
#
# Epoch 5/10
#  - 5s - loss: 0.4764 - acc: 0.7715 - val_loss: 0.5174 - val_acc: 0.7600
#
# Epoch 6/10
#  - 5s - loss: 0.4573 - acc: 0.7871 - val_loss: 0.8149 - val_acc: 0.7200
#
# Epoch 7/10
#  - 5s - loss: 0.4470 - acc: 0.7843 - val_loss: 0.4674 - val_acc: 0.7400
#
# Epoch 8/10
#  - 5s - loss: 0.4350 - acc: 0.7915 - val_loss: 0.5233 - val_acc: 0.7800
#
# Epoch 9/10
#  - 5s - loss: 0.4219 - acc: 0.7958 - val_loss: 0.4945 - val_acc: 0.8000
#
# Epoch 10/10
#  - 5s - loss: 0.4140 - acc: 0.7945 - val_loss: 0.5009 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 9s - loss: 0.7441 - acc: 0.7444 - val_loss: 0.6777 - val_acc: 0.7800
#
# Epoch 2/10
#  - 8s - loss: 0.5334 - acc: 0.7731 - val_loss: 0.4205 - val_acc: 0.7500
#
# Epoch 3/10
#  - 8s - loss: 0.4815 - acc: 0.7770 - val_loss: 0.4749 - val_acc: 0.8400
#
# Epoch 4/10
#  - 8s - loss: 0.4726 - acc: 0.7846 - val_loss: 0.4332 - val_acc: 0.7800
#
# Epoch 5/10
#  - 8s - loss: 0.4392 - acc: 0.8000 - val_loss: 0.4185 - val_acc: 0.7700
#
# Epoch 6/10
#  - 8s - loss: 0.4129 - acc: 0.8071 - val_loss: 0.4227 - val_acc: 0.7800
#
# Epoch 7/10
#  - 8s - loss: 0.3980 - acc: 0.8160 - val_loss: 0.4863 - val_acc: 0.7700
#
# Epoch 8/10
#  - 8s - loss: 0.3696 - acc: 0.8301 - val_loss: 0.5348 - val_acc: 0.7500
#
# Epoch 9/10
#  - 8s - loss: 0.3474 - acc: 0.8408 - val_loss: 0.4676 - val_acc: 0.8000
#
# Epoch 10/10
#  - 8s - loss: 0.3251 - acc: 0.8528 - val_loss: 0.6282 - val_acc: 0.7200
#
# Test accuracy:
# 0.72
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.7007 - acc: 0.6964 - val_loss: 0.4469 - val_acc: 0.8200
#
# Epoch 2/10
#  - 5s - loss: 0.5110 - acc: 0.7517 - val_loss: 0.5592 - val_acc: 0.6100
#
# Epoch 3/10
#  - 5s - loss: 0.4846 - acc: 0.7650 - val_loss: 0.4874 - val_acc: 0.8000
#
# Epoch 4/10
#  - 5s - loss: 0.4675 - acc: 0.7839 - val_loss: 0.6132 - val_acc: 0.7000
#
# Epoch 5/10
#  - 5s - loss: 0.4418 - acc: 0.7922 - val_loss: 0.4915 - val_acc: 0.8000
#
# Epoch 6/10
#  - 5s - loss: 0.4115 - acc: 0.8015 - val_loss: 0.4444 - val_acc: 0.8000
#
# Epoch 7/10
#  - 5s - loss: 0.4052 - acc: 0.8061 - val_loss: 0.5368 - val_acc: 0.7800
#
# Epoch 8/10
#  - 5s - loss: 0.3832 - acc: 0.8153 - val_loss: 0.4806 - val_acc: 0.7700
#
# Epoch 9/10
#  - 5s - loss: 0.3782 - acc: 0.8193 - val_loss: 0.4510 - val_acc: 0.8200
#
# Epoch 10/10
#  - 5s - loss: 0.3638 - acc: 0.8291 - val_loss: 0.5252 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 8s - loss: 0.6782 - acc: 0.7561 - val_loss: 0.4771 - val_acc: 0.8200
#
# Epoch 2/10
#  - 8s - loss: 0.4910 - acc: 0.7804 - val_loss: 0.4265 - val_acc: 0.7600
#
# Epoch 3/10
#  - 8s - loss: 0.4869 - acc: 0.7928 - val_loss: 0.4697 - val_acc: 0.8100
#
# Epoch 4/10
#  - 8s - loss: 0.4671 - acc: 0.8013 - val_loss: 0.4510 - val_acc: 0.8100
#
# Epoch 5/10
#  - 8s - loss: 0.4502 - acc: 0.8062 - val_loss: 0.4723 - val_acc: 0.7500
#
# Epoch 6/10
#  - 8s - loss: 0.4378 - acc: 0.8057 - val_loss: 0.4600 - val_acc: 0.8100
#
# Epoch 7/10
#  - 8s - loss: 0.4223 - acc: 0.8172 - val_loss: 0.4589 - val_acc: 0.8100
#
# Epoch 8/10
#  - 8s - loss: 0.4149 - acc: 0.8119 - val_loss: 0.4275 - val_acc: 0.8100
#
# Epoch 9/10
#  - 8s - loss: 0.3941 - acc: 0.8262 - val_loss: 0.5274 - val_acc: 0.8000
#
# Epoch 10/10
#  - 8s - loss: 0.3842 - acc: 0.8278 - val_loss: 0.6064 - val_acc: 0.7500
#
# Test accuracy:
# 0.75
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.9015 - acc: 0.6817 - val_loss: 0.5312 - val_acc: 0.6700
#
# Epoch 2/10
#  - 5s - loss: 0.5661 - acc: 0.7350 - val_loss: 0.4810 - val_acc: 0.7400
#
# Epoch 3/10
#  - 5s - loss: 0.5241 - acc: 0.7552 - val_loss: 0.4437 - val_acc: 0.8000
#
# Epoch 4/10
#  - 5s - loss: 0.4927 - acc: 0.7715 - val_loss: 0.4761 - val_acc: 0.7500
#
# Epoch 5/10
#  - 5s - loss: 0.4722 - acc: 0.7864 - val_loss: 0.5623 - val_acc: 0.7600
#
# Epoch 6/10
#  - 5s - loss: 0.4486 - acc: 0.7875 - val_loss: 0.4432 - val_acc: 0.8100
#
# Epoch 7/10
#  - 5s - loss: 0.4369 - acc: 0.7979 - val_loss: 0.4847 - val_acc: 0.7300
#
# Epoch 8/10
#  - 5s - loss: 0.4272 - acc: 0.8004 - val_loss: 0.4765 - val_acc: 0.7600
#
# Epoch 9/10
#  - 5s - loss: 0.4096 - acc: 0.8114 - val_loss: 0.4624 - val_acc: 0.7800
#
# Epoch 10/10
#  - 5s - loss: 0.3857 - acc: 0.8204 - val_loss: 0.4937 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.7466 - acc: 0.7288 - val_loss: 0.4549 - val_acc: 0.7800
#
# Epoch 2/10
#  - 3s - loss: 0.5135 - acc: 0.7653 - val_loss: 0.6428 - val_acc: 0.7000
#
# Epoch 3/10
#  - 3s - loss: 0.5072 - acc: 0.7683 - val_loss: 0.4664 - val_acc: 0.7400
#
# Epoch 4/10
#  - 3s - loss: 0.4836 - acc: 0.7809 - val_loss: 0.4400 - val_acc: 0.8100
#
# Epoch 5/10
#  - 3s - loss: 0.4689 - acc: 0.7786 - val_loss: 0.5413 - val_acc: 0.7700
#
# Epoch 6/10
#  - 3s - loss: 0.4715 - acc: 0.7855 - val_loss: 0.5091 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.4344 - acc: 0.8015 - val_loss: 0.4537 - val_acc: 0.8400
#
# Epoch 8/10
#  - 3s - loss: 0.4352 - acc: 0.7967 - val_loss: 0.4866 - val_acc: 0.7700
#
# Epoch 9/10
#  - 3s - loss: 0.4249 - acc: 0.7991 - val_loss: 0.5088 - val_acc: 0.8100
#
# Epoch 10/10
#  - 3s - loss: 0.4103 - acc: 0.8131 - val_loss: 0.5122 - val_acc: 0.8200
#
# Test accuracy:
# 0.82
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 9s - loss: 1.0507 - acc: 0.7308 - val_loss: 0.6323 - val_acc: 0.7700
#
# Epoch 2/10
#  - 8s - loss: 0.5223 - acc: 0.7811 - val_loss: 0.5720 - val_acc: 0.7300
#
# Epoch 3/10
#  - 8s - loss: 0.4833 - acc: 0.7848 - val_loss: 0.6697 - val_acc: 0.7300
#
# Epoch 4/10
#  - 8s - loss: 0.4543 - acc: 0.7960 - val_loss: 0.5118 - val_acc: 0.7800
#
# Epoch 5/10
#  - 8s - loss: 0.4278 - acc: 0.8112 - val_loss: 0.4774 - val_acc: 0.7300
#
# Epoch 6/10
#  - 8s - loss: 0.4147 - acc: 0.8181 - val_loss: 0.4976 - val_acc: 0.7200
#
# Epoch 7/10
#  - 8s - loss: 0.3901 - acc: 0.8206 - val_loss: 0.4122 - val_acc: 0.8200
#
# Epoch 8/10
#  - 8s - loss: 0.3700 - acc: 0.8296 - val_loss: 0.6083 - val_acc: 0.7400
#
# Epoch 9/10
#  - 8s - loss: 0.3488 - acc: 0.8404 - val_loss: 0.4867 - val_acc: 0.8000
#
# Epoch 10/10
#  - 8s - loss: 0.3275 - acc: 0.8532 - val_loss: 0.4646 - val_acc: 0.7600
#
# Test accuracy:
# 0.76
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.7367 - acc: 0.7239 - val_loss: 0.4979 - val_acc: 0.7100
#
# Epoch 2/10
#  - 3s - loss: 0.5463 - acc: 0.7598 - val_loss: 0.4353 - val_acc: 0.8100
#
# Epoch 3/10
#  - 3s - loss: 0.5255 - acc: 0.7646 - val_loss: 0.4393 - val_acc: 0.7800
#
# Epoch 4/10
#  - 3s - loss: 0.4976 - acc: 0.7713 - val_loss: 0.5526 - val_acc: 0.8200
#
# Epoch 5/10
#  - 3s - loss: 0.4886 - acc: 0.7820 - val_loss: 0.4678 - val_acc: 0.7800
#
# Epoch 6/10
#  - 3s - loss: 0.4814 - acc: 0.7806 - val_loss: 0.4773 - val_acc: 0.7800
#
# Epoch 7/10
#  - 3s - loss: 0.4502 - acc: 0.7901 - val_loss: 0.4386 - val_acc: 0.8100
#
# Epoch 8/10
#  - 3s - loss: 0.4353 - acc: 0.7940 - val_loss: 0.4695 - val_acc: 0.8200
#
# Epoch 9/10
#  - 3s - loss: 0.4258 - acc: 0.8006 - val_loss: 0.5252 - val_acc: 0.7700
#
# Epoch 10/10
#  - 3s - loss: 0.4105 - acc: 0.8015 - val_loss: 0.4623 - val_acc: 0.8200
#
# Test accuracy:
# 0.82
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.7997 - acc: 0.7157 - val_loss: 0.5771 - val_acc: 0.7800
#
# Epoch 2/10
#  - 4s - loss: 0.5818 - acc: 0.7520 - val_loss: 0.4447 - val_acc: 0.7900
#
# Epoch 3/10
#  - 4s - loss: 0.5617 - acc: 0.7581 - val_loss: 0.4515 - val_acc: 0.8000
#
# Epoch 4/10
#  - 4s - loss: 0.5700 - acc: 0.7515 - val_loss: 0.5292 - val_acc: 0.7900
#
# Epoch 5/10
#  - 4s - loss: 0.5558 - acc: 0.7644 - val_loss: 0.4809 - val_acc: 0.8100
#
# Epoch 6/10
#  - 4s - loss: 0.5424 - acc: 0.7687 - val_loss: 0.5832 - val_acc: 0.7600
#
# Epoch 7/10
#  - 4s - loss: 0.5344 - acc: 0.7763 - val_loss: 0.5925 - val_acc: 0.7700
#
# Epoch 8/10
#  - 4s - loss: 0.5174 - acc: 0.7742 - val_loss: 0.5036 - val_acc: 0.8200
#
# Epoch 9/10
#  - 4s - loss: 0.5181 - acc: 0.7818 - val_loss: 0.5397 - val_acc: 0.7700
#
# Epoch 10/10
#  - 4s - loss: 0.5042 - acc: 0.7868 - val_loss: 0.4807 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.8167 - acc: 0.7256 - val_loss: 0.5760 - val_acc: 0.7300
#
# Epoch 2/10
#  - 3s - loss: 0.5433 - acc: 0.7581 - val_loss: 0.4516 - val_acc: 0.7700
#
# Epoch 3/10
#  - 3s - loss: 0.5095 - acc: 0.7722 - val_loss: 0.4937 - val_acc: 0.7900
#
# Epoch 4/10
#  - 3s - loss: 0.5092 - acc: 0.7724 - val_loss: 0.4502 - val_acc: 0.8100
#
# Epoch 5/10
#  - 3s - loss: 0.4803 - acc: 0.7811 - val_loss: 0.4592 - val_acc: 0.8200
#
# Epoch 6/10
#  - 3s - loss: 0.4736 - acc: 0.7905 - val_loss: 0.5477 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.4482 - acc: 0.7883 - val_loss: 0.4167 - val_acc: 0.7900
#
# Epoch 8/10
#  - 3s - loss: 0.4410 - acc: 0.7993 - val_loss: 0.4319 - val_acc: 0.8100
#
# Epoch 9/10
#  - 3s - loss: 0.4270 - acc: 0.7991 - val_loss: 0.5857 - val_acc: 0.7500
#
# Epoch 10/10
#  - 3s - loss: 0.4246 - acc: 0.8062 - val_loss: 0.5075 - val_acc: 0.7600
#
# Test accuracy:
# 0.76
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.6569 - acc: 0.7393 - val_loss: 0.4925 - val_acc: 0.7700
#
# Epoch 2/10
#  - 4s - loss: 0.5226 - acc: 0.7600 - val_loss: 0.4489 - val_acc: 0.7900
#
# Epoch 3/10
#  - 4s - loss: 0.5070 - acc: 0.7669 - val_loss: 0.5070 - val_acc: 0.7600
#
# Epoch 4/10
#  - 4s - loss: 0.4876 - acc: 0.7765 - val_loss: 0.5034 - val_acc: 0.7900
#
# Epoch 5/10
#  - 4s - loss: 0.4773 - acc: 0.7767 - val_loss: 0.4309 - val_acc: 0.8000
#
# Epoch 6/10
#  - 4s - loss: 0.4689 - acc: 0.7930 - val_loss: 0.4676 - val_acc: 0.8100
#
# Epoch 7/10
#  - 4s - loss: 0.4598 - acc: 0.7995 - val_loss: 0.5527 - val_acc: 0.7600
#
# Epoch 8/10
#  - 4s - loss: 0.4499 - acc: 0.7972 - val_loss: 0.5310 - val_acc: 0.7600
#
# Epoch 9/10
#  - 4s - loss: 0.4396 - acc: 0.8062 - val_loss: 0.5125 - val_acc: 0.7700
#
# Epoch 10/10
#  - 4s - loss: 0.4263 - acc: 0.8066 - val_loss: 0.4677 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.8170 - acc: 0.7226 - val_loss: 0.5286 - val_acc: 0.7500
#
# Epoch 2/10
#  - 4s - loss: 0.5250 - acc: 0.7598 - val_loss: 0.5279 - val_acc: 0.7400
#
# Epoch 3/10
#  - 4s - loss: 0.4848 - acc: 0.7871 - val_loss: 0.5216 - val_acc: 0.7600
#
# Epoch 4/10
#  - 4s - loss: 0.4903 - acc: 0.7875 - val_loss: 0.4733 - val_acc: 0.7400
#
# Epoch 5/10
#  - 4s - loss: 0.4745 - acc: 0.7914 - val_loss: 0.5143 - val_acc: 0.7900
#
# Epoch 6/10
#  - 4s - loss: 0.4607 - acc: 0.7965 - val_loss: 0.4628 - val_acc: 0.7500
#
# Epoch 7/10
#  - 4s - loss: 0.4477 - acc: 0.7999 - val_loss: 0.4457 - val_acc: 0.8000
#
# Epoch 8/10
#  - 4s - loss: 0.4460 - acc: 0.8004 - val_loss: 0.4900 - val_acc: 0.8000
#
# Epoch 9/10
#  - 4s - loss: 0.4265 - acc: 0.8103 - val_loss: 0.4687 - val_acc: 0.7800
#
# Epoch 10/10
#  - 4s - loss: 0.4269 - acc: 0.8096 - val_loss: 0.4798 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.8850 - acc: 0.7035 - val_loss: 0.4933 - val_acc: 0.7400
#
# Epoch 2/10
#  - 5s - loss: 0.5817 - acc: 0.7469 - val_loss: 0.4271 - val_acc: 0.7700
#
# Epoch 3/10
#  - 5s - loss: 0.5255 - acc: 0.7643 - val_loss: 0.5108 - val_acc: 0.7900
#
# Epoch 4/10
#  - 5s - loss: 0.4975 - acc: 0.7756 - val_loss: 0.4721 - val_acc: 0.7700
#
# Epoch 5/10
#  - 5s - loss: 0.4866 - acc: 0.7857 - val_loss: 0.5127 - val_acc: 0.7700
#
# Epoch 6/10
#  - 5s - loss: 0.4739 - acc: 0.7942 - val_loss: 0.4961 - val_acc: 0.7400
#
# Epoch 7/10
#  - 5s - loss: 0.4583 - acc: 0.7917 - val_loss: 0.7277 - val_acc: 0.6300
#
# Epoch 8/10
#  - 5s - loss: 0.4481 - acc: 0.7896 - val_loss: 0.5015 - val_acc: 0.7900
#
# Epoch 9/10
#  - 5s - loss: 0.4420 - acc: 0.8020 - val_loss: 0.4412 - val_acc: 0.7700
#
# Epoch 10/10
#  - 5s - loss: 0.4139 - acc: 0.8071 - val_loss: 0.5088 - val_acc: 0.7500
#
# Test accuracy:
# 0.75
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.0169 - acc: 0.7210 - val_loss: 0.4879 - val_acc: 0.7800
#
# Epoch 2/10
#  - 3s - loss: 0.4811 - acc: 0.7816 - val_loss: 0.5901 - val_acc: 0.7300
#
# Epoch 3/10
#  - 3s - loss: 0.4354 - acc: 0.8059 - val_loss: 0.5104 - val_acc: 0.8100
#
# Epoch 4/10
#  - 3s - loss: 0.4130 - acc: 0.8062 - val_loss: 0.5636 - val_acc: 0.7800
#
# Epoch 5/10
#  - 3s - loss: 0.3809 - acc: 0.8188 - val_loss: 0.5302 - val_acc: 0.8100
#
# Epoch 6/10
#  - 3s - loss: 0.3538 - acc: 0.8278 - val_loss: 0.6302 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.3307 - acc: 0.8409 - val_loss: 0.4981 - val_acc: 0.8000
#
# Epoch 8/10
#  - 3s - loss: 0.3075 - acc: 0.8518 - val_loss: 0.6076 - val_acc: 0.7500
#
# Epoch 9/10
#  - 3s - loss: 0.2847 - acc: 0.8615 - val_loss: 0.5608 - val_acc: 0.7900
#
# Epoch 10/10
#  - 3s - loss: 0.2686 - acc: 0.8744 - val_loss: 0.6560 - val_acc: 0.7500
#
# Test accuracy:
# 0.75
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.6696 - acc: 0.7193 - val_loss: 0.5738 - val_acc: 0.7500
#
# Epoch 2/10
#  - 3s - loss: 0.5354 - acc: 0.7460 - val_loss: 0.4598 - val_acc: 0.7800
#
# Epoch 3/10
#  - 3s - loss: 0.5215 - acc: 0.7442 - val_loss: 0.5018 - val_acc: 0.7500
#
# Epoch 4/10
#  - 3s - loss: 0.4875 - acc: 0.7650 - val_loss: 0.4929 - val_acc: 0.7700
#
# Epoch 5/10
#  - 3s - loss: 0.4690 - acc: 0.7770 - val_loss: 0.4484 - val_acc: 0.8000
#
# Epoch 6/10
#  - 3s - loss: 0.4565 - acc: 0.7940 - val_loss: 0.4589 - val_acc: 0.8200
#
# Epoch 7/10
#  - 3s - loss: 0.4457 - acc: 0.7887 - val_loss: 0.4741 - val_acc: 0.8200
#
# Epoch 8/10
#  - 3s - loss: 0.4444 - acc: 0.7979 - val_loss: 0.4512 - val_acc: 0.8200
#
# Epoch 9/10
#  - 3s - loss: 0.4119 - acc: 0.8043 - val_loss: 0.5091 - val_acc: 0.8000
#
# Epoch 10/10
#  - 3s - loss: 0.4047 - acc: 0.8027 - val_loss: 0.4343 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.7641 - acc: 0.7283 - val_loss: 0.4601 - val_acc: 0.7900
#
# Epoch 2/10
#  - 3s - loss: 0.5668 - acc: 0.7520 - val_loss: 0.4852 - val_acc: 0.7500
#
# Epoch 3/10
#  - 3s - loss: 0.5222 - acc: 0.7678 - val_loss: 0.4638 - val_acc: 0.7700
#
# Epoch 4/10
#  - 3s - loss: 0.4848 - acc: 0.7719 - val_loss: 0.4485 - val_acc: 0.7700
#
# Epoch 5/10
#  - 3s - loss: 0.4772 - acc: 0.7825 - val_loss: 0.4757 - val_acc: 0.7700
#
# Epoch 6/10
#  - 3s - loss: 0.4610 - acc: 0.7908 - val_loss: 0.4905 - val_acc: 0.7600
#
# Epoch 7/10
#  - 3s - loss: 0.4459 - acc: 0.8007 - val_loss: 0.4434 - val_acc: 0.8000
#
# Epoch 8/10
#  - 3s - loss: 0.4228 - acc: 0.8073 - val_loss: 0.4577 - val_acc: 0.8000
#
# Epoch 9/10
#  - 3s - loss: 0.4107 - acc: 0.8115 - val_loss: 0.4288 - val_acc: 0.7800
#
# Epoch 10/10
#  - 3s - loss: 0.3894 - acc: 0.8245 - val_loss: 0.4131 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.0019 - acc: 0.7303 - val_loss: 0.5215 - val_acc: 0.7600
#
# Epoch 2/10
#  - 3s - loss: 0.5987 - acc: 0.7455 - val_loss: 0.4975 - val_acc: 0.7800
#
# Epoch 3/10
#  - 3s - loss: 0.5660 - acc: 0.7506 - val_loss: 0.4672 - val_acc: 0.8000
#
# Epoch 4/10
#  - 3s - loss: 0.5244 - acc: 0.7604 - val_loss: 0.5158 - val_acc: 0.8100
#
# Epoch 5/10
#  - 3s - loss: 0.5308 - acc: 0.7575 - val_loss: 0.4879 - val_acc: 0.7800
#
# Epoch 6/10
#  - 3s - loss: 0.4936 - acc: 0.7643 - val_loss: 0.4371 - val_acc: 0.8300
#
# Epoch 7/10
#  - 3s - loss: 0.4913 - acc: 0.7685 - val_loss: 0.4517 - val_acc: 0.8100
#
# Epoch 8/10
#  - 3s - loss: 0.4828 - acc: 0.7779 - val_loss: 0.5343 - val_acc: 0.7800
#
# Epoch 9/10
#  - 3s - loss: 0.4724 - acc: 0.7910 - val_loss: 0.5770 - val_acc: 0.7700
#
# Epoch 10/10
#  - 3s - loss: 0.4692 - acc: 0.7970 - val_loss: 0.4372 - val_acc: 0.8600
#
# Test accuracy:
# 0.86
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.9206 - acc: 0.6994 - val_loss: 0.4144 - val_acc: 0.7800
#
# Epoch 2/10
#  - 3s - loss: 0.6416 - acc: 0.7326 - val_loss: 0.4381 - val_acc: 0.7300
#
# Epoch 3/10
#  - 3s - loss: 0.5867 - acc: 0.7414 - val_loss: 0.4476 - val_acc: 0.8000
#
# Epoch 4/10
#  - 3s - loss: 0.5606 - acc: 0.7579 - val_loss: 0.6009 - val_acc: 0.7800
#
# Epoch 5/10
#  - 3s - loss: 0.5603 - acc: 0.7559 - val_loss: 0.4310 - val_acc: 0.7900
#
# Epoch 6/10
#  - 3s - loss: 0.5294 - acc: 0.7591 - val_loss: 0.4614 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.5071 - acc: 0.7680 - val_loss: 0.4411 - val_acc: 0.8100
#
# Epoch 8/10
#  - 3s - loss: 0.5032 - acc: 0.7797 - val_loss: 0.4912 - val_acc: 0.8200
#
# Epoch 9/10
#  - 3s - loss: 0.4855 - acc: 0.7878 - val_loss: 0.4166 - val_acc: 0.8200
#
# Epoch 10/10
#  - 3s - loss: 0.4792 - acc: 0.7747 - val_loss: 0.3995 - val_acc: 0.8600
#
# Test accuracy:
# 0.86
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.1818 - acc: 0.6762 - val_loss: 0.5071 - val_acc: 0.7400
#
# Epoch 2/10
#  - 3s - loss: 0.6857 - acc: 0.6950 - val_loss: 0.5856 - val_acc: 0.6200
#
# Epoch 3/10
#  - 3s - loss: 0.6301 - acc: 0.7203 - val_loss: 0.4798 - val_acc: 0.8000
#
# Epoch 4/10
#  - 3s - loss: 0.5952 - acc: 0.7501 - val_loss: 0.5102 - val_acc: 0.7800
#
# Epoch 5/10
#  - 3s - loss: 0.5819 - acc: 0.7510 - val_loss: 0.5074 - val_acc: 0.7900
#
# Epoch 6/10
#  - 3s - loss: 0.5611 - acc: 0.7566 - val_loss: 0.4994 - val_acc: 0.7600
#
# Epoch 7/10
#  - 3s - loss: 0.5399 - acc: 0.7575 - val_loss: 0.5476 - val_acc: 0.8100
#
# Epoch 8/10
#  - 3s - loss: 0.5398 - acc: 0.7600 - val_loss: 0.5248 - val_acc: 0.7700
#
# Epoch 9/10
#  - 3s - loss: 0.5250 - acc: 0.7597 - val_loss: 0.5581 - val_acc: 0.7500
#
# Epoch 10/10
#  - 3s - loss: 0.5213 - acc: 0.7752 - val_loss: 0.4681 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.7342 - acc: 0.6851 - val_loss: 0.5820 - val_acc: 0.7700
#
# Epoch 2/10
#  - 3s - loss: 0.5760 - acc: 0.7244 - val_loss: 0.4292 - val_acc: 0.7600
#
# Epoch 3/10
#  - 3s - loss: 0.5434 - acc: 0.7460 - val_loss: 0.4125 - val_acc: 0.8100
#
# Epoch 4/10
#  - 3s - loss: 0.5262 - acc: 0.7403 - val_loss: 0.5438 - val_acc: 0.7900
#
# Epoch 5/10
#  - 3s - loss: 0.5289 - acc: 0.7442 - val_loss: 0.4624 - val_acc: 0.7200
#
# Epoch 6/10
#  - 3s - loss: 0.5104 - acc: 0.7589 - val_loss: 0.4814 - val_acc: 0.8100
#
# Epoch 7/10
#  - 3s - loss: 0.4956 - acc: 0.7705 - val_loss: 0.4548 - val_acc: 0.7900
#
# Epoch 8/10
#  - 3s - loss: 0.4946 - acc: 0.7777 - val_loss: 0.5055 - val_acc: 0.8000
#
# Epoch 9/10
#  - 3s - loss: 0.4824 - acc: 0.7832 - val_loss: 0.5083 - val_acc: 0.8100
#
# Epoch 10/10
#  - 3s - loss: 0.4545 - acc: 0.7919 - val_loss: 0.4603 - val_acc: 0.8200
#
# Test accuracy:
# 0.82
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.2478 - acc: 0.6947 - val_loss: 0.4254 - val_acc: 0.7300
#
# Epoch 2/10
#  - 3s - loss: 0.7743 - acc: 0.7069 - val_loss: 0.4396 - val_acc: 0.7700
#
# Epoch 3/10
#  - 3s - loss: 0.6963 - acc: 0.7203 - val_loss: 0.4549 - val_acc: 0.8200
#
# Epoch 4/10
#  - 3s - loss: 0.6637 - acc: 0.7187 - val_loss: 0.5031 - val_acc: 0.8100
#
# Epoch 5/10
#  - 3s - loss: 0.5802 - acc: 0.7488 - val_loss: 0.4396 - val_acc: 0.8000
#
# Epoch 6/10
#  - 3s - loss: 0.5718 - acc: 0.7453 - val_loss: 0.4328 - val_acc: 0.8200
#
# Epoch 7/10
#  - 3s - loss: 0.5469 - acc: 0.7646 - val_loss: 0.4527 - val_acc: 0.7700
#
# Epoch 8/10
#  - 3s - loss: 0.5287 - acc: 0.7607 - val_loss: 0.4251 - val_acc: 0.7800
#
# Epoch 9/10
#  - 3s - loss: 0.5070 - acc: 0.7694 - val_loss: 0.4213 - val_acc: 0.7900
#
# Epoch 10/10
#  - 3s - loss: 0.5013 - acc: 0.7644 - val_loss: 0.4653 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.6684 - acc: 0.7386 - val_loss: 0.4291 - val_acc: 0.8200
#
# Epoch 2/10
#  - 3s - loss: 0.5167 - acc: 0.7705 - val_loss: 0.4487 - val_acc: 0.7700
#
# Epoch 3/10
#  - 3s - loss: 0.4984 - acc: 0.7726 - val_loss: 0.4213 - val_acc: 0.7800
#
# Epoch 4/10
#  - 3s - loss: 0.4792 - acc: 0.7846 - val_loss: 0.4706 - val_acc: 0.7800
#
# Epoch 5/10
#  - 3s - loss: 0.4625 - acc: 0.7933 - val_loss: 0.5723 - val_acc: 0.7900
#
# Epoch 6/10
#  - 3s - loss: 0.4690 - acc: 0.7896 - val_loss: 0.4225 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.4469 - acc: 0.7965 - val_loss: 0.5678 - val_acc: 0.7800
#
# Epoch 8/10
#  - 3s - loss: 0.4296 - acc: 0.7984 - val_loss: 0.5341 - val_acc: 0.7800
#
# Epoch 9/10
#  - 3s - loss: 0.4176 - acc: 0.8039 - val_loss: 0.6013 - val_acc: 0.7100
#
# Epoch 10/10
#  - 3s - loss: 0.4060 - acc: 0.8057 - val_loss: 0.5020 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.0152 - acc: 0.6975 - val_loss: 0.4487 - val_acc: 0.7700
#
# Epoch 2/10
#  - 3s - loss: 0.6205 - acc: 0.7198 - val_loss: 0.4574 - val_acc: 0.7600
#
# Epoch 3/10
#  - 3s - loss: 0.5868 - acc: 0.7634 - val_loss: 0.4397 - val_acc: 0.7900
#
# Epoch 4/10
#  - 3s - loss: 0.5609 - acc: 0.7715 - val_loss: 0.4555 - val_acc: 0.8000
#
# Epoch 5/10
#  - 3s - loss: 0.5327 - acc: 0.7804 - val_loss: 0.5279 - val_acc: 0.7900
#
# Epoch 6/10
#  - 3s - loss: 0.5240 - acc: 0.7871 - val_loss: 0.4667 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.5379 - acc: 0.7875 - val_loss: 0.4690 - val_acc: 0.8200
#
# Epoch 8/10
#  - 3s - loss: 0.5217 - acc: 0.7862 - val_loss: 0.4680 - val_acc: 0.8000
#
# Epoch 9/10
#  - 3s - loss: 0.5110 - acc: 0.7832 - val_loss: 0.4104 - val_acc: 0.8300
#
# Epoch 10/10
#  - 3s - loss: 0.5100 - acc: 0.7860 - val_loss: 0.5014 - val_acc: 0.7500
#
# Test accuracy:
# 0.75
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.9452 - acc: 0.7056 - val_loss: 0.4625 - val_acc: 0.8000
#
# Epoch 2/10
#  - 3s - loss: 0.6101 - acc: 0.7343 - val_loss: 0.4714 - val_acc: 0.7600
#
# Epoch 3/10
#  - 3s - loss: 0.5484 - acc: 0.7363 - val_loss: 0.4649 - val_acc: 0.7500
#
# Epoch 4/10
#  - 3s - loss: 0.5208 - acc: 0.7506 - val_loss: 0.5286 - val_acc: 0.7200
#
# Epoch 5/10
#  - 3s - loss: 0.5160 - acc: 0.7713 - val_loss: 0.4241 - val_acc: 0.7900
#
# Epoch 6/10
#  - 3s - loss: 0.5067 - acc: 0.7786 - val_loss: 0.4480 - val_acc: 0.8300
#
# Epoch 7/10
#  - 3s - loss: 0.4891 - acc: 0.7866 - val_loss: 0.4482 - val_acc: 0.7800
#
# Epoch 8/10
#  - 3s - loss: 0.4811 - acc: 0.7850 - val_loss: 0.4918 - val_acc: 0.7700
#
# Epoch 9/10
#  - 3s - loss: 0.4809 - acc: 0.7889 - val_loss: 0.4749 - val_acc: 0.7800
#
# Epoch 10/10
#  - 3s - loss: 0.4582 - acc: 0.7928 - val_loss: 0.4293 - val_acc: 0.8200
#
# Test accuracy:
# 0.82
# 100%|██████████| 30/30 [22:19<00:00, 32.64s/it, best loss: -0.86]
# Tempo para otimização: 22.351175713539124 minutos
# Summary of the best model: -----------------------
# Evalutation of best performing model:
# 100/100 [==============================] - 0s 443us/step
# [0.4372208499908447, 0.86]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_23 (InputLayer)        (None, 64, 64, 5, 1)      0
# _________________________________________________________________
# conv3d_23 (Conv3D)           (None, 62, 62, 3, 32)     896
# _________________________________________________________________
# max_pooling3d_23 (MaxPooling (None, 31, 31, 1, 32)     0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 30752)             0
# _________________________________________________________________
# dense_67 (Dense)             (None, 64)                1968192
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_68 (Dense)             (None, 16)                1040
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_69 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 1,970,145
# Trainable params: 1,970,145
# Non-trainable params: 0
# _________________________________________________________________
# None
# Conv 1: 32 unidades
# Dense 1: 96 unidades
# Dense 2: 16 unidades
# Dropout 1: 0.07176927609418894
# Dropout 2: 0.2837032463233716
