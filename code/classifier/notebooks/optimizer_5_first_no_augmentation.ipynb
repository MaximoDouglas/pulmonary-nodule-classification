# %% [markdown]
# # Colab config

# %%
from google.colab import drive
drive.mount('drive', force_remount=True)

# %%
# !pip install hyperas

# %% [markdown]
# ## Imports

# %%
import os

import time

import gc

import numpy as np

from scipy import interp

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, roc_curve, auc

from keras import backend as K
from keras import optimizers
from keras.layers import Conv3D, MaxPool3D, Flatten, Dense, Dropout, Input
from keras.losses import binary_crossentropy
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.utils.vis_utils import plot_model, model_to_dot
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## GPU configuration

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 1
set_session(tf.Session(config=config))
session = tf.Session(config=config)

# %% [markdown]
# # Hyperparameters optimization
#
# Func **data()** required by Hyperas. It must return 4 arrays X_train, Y_train, X_test, Y_test.
#
# The data for optimization are on four numpy files, generated with the notebook **import_images.ipynb**.

# %%
'''5-first-no-augmentation'''

def data():
  prefix = "/content/drive/My Drive/Pesquisa - Dicom images/data/no_aug_nps/data-5-first"
  X_train = np.load(prefix + "/X_train.npy")
  X_test = np.load(prefix + "/X_test.npy")
  Y_train = np.load(prefix + "/Y_train.npy")
  Y_test = np.load(prefix + "/Y_test.npy")
  
  return X_train, Y_train, X_test, Y_test

# %% [markdown]
# ## Space of search definition
#
# * **conv_layer1**: [32, 48, 64, 96] unities
# * **dense_layer1**: [32, 64, 128, 256] unities
# * **dense_layer2**: [8, 16, 24, 32] unities
# * **dropout** on dense layers: between 0 and 0.5

# %%
conv1 = [32, 48, 64, 96]
dense1 = [64, 96, 128]
dense2 = [16, 24, 32]
    
def model(X_train, Y_train, X_test, Y_test):
    conv1 = {{choice([32, 48, 64, 96])}}
    dense1 = {{choice([32, 64, 128])}}
    dense2 = {{choice([16, 24, 32])}}
    
    input_layer = Input(X_train.shape[1:5])
    
    conv_layer1 = Conv3D(conv1, kernel_size=(3, 3, 3), activation='relu')(input_layer)
    pooling_layer1 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer1)
    
    flatten_layer = Flatten()(pooling_layer1)
    
    dense_layer1 = Dense(dense1, activation='relu')(flatten_layer)
    dense_layer1 = Dropout({{uniform(0, .5)}})(dense_layer1)
    
    dense_layer2 = Dense(dense2, activation='relu')(dense_layer1)
    dense_layer2 = Dropout({{uniform(0, .5)}})(dense_layer2)
    
    output_layer = Dense(units=1, activation='sigmoid')(dense_layer2)
    
    model = Model(inputs=input_layer, outputs=output_layer)
    
    opt = optimizers.RMSprop(lr=0.0001)
    
    model.compile(loss=binary_crossentropy, optimizer=opt, metrics=['acc'])
    
    model.fit(X_train, Y_train,
              batch_size=128,
              epochs=10,
              verbose=2,
              validation_data=(X_test, Y_test)
              )
    
    score, acc = model.evaluate(X_test, Y_test, verbose=0)
    
    print('Test accuracy:', acc)
    
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %% [markdown]
# ## Otimization

# %%
X_train, Y_train, X_test, Y_test = data()

start = time.time()

best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=30,
                                      trials=Trials(),
                                      verbose=False,
                                      notebook_name='drive/My Drive/Pesquisa - Dicom images/notebooks/optimizer_5_first')
end = time.time()

print("Time on optimization:", (end - start)/60, "minutes")

print()
print('Summary of the best model: -----------------------')

print("Evalutation of best performing model:")
print(best_model.evaluate(X_test, Y_test))

print(best_model.summary())

c1 = conv1[best_run['conv1']]
d1 = dense1[best_run['dense1']]
d2 = dense2[best_run['dense2']]
drop1 = best_run['Dropout']
drop2 = best_run['Dropout_1']

print('Conv 1:', c1, 'unidades')
print('Dense 1:', d1, 'unidades')
print('Dense 2:', d2, 'unidades')
print('Dropout 1:', drop1)
print('Dropout 2:', drop2)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 1.2942 - acc: 0.6662 - val_loss: 0.7666 - val_acc: 0.7000
#
# Epoch 2/10
#  - 0s - loss: 0.6526 - acc: 0.7609 - val_loss: 0.4443 - val_acc: 0.7700
#
# Epoch 3/10
#  - 0s - loss: 0.6509 - acc: 0.7724 - val_loss: 0.5451 - val_acc: 0.7300
#
# Epoch 4/10
#  - 0s - loss: 0.6251 - acc: 0.7506 - val_loss: 0.5614 - val_acc: 0.7000
#
# Epoch 5/10
#  - 0s - loss: 0.5503 - acc: 0.7826 - val_loss: 0.4713 - val_acc: 0.7500
#
# Epoch 6/10
#  - 0s - loss: 0.4966 - acc: 0.7813 - val_loss: 0.6290 - val_acc: 0.7300
#
# Epoch 7/10
#  - 0s - loss: 0.4549 - acc: 0.7980 - val_loss: 0.6011 - val_acc: 0.7300
#
# Epoch 8/10
#  - 0s - loss: 0.4905 - acc: 0.7928 - val_loss: 0.5745 - val_acc: 0.7100
#
# Epoch 9/10
#  - 0s - loss: 0.4420 - acc: 0.8031 - val_loss: 0.4928 - val_acc: 0.7200
#
# Epoch 10/10
#  - 0s - loss: 0.4232 - acc: 0.8159 - val_loss: 0.4939 - val_acc: 0.7500
#
# Test accuracy:
# 0.75
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 1.1431 - acc: 0.6982 - val_loss: 0.5569 - val_acc: 0.6400
#
# Epoch 2/10
#  - 0s - loss: 0.4985 - acc: 0.7609 - val_loss: 0.5822 - val_acc: 0.5800
#
# Epoch 3/10
#  - 0s - loss: 0.4780 - acc: 0.7980 - val_loss: 0.6846 - val_acc: 0.5800
#
# Epoch 4/10
#  - 0s - loss: 0.4549 - acc: 0.7890 - val_loss: 0.7003 - val_acc: 0.5900
#
# Epoch 5/10
#  - 0s - loss: 0.4624 - acc: 0.7852 - val_loss: 0.6902 - val_acc: 0.5800
#
# Epoch 6/10
#  - 0s - loss: 0.4106 - acc: 0.7980 - val_loss: 0.6051 - val_acc: 0.6600
#
# Epoch 7/10
#  - 0s - loss: 0.4298 - acc: 0.8069 - val_loss: 0.6852 - val_acc: 0.6900
#
# Epoch 8/10
#  - 0s - loss: 0.4255 - acc: 0.7980 - val_loss: 0.6387 - val_acc: 0.6200
#
# Epoch 9/10
#  - 0s - loss: 0.4022 - acc: 0.7813 - val_loss: 0.5258 - val_acc: 0.6700
#
# Epoch 10/10
#  - 0s - loss: 0.3511 - acc: 0.8325 - val_loss: 0.6331 - val_acc: 0.7100
#
# Test accuracy:
# 0.71
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 2.2222 - acc: 0.6701 - val_loss: 2.3607 - val_acc: 0.5200
#
# Epoch 2/10
#  - 1s - loss: 0.9812 - acc: 0.7596 - val_loss: 0.6421 - val_acc: 0.6900
#
# Epoch 3/10
#  - 1s - loss: 0.6382 - acc: 0.7711 - val_loss: 0.6221 - val_acc: 0.6900
#
# Epoch 4/10
#  - 1s - loss: 0.6370 - acc: 0.7698 - val_loss: 0.6180 - val_acc: 0.6600
#
# Epoch 5/10
#  - 1s - loss: 0.4788 - acc: 0.7813 - val_loss: 0.5950 - val_acc: 0.6400
#
# Epoch 6/10
#  - 1s - loss: 0.4941 - acc: 0.7826 - val_loss: 0.6599 - val_acc: 0.6200
#
# Epoch 7/10
#  - 1s - loss: 0.5593 - acc: 0.7685 - val_loss: 0.6500 - val_acc: 0.6200
#
# Epoch 8/10
#  - 1s - loss: 0.5013 - acc: 0.7890 - val_loss: 0.4891 - val_acc: 0.7600
#
# Epoch 9/10
#  - 1s - loss: 0.4985 - acc: 0.7801 - val_loss: 0.4866 - val_acc: 0.6900
#
# Epoch 10/10
#  - 1s - loss: 0.4838 - acc: 0.7801 - val_loss: 0.5295 - val_acc: 0.6500
#
# Test accuracy:
# 0.65
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 2.3494 - acc: 0.7059 - val_loss: 0.9026 - val_acc: 0.7300
#
# Epoch 2/10
#  - 0s - loss: 1.1558 - acc: 0.7455 - val_loss: 0.5451 - val_acc: 0.7600
#
# Epoch 3/10
#  - 0s - loss: 0.8855 - acc: 0.7647 - val_loss: 0.6608 - val_acc: 0.7400
#
# Epoch 4/10
#  - 0s - loss: 0.7494 - acc: 0.7826 - val_loss: 0.5178 - val_acc: 0.7400
#
# Epoch 5/10
#  - 0s - loss: 0.6386 - acc: 0.7788 - val_loss: 0.7321 - val_acc: 0.7100
#
# Epoch 6/10
#  - 0s - loss: 0.5934 - acc: 0.7749 - val_loss: 0.4799 - val_acc: 0.7100
#
# Epoch 7/10
#  - 0s - loss: 0.5573 - acc: 0.7609 - val_loss: 0.4584 - val_acc: 0.7300
#
# Epoch 8/10
#  - 0s - loss: 0.5063 - acc: 0.7685 - val_loss: 0.5063 - val_acc: 0.7200
#
# Epoch 9/10
#  - 0s - loss: 0.4433 - acc: 0.7698 - val_loss: 0.4787 - val_acc: 0.6700
#
# Epoch 10/10
#  - 0s - loss: 0.4429 - acc: 0.7609 - val_loss: 0.6097 - val_acc: 0.6600
#
# Test accuracy:
# 0.66
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.2638 - acc: 0.7174 - val_loss: 2.1039 - val_acc: 0.5400
#
# Epoch 2/10
#  - 1s - loss: 0.6768 - acc: 0.7813 - val_loss: 0.5759 - val_acc: 0.7500
#
# Epoch 3/10
#  - 1s - loss: 0.4842 - acc: 0.8069 - val_loss: 0.5525 - val_acc: 0.6000
#
# Epoch 4/10
#  - 1s - loss: 0.4909 - acc: 0.7967 - val_loss: 1.5522 - val_acc: 0.6500
#
# Epoch 5/10
#  - 1s - loss: 0.4913 - acc: 0.8120 - val_loss: 0.9021 - val_acc: 0.5900
#
# Epoch 6/10
#  - 1s - loss: 0.4462 - acc: 0.8133 - val_loss: 0.6777 - val_acc: 0.7100
#
# Epoch 7/10
#  - 1s - loss: 0.4404 - acc: 0.8159 - val_loss: 0.5945 - val_acc: 0.6200
#
# Epoch 8/10
#  - 1s - loss: 0.4663 - acc: 0.8299 - val_loss: 0.6445 - val_acc: 0.7200
#
# Epoch 9/10
#  - 1s - loss: 0.4295 - acc: 0.8223 - val_loss: 1.6111 - val_acc: 0.6600
#
# Epoch 10/10
#  - 1s - loss: 0.4769 - acc: 0.8095 - val_loss: 0.4931 - val_acc: 0.6800
#
# Test accuracy:
# 0.68
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 2.3651 - acc: 0.6803 - val_loss: 0.8827 - val_acc: 0.7700
#
# Epoch 2/10
#  - 1s - loss: 1.4496 - acc: 0.7455 - val_loss: 0.4977 - val_acc: 0.7600
#
# Epoch 3/10
#  - 1s - loss: 1.0847 - acc: 0.7506 - val_loss: 0.6143 - val_acc: 0.6800
#
# Epoch 4/10
#  - 1s - loss: 0.9595 - acc: 0.7647 - val_loss: 0.7242 - val_acc: 0.6900
#
# Epoch 5/10
#  - 1s - loss: 0.9924 - acc: 0.7801 - val_loss: 0.5682 - val_acc: 0.7400
#
# Epoch 6/10
#  - 1s - loss: 0.7415 - acc: 0.7737 - val_loss: 0.7316 - val_acc: 0.6700
#
# Epoch 7/10
#  - 1s - loss: 0.6382 - acc: 0.7954 - val_loss: 0.6811 - val_acc: 0.6200
#
# Epoch 8/10
#  - 1s - loss: 0.7208 - acc: 0.7839 - val_loss: 0.5516 - val_acc: 0.7100
#
# Epoch 9/10
#  - 1s - loss: 0.6553 - acc: 0.7954 - val_loss: 0.5691 - val_acc: 0.7200
#
# Epoch 10/10
#  - 1s - loss: 0.7383 - acc: 0.7647 - val_loss: 0.5446 - val_acc: 0.7100
#
# Test accuracy:
# 0.71
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 1.1882 - acc: 0.6982 - val_loss: 0.5132 - val_acc: 0.7800
#
# Epoch 2/10
#  - 0s - loss: 0.6791 - acc: 0.7289 - val_loss: 0.7571 - val_acc: 0.7400
#
# Epoch 3/10
#  - 0s - loss: 0.5033 - acc: 0.8107 - val_loss: 0.5063 - val_acc: 0.7400
#
# Epoch 4/10
#  - 0s - loss: 0.5166 - acc: 0.7801 - val_loss: 0.7825 - val_acc: 0.7200
#
# Epoch 5/10
#  - 0s - loss: 0.4874 - acc: 0.8095 - val_loss: 0.5537 - val_acc: 0.7000
#
# Epoch 6/10
#  - 0s - loss: 0.4414 - acc: 0.8005 - val_loss: 0.5619 - val_acc: 0.7800
#
# Epoch 7/10
#  - 0s - loss: 0.4349 - acc: 0.8056 - val_loss: 0.6224 - val_acc: 0.7100
#
# Epoch 8/10
#  - 0s - loss: 0.4293 - acc: 0.8031 - val_loss: 0.5290 - val_acc: 0.7600
#
# Epoch 9/10
#  - 0s - loss: 0.4184 - acc: 0.7992 - val_loss: 0.4611 - val_acc: 0.8100
#
# Epoch 10/10
#  - 0s - loss: 0.3539 - acc: 0.8350 - val_loss: 0.4918 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.5151 - acc: 0.7174 - val_loss: 0.6998 - val_acc: 0.7300
#
# Epoch 2/10
#  - 1s - loss: 0.6306 - acc: 0.8018 - val_loss: 0.6810 - val_acc: 0.6900
#
# Epoch 3/10
#  - 1s - loss: 0.5848 - acc: 0.7877 - val_loss: 0.5464 - val_acc: 0.8200
#
# Epoch 4/10
#  - 1s - loss: 0.4585 - acc: 0.8159 - val_loss: 0.5608 - val_acc: 0.6900
#
# Epoch 5/10
#  - 1s - loss: 0.4252 - acc: 0.8171 - val_loss: 0.6868 - val_acc: 0.6500
#
# Epoch 6/10
#  - 1s - loss: 0.4148 - acc: 0.8338 - val_loss: 1.0705 - val_acc: 0.7100
#
# Epoch 7/10
#  - 1s - loss: 0.4105 - acc: 0.8325 - val_loss: 0.4949 - val_acc: 0.7500
#
# Epoch 8/10
#  - 1s - loss: 0.3869 - acc: 0.8286 - val_loss: 0.4692 - val_acc: 0.7500
#
# Epoch 9/10
#  - 1s - loss: 0.3621 - acc: 0.8389 - val_loss: 0.7958 - val_acc: 0.6200
#
# Epoch 10/10
#  - 1s - loss: 0.2767 - acc: 0.8708 - val_loss: 0.8034 - val_acc: 0.6800
#
# Test accuracy:
# 0.68
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.4155 - acc: 0.6880 - val_loss: 0.5365 - val_acc: 0.7000
#
# Epoch 2/10
#  - 1s - loss: 0.6095 - acc: 0.7762 - val_loss: 0.8201 - val_acc: 0.7500
#
# Epoch 3/10
#  - 1s - loss: 0.5116 - acc: 0.7992 - val_loss: 0.7717 - val_acc: 0.7500
#
# Epoch 4/10
#  - 1s - loss: 0.4923 - acc: 0.7852 - val_loss: 0.6389 - val_acc: 0.7400
#
# Epoch 5/10
#  - 1s - loss: 0.4623 - acc: 0.7762 - val_loss: 0.7124 - val_acc: 0.7700
#
# Epoch 6/10
#  - 1s - loss: 0.4546 - acc: 0.7916 - val_loss: 0.7877 - val_acc: 0.7000
#
# Epoch 7/10
#  - 1s - loss: 0.4292 - acc: 0.8133 - val_loss: 0.5904 - val_acc: 0.7200
#
# Epoch 8/10
#  - 1s - loss: 0.4388 - acc: 0.8120 - val_loss: 0.7334 - val_acc: 0.7300
#
# Epoch 9/10
#  - 1s - loss: 0.3994 - acc: 0.8005 - val_loss: 0.4384 - val_acc: 0.8000
#
# Epoch 10/10
#  - 1s - loss: 0.4091 - acc: 0.8069 - val_loss: 0.5459 - val_acc: 0.6000
#
# Test accuracy:
# 0.6
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.4625 - acc: 0.7430 - val_loss: 0.5960 - val_acc: 0.7100
#
# Epoch 2/10
#  - 1s - loss: 0.5824 - acc: 0.7954 - val_loss: 0.6919 - val_acc: 0.6200
#
# Epoch 3/10
#  - 1s - loss: 0.5050 - acc: 0.8018 - val_loss: 0.4815 - val_acc: 0.8100
#
# Epoch 4/10
#  - 1s - loss: 0.4987 - acc: 0.8056 - val_loss: 0.6800 - val_acc: 0.6400
#
# Epoch 5/10
#  - 1s - loss: 0.4441 - acc: 0.7903 - val_loss: 2.1971 - val_acc: 0.5000
#
# Epoch 6/10
#  - 1s - loss: 0.5906 - acc: 0.7903 - val_loss: 0.7332 - val_acc: 0.5400
#
# Epoch 7/10
#  - 1s - loss: 0.4262 - acc: 0.7916 - val_loss: 0.6696 - val_acc: 0.6300
#
# Epoch 8/10
#  - 1s - loss: 0.3836 - acc: 0.8159 - val_loss: 0.4640 - val_acc: 0.7300
#
# Epoch 9/10
#  - 1s - loss: 0.3914 - acc: 0.8223 - val_loss: 0.8259 - val_acc: 0.7400
#
# Epoch 10/10
#  - 1s - loss: 0.3645 - acc: 0.8299 - val_loss: 0.5483 - val_acc: 0.6900
#
# Test accuracy:
# 0.69
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.1631 - acc: 0.7059 - val_loss: 0.5199 - val_acc: 0.7700
#
# Epoch 2/10
#  - 1s - loss: 0.7228 - acc: 0.7724 - val_loss: 0.8526 - val_acc: 0.7500
#
# Epoch 3/10
#  - 1s - loss: 0.5385 - acc: 0.7954 - val_loss: 0.5545 - val_acc: 0.7700
#
# Epoch 4/10
#  - 1s - loss: 0.4929 - acc: 0.7941 - val_loss: 0.6645 - val_acc: 0.7300
#
# Epoch 5/10
#  - 1s - loss: 0.4985 - acc: 0.8069 - val_loss: 0.5488 - val_acc: 0.7500
#
# Epoch 6/10
#  - 1s - loss: 0.4701 - acc: 0.7903 - val_loss: 0.4883 - val_acc: 0.7400
#
# Epoch 7/10
#  - 1s - loss: 0.4098 - acc: 0.8261 - val_loss: 0.6547 - val_acc: 0.7400
#
# Epoch 8/10
#  - 1s - loss: 0.4070 - acc: 0.8363 - val_loss: 0.9102 - val_acc: 0.6200
#
# Epoch 9/10
#  - 1s - loss: 0.4567 - acc: 0.8286 - val_loss: 0.6449 - val_acc: 0.7700
#
# Epoch 10/10
#  - 1s - loss: 0.3973 - acc: 0.8299 - val_loss: 0.7092 - val_acc: 0.6500
#
# Test accuracy:
# 0.65
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 0.8644 - acc: 0.6790 - val_loss: 0.7420 - val_acc: 0.6800
#
# Epoch 2/10
#  - 0s - loss: 0.5122 - acc: 0.7967 - val_loss: 0.8855 - val_acc: 0.5900
#
# Epoch 3/10
#  - 0s - loss: 0.5002 - acc: 0.7903 - val_loss: 0.5737 - val_acc: 0.7300
#
# Epoch 4/10
#  - 0s - loss: 0.4331 - acc: 0.8095 - val_loss: 0.5119 - val_acc: 0.7300
#
# Epoch 5/10
#  - 0s - loss: 0.4095 - acc: 0.8261 - val_loss: 0.8999 - val_acc: 0.5500
#
# Epoch 6/10
#  - 0s - loss: 0.4206 - acc: 0.8133 - val_loss: 0.5245 - val_acc: 0.6900
#
# Epoch 7/10
#  - 0s - loss: 0.3760 - acc: 0.8171 - val_loss: 0.6416 - val_acc: 0.7100
#
# Epoch 8/10
#  - 0s - loss: 0.3656 - acc: 0.8350 - val_loss: 0.6449 - val_acc: 0.7100
#
# Epoch 9/10
#  - 0s - loss: 0.3505 - acc: 0.8389 - val_loss: 0.7326 - val_acc: 0.6400
#
# Epoch 10/10
#  - 0s - loss: 0.3243 - acc: 0.8478 - val_loss: 0.5343 - val_acc: 0.7500
#
# Test accuracy:
# 0.75
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 3.3607 - acc: 0.6381 - val_loss: 1.0095 - val_acc: 0.7400
#
# Epoch 2/10
#  - 1s - loss: 0.9287 - acc: 0.7967 - val_loss: 0.6739 - val_acc: 0.7200
#
# Epoch 3/10
#  - 1s - loss: 0.6668 - acc: 0.8043 - val_loss: 0.4911 - val_acc: 0.7500
#
# Epoch 4/10
#  - 1s - loss: 0.5190 - acc: 0.8031 - val_loss: 0.5731 - val_acc: 0.7100
#
# Epoch 5/10
#  - 1s - loss: 0.4575 - acc: 0.7992 - val_loss: 0.4771 - val_acc: 0.7500
#
# Epoch 6/10
#  - 1s - loss: 0.4462 - acc: 0.8095 - val_loss: 1.0569 - val_acc: 0.7300
#
# Epoch 7/10
#  - 1s - loss: 0.4333 - acc: 0.8210 - val_loss: 0.5181 - val_acc: 0.7300
#
# Epoch 8/10
#  - 1s - loss: 0.3988 - acc: 0.8107 - val_loss: 0.7194 - val_acc: 0.6800
#
# Epoch 9/10
#  - 1s - loss: 0.4199 - acc: 0.8171 - val_loss: 0.9437 - val_acc: 0.7400
#
# Epoch 10/10
#  - 1s - loss: 0.4797 - acc: 0.8056 - val_loss: 0.5154 - val_acc: 0.7200
#
# Test accuracy:
# 0.72
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.2858 - acc: 0.6880 - val_loss: 0.6026 - val_acc: 0.7600
#
# Epoch 2/10
#  - 0s - loss: 0.7028 - acc: 0.7558 - val_loss: 0.5325 - val_acc: 0.7700
#
# Epoch 3/10
#  - 0s - loss: 0.5671 - acc: 0.7903 - val_loss: 0.5805 - val_acc: 0.7500
#
# Epoch 4/10
#  - 0s - loss: 0.4982 - acc: 0.7826 - val_loss: 0.9658 - val_acc: 0.6800
#
# Epoch 5/10
#  - 0s - loss: 0.5123 - acc: 0.7839 - val_loss: 0.8348 - val_acc: 0.6400
#
# Epoch 6/10
#  - 0s - loss: 0.4685 - acc: 0.8056 - val_loss: 0.5900 - val_acc: 0.7100
#
# Epoch 7/10
#  - 0s - loss: 0.5183 - acc: 0.7967 - val_loss: 0.4754 - val_acc: 0.7600
#
# Epoch 8/10
#  - 0s - loss: 0.4007 - acc: 0.8056 - val_loss: 0.5324 - val_acc: 0.7300
#
# Epoch 9/10
#  - 0s - loss: 0.4714 - acc: 0.7954 - val_loss: 0.5690 - val_acc: 0.7100
#
# Epoch 10/10
#  - 0s - loss: 0.4768 - acc: 0.7941 - val_loss: 0.5490 - val_acc: 0.6900
#
# Test accuracy:
# 0.69
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.4938 - acc: 0.6957 - val_loss: 0.5809 - val_acc: 0.7600
#
# Epoch 2/10
#  - 0s - loss: 0.7275 - acc: 0.7187 - val_loss: 0.5887 - val_acc: 0.7400
#
# Epoch 3/10
#  - 0s - loss: 0.6152 - acc: 0.7455 - val_loss: 0.5392 - val_acc: 0.7300
#
# Epoch 4/10
#  - 0s - loss: 0.5356 - acc: 0.7532 - val_loss: 0.6254 - val_acc: 0.6900
#
# Epoch 5/10
#  - 0s - loss: 0.5175 - acc: 0.7775 - val_loss: 0.6656 - val_acc: 0.6200
#
# Epoch 6/10
#  - 0s - loss: 0.4727 - acc: 0.7481 - val_loss: 0.5920 - val_acc: 0.6100
#
# Epoch 7/10
#  - 0s - loss: 0.4484 - acc: 0.7673 - val_loss: 0.5133 - val_acc: 0.6900
#
# Epoch 8/10
#  - 0s - loss: 0.4449 - acc: 0.7647 - val_loss: 0.5264 - val_acc: 0.7300
#
# Epoch 9/10
#  - 0s - loss: 0.4568 - acc: 0.7647 - val_loss: 0.4557 - val_acc: 0.7600
#
# Epoch 10/10
#  - 0s - loss: 0.4099 - acc: 0.7762 - val_loss: 0.5259 - val_acc: 0.7300
#
# Test accuracy:
# 0.73
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.7256 - acc: 0.6151 - val_loss: 0.5812 - val_acc: 0.7600
#
# Epoch 2/10
#  - 0s - loss: 0.6579 - acc: 0.7839 - val_loss: 0.6969 - val_acc: 0.7100
#
# Epoch 3/10
#  - 0s - loss: 0.6163 - acc: 0.7724 - val_loss: 0.8091 - val_acc: 0.6800
#
# Epoch 4/10
#  - 0s - loss: 0.5755 - acc: 0.7711 - val_loss: 0.6859 - val_acc: 0.6800
#
# Epoch 5/10
#  - 0s - loss: 0.5296 - acc: 0.8082 - val_loss: 0.5118 - val_acc: 0.7300
#
# Epoch 6/10
#  - 0s - loss: 0.4452 - acc: 0.8133 - val_loss: 0.9764 - val_acc: 0.5700
#
# Epoch 7/10
#  - 0s - loss: 0.4821 - acc: 0.8095 - val_loss: 0.6742 - val_acc: 0.6200
#
# Epoch 8/10
#  - 0s - loss: 0.4556 - acc: 0.7941 - val_loss: 0.5675 - val_acc: 0.7400
#
# Epoch 9/10
#  - 0s - loss: 0.4278 - acc: 0.8005 - val_loss: 1.0257 - val_acc: 0.6200
#
# Epoch 10/10
#  - 0s - loss: 0.4609 - acc: 0.8146 - val_loss: 0.6304 - val_acc: 0.6700
#
# Test accuracy:
# 0.67
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 2.5816 - acc: 0.6701 - val_loss: 0.7573 - val_acc: 0.7500
#
# Epoch 2/10
#  - 0s - loss: 1.0097 - acc: 0.7621 - val_loss: 0.6385 - val_acc: 0.7100
#
# Epoch 3/10
#  - 0s - loss: 0.8448 - acc: 0.7801 - val_loss: 1.0523 - val_acc: 0.7200
#
# Epoch 4/10
#  - 0s - loss: 0.8351 - acc: 0.8043 - val_loss: 0.6512 - val_acc: 0.7000
#
# Epoch 5/10
#  - 0s - loss: 0.6604 - acc: 0.7864 - val_loss: 0.6687 - val_acc: 0.6800
#
# Epoch 6/10
#  - 0s - loss: 0.6743 - acc: 0.7775 - val_loss: 0.6711 - val_acc: 0.7700
#
# Epoch 7/10
#  - 0s - loss: 0.5964 - acc: 0.7852 - val_loss: 0.6564 - val_acc: 0.7100
#
# Epoch 8/10
#  - 0s - loss: 0.5727 - acc: 0.8082 - val_loss: 0.4648 - val_acc: 0.7600
#
# Epoch 9/10
#  - 0s - loss: 0.5201 - acc: 0.7916 - val_loss: 0.6426 - val_acc: 0.7200
#
# Epoch 10/10
#  - 0s - loss: 0.4758 - acc: 0.8133 - val_loss: 0.7512 - val_acc: 0.6900
#
# Test accuracy:
# 0.69
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.0719 - acc: 0.6957 - val_loss: 0.6122 - val_acc: 0.7300
#
# Epoch 2/10
#  - 0s - loss: 0.5994 - acc: 0.7775 - val_loss: 0.6242 - val_acc: 0.6900
#
# Epoch 3/10
#  - 0s - loss: 0.4976 - acc: 0.7941 - val_loss: 0.5282 - val_acc: 0.8000
#
# Epoch 4/10
#  - 0s - loss: 0.4736 - acc: 0.7864 - val_loss: 0.7342 - val_acc: 0.6900
#
# Epoch 5/10
#  - 0s - loss: 0.4468 - acc: 0.8107 - val_loss: 0.5578 - val_acc: 0.7400
#
# Epoch 6/10
#  - 0s - loss: 0.4365 - acc: 0.8018 - val_loss: 0.5339 - val_acc: 0.7400
#
# Epoch 7/10
#  - 0s - loss: 0.4461 - acc: 0.7928 - val_loss: 0.4971 - val_acc: 0.8000
#
# Epoch 8/10
#  - 0s - loss: 0.4186 - acc: 0.7967 - val_loss: 0.9270 - val_acc: 0.6900
#
# Epoch 9/10
#  - 0s - loss: 0.3929 - acc: 0.8133 - val_loss: 0.7635 - val_acc: 0.6900
#
# Epoch 10/10
#  - 0s - loss: 0.3874 - acc: 0.8146 - val_loss: 0.7637 - val_acc: 0.6900
#
# Test accuracy:
# 0.69
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.0892 - acc: 0.6982 - val_loss: 0.6257 - val_acc: 0.7800
#
# Epoch 2/10
#  - 0s - loss: 0.6404 - acc: 0.7583 - val_loss: 0.8885 - val_acc: 0.5400
#
# Epoch 3/10
#  - 0s - loss: 0.4879 - acc: 0.7481 - val_loss: 0.6756 - val_acc: 0.7300
#
# Epoch 4/10
#  - 0s - loss: 0.5264 - acc: 0.7442 - val_loss: 0.5610 - val_acc: 0.6300
#
# Epoch 5/10
#  - 0s - loss: 0.4158 - acc: 0.7749 - val_loss: 0.7273 - val_acc: 0.5500
#
# Epoch 6/10
#  - 0s - loss: 0.4326 - acc: 0.7442 - val_loss: 0.5681 - val_acc: 0.7000
#
# Epoch 7/10
#  - 0s - loss: 0.4419 - acc: 0.7711 - val_loss: 0.4900 - val_acc: 0.8000
#
# Epoch 8/10
#  - 0s - loss: 0.4557 - acc: 0.7660 - val_loss: 0.5394 - val_acc: 0.5700
#
# Epoch 9/10
#  - 0s - loss: 0.4097 - acc: 0.7801 - val_loss: 0.4996 - val_acc: 0.7000
#
# Epoch 10/10
#  - 0s - loss: 0.4277 - acc: 0.7762 - val_loss: 0.5467 - val_acc: 0.7000
#
# Test accuracy:
# 0.7
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.8934 - acc: 0.7110 - val_loss: 3.9446 - val_acc: 0.5400
#
# Epoch 2/10
#  - 0s - loss: 0.7865 - acc: 0.7954 - val_loss: 0.8026 - val_acc: 0.7200
#
# Epoch 3/10
#  - 0s - loss: 0.5034 - acc: 0.8095 - val_loss: 0.5898 - val_acc: 0.7300
#
# Epoch 4/10
#  - 0s - loss: 0.4164 - acc: 0.8440 - val_loss: 0.5553 - val_acc: 0.7000
#
# Epoch 5/10
#  - 0s - loss: 0.3746 - acc: 0.8389 - val_loss: 0.6869 - val_acc: 0.7500
#
# Epoch 6/10
#  - 0s - loss: 0.5475 - acc: 0.7954 - val_loss: 0.5345 - val_acc: 0.7400
#
# Epoch 7/10
#  - 0s - loss: 0.3597 - acc: 0.8440 - val_loss: 0.6131 - val_acc: 0.7400
#
# Epoch 8/10
#  - 0s - loss: 0.3516 - acc: 0.8491 - val_loss: 0.8900 - val_acc: 0.6400
#
# Epoch 9/10
#  - 0s - loss: 0.3132 - acc: 0.8760 - val_loss: 0.7954 - val_acc: 0.7200
#
# Epoch 10/10
#  - 0s - loss: 0.3370 - acc: 0.8683 - val_loss: 0.9816 - val_acc: 0.5900
#
# Test accuracy:
# 0.59
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.4543 - acc: 0.6918 - val_loss: 0.5868 - val_acc: 0.7400
#
# Epoch 2/10
#  - 0s - loss: 0.8176 - acc: 0.7315 - val_loss: 0.5723 - val_acc: 0.7000
#
# Epoch 3/10
#  - 0s - loss: 0.5627 - acc: 0.7251 - val_loss: 0.5420 - val_acc: 0.7100
#
# Epoch 4/10
#  - 0s - loss: 0.5477 - acc: 0.7148 - val_loss: 0.6924 - val_acc: 0.5800
#
# Epoch 5/10
#  - 0s - loss: 0.5394 - acc: 0.7123 - val_loss: 0.6861 - val_acc: 0.5700
#
# Epoch 6/10
#  - 0s - loss: 0.4907 - acc: 0.7199 - val_loss: 0.6547 - val_acc: 0.6000
#
# Epoch 7/10
#  - 0s - loss: 0.4827 - acc: 0.7161 - val_loss: 0.6120 - val_acc: 0.6200
#
# Epoch 8/10
#  - 0s - loss: 0.4835 - acc: 0.7110 - val_loss: 0.7292 - val_acc: 0.5200
#
# Epoch 9/10
#  - 0s - loss: 0.4866 - acc: 0.7008 - val_loss: 0.6253 - val_acc: 0.5900
#
# Epoch 10/10
#  - 0s - loss: 0.4685 - acc: 0.7212 - val_loss: 0.7670 - val_acc: 0.5200
#
# Test accuracy:
# 0.52
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.9827 - acc: 0.6829 - val_loss: 0.7796 - val_acc: 0.7400
#
# Epoch 2/10
#  - 0s - loss: 0.9006 - acc: 0.7852 - val_loss: 0.6968 - val_acc: 0.7300
#
# Epoch 3/10
#  - 0s - loss: 0.9293 - acc: 0.7609 - val_loss: 0.5367 - val_acc: 0.7200
#
# Epoch 4/10
#  - 0s - loss: 0.6340 - acc: 0.7852 - val_loss: 0.6160 - val_acc: 0.7200
#
# Epoch 5/10
#  - 0s - loss: 0.6687 - acc: 0.7788 - val_loss: 0.7236 - val_acc: 0.6400
#
# Epoch 6/10
#  - 0s - loss: 0.5347 - acc: 0.7762 - val_loss: 0.5673 - val_acc: 0.6800
#
# Epoch 7/10
#  - 0s - loss: 0.4838 - acc: 0.8043 - val_loss: 0.5207 - val_acc: 0.7200
#
# Epoch 8/10
#  - 0s - loss: 0.5228 - acc: 0.7801 - val_loss: 0.5673 - val_acc: 0.7300
#
# Epoch 9/10
#  - 0s - loss: 0.4761 - acc: 0.7967 - val_loss: 0.7587 - val_acc: 0.6600
#
# Epoch 10/10
#  - 0s - loss: 0.4545 - acc: 0.7941 - val_loss: 0.6041 - val_acc: 0.7300
#
# Test accuracy:
# 0.73
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 2.1683 - acc: 0.6880 - val_loss: 2.2234 - val_acc: 0.7300
#
# Epoch 2/10
#  - 0s - loss: 1.2246 - acc: 0.7762 - val_loss: 0.4862 - val_acc: 0.8000
#
# Epoch 3/10
#  - 0s - loss: 1.0404 - acc: 0.7442 - val_loss: 2.0249 - val_acc: 0.5800
#
# Epoch 4/10
#  - 0s - loss: 0.9473 - acc: 0.7775 - val_loss: 0.6166 - val_acc: 0.6900
#
# Epoch 5/10
#  - 0s - loss: 0.8373 - acc: 0.7583 - val_loss: 0.7182 - val_acc: 0.7000
#
# Epoch 6/10
#  - 0s - loss: 0.7617 - acc: 0.7609 - val_loss: 0.6086 - val_acc: 0.7000
#
# Epoch 7/10
#  - 0s - loss: 0.6825 - acc: 0.7545 - val_loss: 0.5077 - val_acc: 0.7300
#
# Epoch 8/10
#  - 0s - loss: 0.5279 - acc: 0.7941 - val_loss: 0.4710 - val_acc: 0.7300
#
# Epoch 9/10
#  - 0s - loss: 0.5408 - acc: 0.7711 - val_loss: 0.5586 - val_acc: 0.7100
#
# Epoch 10/10
#  - 0s - loss: 0.5116 - acc: 0.7954 - val_loss: 0.6675 - val_acc: 0.6700
#
# Test accuracy:
# 0.67
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.5386 - acc: 0.6637 - val_loss: 0.5990 - val_acc: 0.7300
#
# Epoch 2/10
#  - 0s - loss: 0.6502 - acc: 0.7660 - val_loss: 0.4834 - val_acc: 0.7400
#
# Epoch 3/10
#  - 0s - loss: 0.4925 - acc: 0.7826 - val_loss: 0.6659 - val_acc: 0.5900
#
# Epoch 4/10
#  - 0s - loss: 0.4717 - acc: 0.7928 - val_loss: 0.5366 - val_acc: 0.6800
#
# Epoch 5/10
#  - 0s - loss: 0.4467 - acc: 0.7916 - val_loss: 0.8326 - val_acc: 0.6900
#
# Epoch 6/10
#  - 0s - loss: 0.4725 - acc: 0.7864 - val_loss: 0.4825 - val_acc: 0.7500
#
# Epoch 7/10
#  - 0s - loss: 0.4044 - acc: 0.8018 - val_loss: 0.5487 - val_acc: 0.7300
#
# Epoch 8/10
#  - 0s - loss: 0.4056 - acc: 0.8210 - val_loss: 0.6121 - val_acc: 0.7400
#
# Epoch 9/10
#  - 0s - loss: 0.4249 - acc: 0.8043 - val_loss: 0.8293 - val_acc: 0.6800
#
# Epoch 10/10
#  - 0s - loss: 0.4326 - acc: 0.8107 - val_loss: 0.9035 - val_acc: 0.5700
#
# Test accuracy:
# 0.57
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.5187 - acc: 0.6867 - val_loss: 0.5006 - val_acc: 0.7300
#
# Epoch 2/10
#  - 0s - loss: 0.9184 - acc: 0.7494 - val_loss: 0.5961 - val_acc: 0.6800
#
# Epoch 3/10
#  - 0s - loss: 0.8069 - acc: 0.7621 - val_loss: 0.6078 - val_acc: 0.6700
#
# Epoch 4/10
#  - 0s - loss: 0.7320 - acc: 0.7519 - val_loss: 0.7193 - val_acc: 0.6100
#
# Epoch 5/10
#  - 0s - loss: 0.7169 - acc: 0.7634 - val_loss: 0.7037 - val_acc: 0.6300
#
# Epoch 6/10
#  - 0s - loss: 0.6702 - acc: 0.7404 - val_loss: 0.6229 - val_acc: 0.6200
#
# Epoch 7/10
#  - 0s - loss: 0.5840 - acc: 0.7788 - val_loss: 0.5976 - val_acc: 0.6800
#
# Epoch 8/10
#  - 0s - loss: 0.5687 - acc: 0.7685 - val_loss: 0.6839 - val_acc: 0.7000
#
# Epoch 9/10
#  - 0s - loss: 0.5785 - acc: 0.7826 - val_loss: 0.6198 - val_acc: 0.6700
#
# Epoch 10/10
#  - 0s - loss: 0.4685 - acc: 0.7903 - val_loss: 0.5657 - val_acc: 0.6900
#
# Test accuracy:
# 0.69
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 0.9249 - acc: 0.6816 - val_loss: 0.5302 - val_acc: 0.7000
#
# Epoch 2/10
#  - 1s - loss: 0.5611 - acc: 0.7634 - val_loss: 0.4885 - val_acc: 0.7100
#
# Epoch 3/10
#  - 0s - loss: 0.5655 - acc: 0.7417 - val_loss: 0.6757 - val_acc: 0.6100
#
# Epoch 4/10
#  - 0s - loss: 0.5438 - acc: 0.7276 - val_loss: 0.6339 - val_acc: 0.5100
#
# Epoch 5/10
#  - 0s - loss: 0.4813 - acc: 0.7161 - val_loss: 0.7334 - val_acc: 0.5200
#
# Epoch 6/10
#  - 0s - loss: 0.4847 - acc: 0.7123 - val_loss: 0.8920 - val_acc: 0.5400
#
# Epoch 7/10
#  - 0s - loss: 0.4756 - acc: 0.7212 - val_loss: 0.5559 - val_acc: 0.6400
#
# Epoch 8/10
#  - 0s - loss: 0.5049 - acc: 0.6982 - val_loss: 0.4850 - val_acc: 0.7400
#
# Epoch 9/10
#  - 0s - loss: 0.4786 - acc: 0.7238 - val_loss: 0.5544 - val_acc: 0.6700
#
# Epoch 10/10
#  - 0s - loss: 0.4687 - acc: 0.7148 - val_loss: 0.5791 - val_acc: 0.5100
#
# Test accuracy:
# 0.51
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.7606 - acc: 0.6547 - val_loss: 0.6603 - val_acc: 0.7500
#
# Epoch 2/10
#  - 0s - loss: 1.0669 - acc: 0.6918 - val_loss: 0.5472 - val_acc: 0.6900
#
# Epoch 3/10
#  - 0s - loss: 0.9200 - acc: 0.6931 - val_loss: 0.5642 - val_acc: 0.6300
#
# Epoch 4/10
#  - 0s - loss: 0.7261 - acc: 0.7289 - val_loss: 0.5618 - val_acc: 0.7200
#
# Epoch 5/10
#  - 0s - loss: 0.8170 - acc: 0.7136 - val_loss: 0.4664 - val_acc: 0.7600
#
# Epoch 6/10
#  - 0s - loss: 0.7299 - acc: 0.7302 - val_loss: 0.6318 - val_acc: 0.6600
#
# Epoch 7/10
#  - 0s - loss: 0.6722 - acc: 0.7148 - val_loss: 0.5252 - val_acc: 0.6900
#
# Epoch 8/10
#  - 0s - loss: 0.7402 - acc: 0.7442 - val_loss: 0.5489 - val_acc: 0.7200
#
# Epoch 9/10
#  - 0s - loss: 0.5815 - acc: 0.7468 - val_loss: 0.5447 - val_acc: 0.7100
#
# Epoch 10/10
#  - 0s - loss: 0.5796 - acc: 0.7404 - val_loss: 0.4872 - val_acc: 0.7300
#
# Test accuracy:
# 0.73
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.5776 - acc: 0.6880 - val_loss: 0.6397 - val_acc: 0.7300
#
# Epoch 2/10
#  - 0s - loss: 0.8717 - acc: 0.7353 - val_loss: 0.5224 - val_acc: 0.7400
#
# Epoch 3/10
#  - 0s - loss: 0.6105 - acc: 0.7353 - val_loss: 0.6142 - val_acc: 0.7100
#
# Epoch 4/10
#  - 0s - loss: 0.5278 - acc: 0.7506 - val_loss: 0.6526 - val_acc: 0.7400
#
# Epoch 5/10
#  - 0s - loss: 0.6092 - acc: 0.7877 - val_loss: 0.7279 - val_acc: 0.6900
#
# Epoch 6/10
#  - 0s - loss: 0.5363 - acc: 0.7583 - val_loss: 0.5708 - val_acc: 0.6700
#
# Epoch 7/10
#  - 0s - loss: 0.4636 - acc: 0.7391 - val_loss: 1.3121 - val_acc: 0.6300
#
# Epoch 8/10
#  - 0s - loss: 0.5528 - acc: 0.7749 - val_loss: 0.5407 - val_acc: 0.7300
#
# Epoch 9/10
#  - 0s - loss: 0.4892 - acc: 0.7468 - val_loss: 0.6866 - val_acc: 0.5200
#
# Epoch 10/10
#  - 0s - loss: 0.4584 - acc: 0.7225 - val_loss: 0.7530 - val_acc: 0.6400
#
# Test accuracy:
# 0.64
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.2640 - acc: 0.7327 - val_loss: 0.7326 - val_acc: 0.7000
#
# Epoch 2/10
#  - 0s - loss: 0.7778 - acc: 0.7762 - val_loss: 0.6514 - val_acc: 0.7100
#
# Epoch 3/10
#  - 0s - loss: 0.7282 - acc: 0.7877 - val_loss: 0.5421 - val_acc: 0.7100
#
# Epoch 4/10
#  - 0s - loss: 0.5525 - acc: 0.7967 - val_loss: 0.5052 - val_acc: 0.7000
#
# Epoch 5/10
#  - 0s - loss: 0.5240 - acc: 0.7852 - val_loss: 0.5322 - val_acc: 0.6800
#
# Epoch 6/10
#  - 0s - loss: 0.4066 - acc: 0.8018 - val_loss: 0.5518 - val_acc: 0.6800
#
# Epoch 7/10
#  - 0s - loss: 0.4134 - acc: 0.8184 - val_loss: 0.7431 - val_acc: 0.6400
#
# Epoch 8/10
#  - 0s - loss: 0.4071 - acc: 0.8056 - val_loss: 0.6206 - val_acc: 0.7100
#
# Epoch 9/10
#  - 0s - loss: 0.3958 - acc: 0.8095 - val_loss: 0.6344 - val_acc: 0.7000
#
# Epoch 10/10
#  - 0s - loss: 0.3938 - acc: 0.8133 - val_loss: 0.6356 - val_acc: 0.6700
#
# Test accuracy:
# 0.67
# Train on 782 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 1.3962 - acc: 0.6893 - val_loss: 1.1365 - val_acc: 0.7300
#
# Epoch 2/10
#  - 1s - loss: 0.7309 - acc: 0.7801 - val_loss: 0.8348 - val_acc: 0.6500
#
# Epoch 3/10
#  - 1s - loss: 0.6777 - acc: 0.7634 - val_loss: 0.8132 - val_acc: 0.6900
#
# Epoch 4/10
#  - 1s - loss: 0.5917 - acc: 0.7928 - val_loss: 0.7691 - val_acc: 0.6500
#
# Epoch 5/10
#  - 1s - loss: 0.5967 - acc: 0.8005 - val_loss: 0.7221 - val_acc: 0.7000
#
# Epoch 6/10
#  - 1s - loss: 0.4918 - acc: 0.7890 - val_loss: 0.5194 - val_acc: 0.7200
#
# Epoch 7/10
#  - 1s - loss: 0.4655 - acc: 0.8056 - val_loss: 1.1156 - val_acc: 0.6300
#
# Epoch 8/10
#  - 1s - loss: 0.4868 - acc: 0.8146 - val_loss: 0.7624 - val_acc: 0.6400
#
# Epoch 9/10
#  - 1s - loss: 0.4213 - acc: 0.8312 - val_loss: 0.5143 - val_acc: 0.7400
#
# Epoch 10/10
#  - 1s - loss: 0.3873 - acc: 0.8184 - val_loss: 0.9720 - val_acc: 0.7300
#
# Test accuracy:
# 0.73
# 100%|██████████| 30/30 [03:34<00:00,  8.22s/it, best loss: -0.78]
# Time on optimization: 3.592651355266571 minutes
#
# Summary of the best model: -----------------------
# Evalutation of best performing model:
# 100/100 [==============================] - 0s 354us/step
# [0.49178935050964356, 0.78]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 64, 64, 5, 1)      0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 62, 62, 3, 64)     1792
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 31, 31, 1, 64)     0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 61504)             0
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                1968160
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 1,970,497
# Trainable params: 1,970,497
# Non-trainable params: 0
# _________________________________________________________________
# None
# Conv 1: 64 unidades
# Dense 1: 64 unidades
# Dense 2: 16 unidades
# Dropout 1: 0.1141906556451216
# Dropout 2: 0.27112063453183133
