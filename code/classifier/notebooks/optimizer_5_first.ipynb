# %% [markdown]
# # Colab config

# %%
from google.colab import drive
drive.mount('drive', force_remount=True)

# %%
# !pip install hyperas

# %% [markdown]
# ## Imports

# %%
import os

import time

import gc

import numpy as np

from scipy import interp

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, roc_curve, auc

from keras import backend as K
from keras import optimizers
from keras.layers import Conv3D, MaxPool3D, Flatten, Dense, Dropout, Input
from keras.losses import binary_crossentropy
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.utils.vis_utils import plot_model, model_to_dot
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## GPU configuration

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 1
set_session(tf.Session(config=config))
session = tf.Session(config=config)

# %% [markdown]
# # Hyperparameters optimization
#
# Func **data()** required by Hyperas. It must return 4 arrays X_train, Y_train, X_test, Y_test.
#
# The data for optimization are on four numpy files, generated with the notebook **import_images.ipynb**.

# %%
'''5-first'''

def data():
  prefix = "/content/drive/My Drive/Pesquisa - Dicom images/data/clean_nps/data-5-first"
  X_train = np.load(prefix + "/X_train.npy")
  X_test = np.load(prefix + "/X_test.npy")
  Y_train = np.load(prefix + "/Y_train.npy")
  Y_test = np.load(prefix + "/Y_test.npy")
  
  return X_train, Y_train, X_test, Y_test

# %% [markdown]
# ## Space of search definition
#
# * **conv_layer1**: [32, 48, 64, 96] unities
# * **dense_layer1**: [32, 64, 128, 256] unities
# * **dense_layer2**: [8, 16, 24, 32] unities
# * **dropout** on dense layers: between 0 and 0.5

# %%
conv1 = [32, 48, 64, 96]
dense1 = [64, 96, 128]
dense2 = [16, 24, 32]
    
def model(X_train, Y_train, X_test, Y_test):
    conv1 = {{choice([32, 48, 64, 96])}}
    dense1 = {{choice([32, 64, 128])}}
    dense2 = {{choice([16, 24, 32])}}
    
    input_layer = Input(X_train.shape[1:5])
    
    conv_layer1 = Conv3D(conv1, kernel_size=(3, 3, 3), activation='relu')(input_layer)
    pooling_layer1 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer1)
    
    flatten_layer = Flatten()(pooling_layer1)
    
    dense_layer1 = Dense(dense1, activation='relu')(flatten_layer)
    dense_layer1 = Dropout({{uniform(0, .5)}})(dense_layer1)
    
    dense_layer2 = Dense(dense2, activation='relu')(dense_layer1)
    dense_layer2 = Dropout({{uniform(0, .5)}})(dense_layer2)
    
    output_layer = Dense(units=1, activation='sigmoid')(dense_layer2)
    
    model = Model(inputs=input_layer, outputs=output_layer)
    
    opt = optimizers.RMSprop(lr=0.0001)
    
    model.compile(loss=binary_crossentropy, optimizer=opt, metrics=['acc'])
    
    model.fit(X_train, Y_train,
              batch_size=128,
              epochs=10,
              verbose=2,
              validation_data=(X_test, Y_test)
              )
    
    score, acc = model.evaluate(X_test, Y_test, verbose=0)
    
    print('Test accuracy:', acc)
    
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %% [markdown]
# ## Otimization

# %%
X_train, Y_train, X_test, Y_test = data()

start = time.time()

best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=30,
                                      trials=Trials(),
                                      verbose=False,
                                      notebook_name='drive/My Drive/Pesquisa - Dicom images/notebooks/optimizer_5_first')
end = time.time()

print("Time on optimization:", (end - start)/60, "minutes")

print()
print('Summary of the best model: -----------------------')

print("Evalutation of best performing model:")
print(best_model.evaluate(X_test, Y_test))

print(best_model.summary())

c1 = conv1[best_run['conv1']]
d1 = dense1[best_run['dense1']]
d2 = dense2[best_run['dense2']]
drop1 = best_run['Dropout']
drop2 = best_run['Dropout_1']

print('Conv 1:', c1, 'unidades')
print('Dense 1:', d1, 'unidades')
print('Dense 2:', d2, 'unidades')
print('Dropout 1:', drop1)
print('Dropout 2:', drop2)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.9203 - acc: 0.7078 - val_loss: 0.4694 - val_acc: 0.7600
#
# Epoch 2/10
#  - 2s - loss: 0.5789 - acc: 0.7577 - val_loss: 0.4308 - val_acc: 0.8000
#
# Epoch 3/10
#  - 2s - loss: 0.5773 - acc: 0.7634 - val_loss: 0.4240 - val_acc: 0.8000
#
# Epoch 4/10
#  - 2s - loss: 0.5381 - acc: 0.7728 - val_loss: 0.4576 - val_acc: 0.7700
#
# Epoch 5/10
#  - 2s - loss: 0.5361 - acc: 0.7775 - val_loss: 0.4412 - val_acc: 0.8000
#
# Epoch 6/10
#  - 2s - loss: 0.5260 - acc: 0.7781 - val_loss: 0.4809 - val_acc: 0.7600
#
# Epoch 7/10
#  - 2s - loss: 0.4950 - acc: 0.7837 - val_loss: 0.4672 - val_acc: 0.7900
#
# Epoch 8/10
#  - 2s - loss: 0.4992 - acc: 0.7864 - val_loss: 0.4429 - val_acc: 0.7800
#
# Epoch 9/10
#  - 2s - loss: 0.4850 - acc: 0.7846 - val_loss: 0.4504 - val_acc: 0.7800
#
# Epoch 10/10
#  - 2s - loss: 0.4788 - acc: 0.7942 - val_loss: 0.5677 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 0.6757 - acc: 0.7210 - val_loss: 0.4892 - val_acc: 0.7500
#
# Epoch 2/10
#  - 3s - loss: 0.5378 - acc: 0.7568 - val_loss: 0.4499 - val_acc: 0.7700
#
# Epoch 3/10
#  - 3s - loss: 0.5110 - acc: 0.7671 - val_loss: 0.4333 - val_acc: 0.7800
#
# Epoch 4/10
#  - 3s - loss: 0.5126 - acc: 0.7667 - val_loss: 0.4454 - val_acc: 0.7600
#
# Epoch 5/10
#  - 3s - loss: 0.5198 - acc: 0.7726 - val_loss: 0.4902 - val_acc: 0.7900
#
# Epoch 6/10
#  - 3s - loss: 0.4939 - acc: 0.7735 - val_loss: 0.4512 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.4917 - acc: 0.7738 - val_loss: 0.4516 - val_acc: 0.7800
#
# Epoch 8/10
#  - 3s - loss: 0.4800 - acc: 0.7775 - val_loss: 0.4843 - val_acc: 0.7500
#
# Epoch 9/10
#  - 3s - loss: 0.4695 - acc: 0.7724 - val_loss: 0.5124 - val_acc: 0.7600
#
# Epoch 10/10
#  - 3s - loss: 0.4849 - acc: 0.7859 - val_loss: 0.4550 - val_acc: 0.7500
#
# Test accuracy:
# 0.75
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.7315 - acc: 0.7301 - val_loss: 0.5232 - val_acc: 0.7900
#
# Epoch 2/10
#  - 3s - loss: 0.5769 - acc: 0.7595 - val_loss: 0.4988 - val_acc: 0.8000
#
# Epoch 3/10
#  - 3s - loss: 0.5253 - acc: 0.7772 - val_loss: 0.4451 - val_acc: 0.7500
#
# Epoch 4/10
#  - 3s - loss: 0.5231 - acc: 0.7738 - val_loss: 0.4881 - val_acc: 0.7800
#
# Epoch 5/10
#  - 3s - loss: 0.5132 - acc: 0.7729 - val_loss: 0.4292 - val_acc: 0.8100
#
# Epoch 6/10
#  - 3s - loss: 0.4894 - acc: 0.7891 - val_loss: 0.4486 - val_acc: 0.8200
#
# Epoch 7/10
#  - 3s - loss: 0.4777 - acc: 0.7850 - val_loss: 0.4937 - val_acc: 0.7900
#
# Epoch 8/10
#  - 3s - loss: 0.4643 - acc: 0.7873 - val_loss: 0.4336 - val_acc: 0.8200
#
# Epoch 9/10
#  - 3s - loss: 0.4628 - acc: 0.7981 - val_loss: 0.4577 - val_acc: 0.8200
#
# Epoch 10/10
#  - 3s - loss: 0.4469 - acc: 0.8013 - val_loss: 0.4558 - val_acc: 0.8200
#
# Test accuracy:
# 0.82
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 0.7066 - acc: 0.7249 - val_loss: 0.4264 - val_acc: 0.7500
#
# Epoch 2/10
#  - 3s - loss: 0.5128 - acc: 0.7713 - val_loss: 0.4759 - val_acc: 0.7800
#
# Epoch 3/10
#  - 3s - loss: 0.4994 - acc: 0.7813 - val_loss: 0.4688 - val_acc: 0.7700
#
# Epoch 4/10
#  - 3s - loss: 0.4907 - acc: 0.7912 - val_loss: 0.4573 - val_acc: 0.7300
#
# Epoch 5/10
#  - 3s - loss: 0.4663 - acc: 0.7953 - val_loss: 0.4360 - val_acc: 0.7600
#
# Epoch 6/10
#  - 3s - loss: 0.4677 - acc: 0.7931 - val_loss: 0.4059 - val_acc: 0.8100
#
# Epoch 7/10
#  - 3s - loss: 0.4607 - acc: 0.7976 - val_loss: 0.4619 - val_acc: 0.8100
#
# Epoch 8/10
#  - 3s - loss: 0.4432 - acc: 0.7988 - val_loss: 0.4556 - val_acc: 0.7800
#
# Epoch 9/10
#  - 3s - loss: 0.4401 - acc: 0.8053 - val_loss: 0.4529 - val_acc: 0.7900
#
# Epoch 10/10
#  - 3s - loss: 0.4199 - acc: 0.8078 - val_loss: 0.4405 - val_acc: 0.8300
#
# Test accuracy:
# 0.83
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 0.6529 - acc: 0.7582 - val_loss: 0.4924 - val_acc: 0.7300
#
# Epoch 2/10
#  - 5s - loss: 0.4570 - acc: 0.7917 - val_loss: 0.4710 - val_acc: 0.7100
#
# Epoch 3/10
#  - 4s - loss: 0.4541 - acc: 0.7908 - val_loss: 0.4376 - val_acc: 0.8000
#
# Epoch 4/10
#  - 4s - loss: 0.4333 - acc: 0.8034 - val_loss: 0.5656 - val_acc: 0.7300
#
# Epoch 5/10
#  - 4s - loss: 0.4193 - acc: 0.8006 - val_loss: 0.5493 - val_acc: 0.7500
#
# Epoch 6/10
#  - 4s - loss: 0.4020 - acc: 0.8126 - val_loss: 0.4270 - val_acc: 0.8200
#
# Epoch 7/10
#  - 4s - loss: 0.3888 - acc: 0.8185 - val_loss: 0.5521 - val_acc: 0.7500
#
# Epoch 8/10
#  - 4s - loss: 0.3780 - acc: 0.8202 - val_loss: 0.5104 - val_acc: 0.8200
#
# Epoch 9/10
#  - 4s - loss: 0.3602 - acc: 0.8355 - val_loss: 0.4994 - val_acc: 0.7500
#
# Epoch 10/10
#  - 5s - loss: 0.3427 - acc: 0.8353 - val_loss: 0.4521 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 1.1794 - acc: 0.7140 - val_loss: 0.4486 - val_acc: 0.7900
#
# Epoch 2/10
#  - 3s - loss: 0.6696 - acc: 0.7311 - val_loss: 0.4569 - val_acc: 0.7400
#
# Epoch 3/10
#  - 3s - loss: 0.6013 - acc: 0.7189 - val_loss: 0.4753 - val_acc: 0.7400
#
# Epoch 4/10
#  - 3s - loss: 0.5568 - acc: 0.7540 - val_loss: 0.4781 - val_acc: 0.7700
#
# Epoch 5/10
#  - 3s - loss: 0.5440 - acc: 0.7593 - val_loss: 0.4833 - val_acc: 0.7400
#
# Epoch 6/10
#  - 3s - loss: 0.5442 - acc: 0.7664 - val_loss: 0.5189 - val_acc: 0.8000
#
# Epoch 7/10
#  - 3s - loss: 0.5187 - acc: 0.7708 - val_loss: 0.4359 - val_acc: 0.7400
#
# Epoch 8/10
#  - 3s - loss: 0.5128 - acc: 0.7839 - val_loss: 0.4649 - val_acc: 0.8000
#
# Epoch 9/10
#  - 3s - loss: 0.5031 - acc: 0.7860 - val_loss: 0.4626 - val_acc: 0.7700
#
# Epoch 10/10
#  - 3s - loss: 0.4896 - acc: 0.7841 - val_loss: 0.4684 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.7044 - acc: 0.6876 - val_loss: 0.4946 - val_acc: 0.7300
#
# Epoch 2/10
#  - 3s - loss: 0.5201 - acc: 0.7402 - val_loss: 0.4395 - val_acc: 0.7900
#
# Epoch 3/10
#  - 3s - loss: 0.5048 - acc: 0.7476 - val_loss: 0.4811 - val_acc: 0.8100
#
# Epoch 4/10
#  - 3s - loss: 0.5001 - acc: 0.7575 - val_loss: 0.4660 - val_acc: 0.8300
#
# Epoch 5/10
#  - 3s - loss: 0.4745 - acc: 0.7788 - val_loss: 0.6691 - val_acc: 0.7300
#
# Epoch 6/10
#  - 3s - loss: 0.4760 - acc: 0.7756 - val_loss: 0.4421 - val_acc: 0.7400
#
# Epoch 7/10
#  - 3s - loss: 0.4618 - acc: 0.7797 - val_loss: 0.6266 - val_acc: 0.7300
#
# Epoch 8/10
#  - 3s - loss: 0.4464 - acc: 0.7986 - val_loss: 0.4530 - val_acc: 0.8200
#
# Epoch 9/10
#  - 3s - loss: 0.4311 - acc: 0.8030 - val_loss: 0.4590 - val_acc: 0.8100
#
# Epoch 10/10
#  - 3s - loss: 0.4102 - acc: 0.8092 - val_loss: 0.4645 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.9838 - acc: 0.7322 - val_loss: 0.4256 - val_acc: 0.7800
#
# Epoch 2/10
#  - 4s - loss: 0.5162 - acc: 0.7754 - val_loss: 0.5042 - val_acc: 0.7700
#
# Epoch 3/10
#  - 4s - loss: 0.4960 - acc: 0.7767 - val_loss: 0.5082 - val_acc: 0.7700
#
# Epoch 4/10
#  - 4s - loss: 0.4759 - acc: 0.7853 - val_loss: 0.5423 - val_acc: 0.7400
#
# Epoch 5/10
#  - 4s - loss: 0.4531 - acc: 0.8041 - val_loss: 0.5339 - val_acc: 0.7500
#
# Epoch 6/10
#  - 4s - loss: 0.4377 - acc: 0.8092 - val_loss: 0.4212 - val_acc: 0.8000
#
# Epoch 7/10
#  - 4s - loss: 0.4178 - acc: 0.8163 - val_loss: 0.4666 - val_acc: 0.8200
#
# Epoch 8/10
#  - 4s - loss: 0.4042 - acc: 0.8231 - val_loss: 0.4493 - val_acc: 0.7900
#
# Epoch 9/10
#  - 4s - loss: 0.4016 - acc: 0.8247 - val_loss: 0.4546 - val_acc: 0.8000
#
# Epoch 10/10
#  - 4s - loss: 0.3801 - acc: 0.8328 - val_loss: 0.6156 - val_acc: 0.7500
#
# Test accuracy:
# 0.75
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.6688 - acc: 0.7494 - val_loss: 0.4707 - val_acc: 0.7700
#
# Epoch 2/10
#  - 3s - loss: 0.4878 - acc: 0.7834 - val_loss: 0.4352 - val_acc: 0.8100
#
# Epoch 3/10
#  - 3s - loss: 0.4706 - acc: 0.7857 - val_loss: 0.4566 - val_acc: 0.8000
#
# Epoch 4/10
#  - 3s - loss: 0.4595 - acc: 0.7953 - val_loss: 0.4140 - val_acc: 0.8100
#
# Epoch 5/10
#  - 3s - loss: 0.4465 - acc: 0.7990 - val_loss: 0.4397 - val_acc: 0.7500
#
# Epoch 6/10
#  - 3s - loss: 0.4368 - acc: 0.8068 - val_loss: 0.4529 - val_acc: 0.8100
#
# Epoch 7/10
#  - 3s - loss: 0.4205 - acc: 0.8068 - val_loss: 0.4391 - val_acc: 0.7900
#
# Epoch 8/10
#  - 3s - loss: 0.4208 - acc: 0.8032 - val_loss: 0.4768 - val_acc: 0.7800
#
# Epoch 9/10
#  - 3s - loss: 0.4085 - acc: 0.8108 - val_loss: 0.4189 - val_acc: 0.7600
#
# Epoch 10/10
#  - 3s - loss: 0.4057 - acc: 0.8115 - val_loss: 0.4662 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.7828 - acc: 0.7304 - val_loss: 0.5734 - val_acc: 0.7500
#
# Epoch 2/10
#  - 4s - loss: 0.5298 - acc: 0.7612 - val_loss: 0.6050 - val_acc: 0.6300
#
# Epoch 3/10
#  - 4s - loss: 0.4964 - acc: 0.7781 - val_loss: 0.5113 - val_acc: 0.7900
#
# Epoch 4/10
#  - 4s - loss: 0.4740 - acc: 0.7917 - val_loss: 0.4634 - val_acc: 0.8100
#
# Epoch 5/10
#  - 4s - loss: 0.4595 - acc: 0.7995 - val_loss: 0.6178 - val_acc: 0.7600
#
# Epoch 6/10
#  - 4s - loss: 0.4528 - acc: 0.7983 - val_loss: 0.6216 - val_acc: 0.7400
#
# Epoch 7/10
#  - 4s - loss: 0.4330 - acc: 0.8036 - val_loss: 0.4493 - val_acc: 0.7700
#
# Epoch 8/10
#  - 4s - loss: 0.4181 - acc: 0.8078 - val_loss: 0.4520 - val_acc: 0.8300
#
# Epoch 9/10
#  - 4s - loss: 0.3949 - acc: 0.8119 - val_loss: 0.4275 - val_acc: 0.8400
#
# Epoch 10/10
#  - 4s - loss: 0.3807 - acc: 0.8225 - val_loss: 0.4518 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.7471 - acc: 0.7272 - val_loss: 0.4339 - val_acc: 0.7800
#
# Epoch 2/10
#  - 3s - loss: 0.5380 - acc: 0.7655 - val_loss: 0.4265 - val_acc: 0.7900
#
# Epoch 3/10
#  - 3s - loss: 0.5105 - acc: 0.7783 - val_loss: 0.4398 - val_acc: 0.7800
#
# Epoch 4/10
#  - 3s - loss: 0.4993 - acc: 0.7873 - val_loss: 0.4847 - val_acc: 0.8200
#
# Epoch 5/10
#  - 3s - loss: 0.4707 - acc: 0.7933 - val_loss: 0.4337 - val_acc: 0.8200
#
# Epoch 6/10
#  - 3s - loss: 0.4591 - acc: 0.7889 - val_loss: 0.5040 - val_acc: 0.8000
#
# Epoch 7/10
#  - 3s - loss: 0.4582 - acc: 0.7981 - val_loss: 0.4411 - val_acc: 0.8100
#
# Epoch 8/10
#  - 3s - loss: 0.4428 - acc: 0.8052 - val_loss: 0.4434 - val_acc: 0.8200
#
# Epoch 9/10
#  - 3s - loss: 0.4150 - acc: 0.8066 - val_loss: 0.4511 - val_acc: 0.7900
#
# Epoch 10/10
#  - 3s - loss: 0.4162 - acc: 0.8092 - val_loss: 0.4315 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 0.7372 - acc: 0.7303 - val_loss: 0.4622 - val_acc: 0.7500
#
# Epoch 2/10
#  - 2s - loss: 0.4990 - acc: 0.7682 - val_loss: 0.4323 - val_acc: 0.8000
#
# Epoch 3/10
#  - 2s - loss: 0.4688 - acc: 0.7708 - val_loss: 0.4560 - val_acc: 0.7400
#
# Epoch 4/10
#  - 2s - loss: 0.4508 - acc: 0.7841 - val_loss: 0.5128 - val_acc: 0.7500
#
# Epoch 5/10
#  - 2s - loss: 0.4414 - acc: 0.7869 - val_loss: 0.4096 - val_acc: 0.8200
#
# Epoch 6/10
#  - 2s - loss: 0.4160 - acc: 0.8101 - val_loss: 0.4390 - val_acc: 0.8100
#
# Epoch 7/10
#  - 2s - loss: 0.4134 - acc: 0.8043 - val_loss: 0.4838 - val_acc: 0.8000
#
# Epoch 8/10
#  - 2s - loss: 0.3985 - acc: 0.8124 - val_loss: 0.5142 - val_acc: 0.7900
#
# Epoch 9/10
#  - 2s - loss: 0.3886 - acc: 0.8241 - val_loss: 0.6028 - val_acc: 0.7900
#
# Epoch 10/10
#  - 2s - loss: 0.3774 - acc: 0.8245 - val_loss: 0.6138 - val_acc: 0.7000
#
# Test accuracy:
# 0.7
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 6s - loss: 1.1236 - acc: 0.7318 - val_loss: 0.4738 - val_acc: 0.7700
#
# Epoch 2/10
#  - 4s - loss: 0.5539 - acc: 0.7671 - val_loss: 0.4305 - val_acc: 0.7900
#
# Epoch 3/10
#  - 4s - loss: 0.4964 - acc: 0.7857 - val_loss: 0.4449 - val_acc: 0.7900
#
# Epoch 4/10
#  - 4s - loss: 0.4663 - acc: 0.7940 - val_loss: 0.4389 - val_acc: 0.7900
#
# Epoch 5/10
#  - 5s - loss: 0.4482 - acc: 0.8007 - val_loss: 0.4497 - val_acc: 0.7800
#
# Epoch 6/10
#  - 5s - loss: 0.4203 - acc: 0.8085 - val_loss: 0.5142 - val_acc: 0.8300
#
# Epoch 7/10
#  - 4s - loss: 0.3983 - acc: 0.8146 - val_loss: 0.4380 - val_acc: 0.8200
#
# Epoch 8/10
#  - 4s - loss: 0.3786 - acc: 0.8248 - val_loss: 0.4851 - val_acc: 0.8000
#
# Epoch 9/10
#  - 4s - loss: 0.3570 - acc: 0.8340 - val_loss: 0.7206 - val_acc: 0.7700
#
# Epoch 10/10
#  - 4s - loss: 0.3498 - acc: 0.8385 - val_loss: 0.5587 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 0.8021 - acc: 0.6943 - val_loss: 0.4854 - val_acc: 0.7900
#
# Epoch 2/10
#  - 2s - loss: 0.6005 - acc: 0.7329 - val_loss: 0.4851 - val_acc: 0.8400
#
# Epoch 3/10
#  - 2s - loss: 0.5404 - acc: 0.7465 - val_loss: 0.4247 - val_acc: 0.8300
#
# Epoch 4/10
#  - 2s - loss: 0.5224 - acc: 0.7589 - val_loss: 0.4322 - val_acc: 0.8400
#
# Epoch 5/10
#  - 2s - loss: 0.4939 - acc: 0.7811 - val_loss: 0.4625 - val_acc: 0.7400
#
# Epoch 6/10
#  - 2s - loss: 0.4877 - acc: 0.7837 - val_loss: 0.4723 - val_acc: 0.8000
#
# Epoch 7/10
#  - 2s - loss: 0.4773 - acc: 0.7910 - val_loss: 0.4100 - val_acc: 0.8100
#
# Epoch 8/10
#  - 2s - loss: 0.4664 - acc: 0.7977 - val_loss: 0.4852 - val_acc: 0.7700
#
# Epoch 9/10
#  - 2s - loss: 0.4529 - acc: 0.7977 - val_loss: 0.4752 - val_acc: 0.8000
#
# Epoch 10/10
#  - 2s - loss: 0.4402 - acc: 0.8029 - val_loss: 0.4536 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.7207 - acc: 0.7056 - val_loss: 0.4471 - val_acc: 0.7400
#
# Epoch 2/10
#  - 3s - loss: 0.5585 - acc: 0.7311 - val_loss: 0.4461 - val_acc: 0.8100
#
# Epoch 3/10
#  - 3s - loss: 0.5283 - acc: 0.7595 - val_loss: 0.4532 - val_acc: 0.7600
#
# Epoch 4/10
#  - 3s - loss: 0.5208 - acc: 0.7657 - val_loss: 0.4539 - val_acc: 0.8100
#
# Epoch 5/10
#  - 3s - loss: 0.5190 - acc: 0.7682 - val_loss: 0.5306 - val_acc: 0.7800
#
# Epoch 6/10
#  - 3s - loss: 0.4864 - acc: 0.7738 - val_loss: 0.6938 - val_acc: 0.7300
#
# Epoch 7/10
#  - 3s - loss: 0.4854 - acc: 0.7745 - val_loss: 0.4648 - val_acc: 0.7800
#
# Epoch 8/10
#  - 3s - loss: 0.4911 - acc: 0.7830 - val_loss: 0.5133 - val_acc: 0.7900
#
# Epoch 9/10
#  - 3s - loss: 0.4595 - acc: 0.7903 - val_loss: 0.5037 - val_acc: 0.7600
#
# Epoch 10/10
#  - 3s - loss: 0.4460 - acc: 0.7873 - val_loss: 0.5492 - val_acc: 0.7600
#
# Test accuracy:
# 0.76
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 0.6540 - acc: 0.7097 - val_loss: 0.4945 - val_acc: 0.7900
#
# Epoch 2/10
#  - 2s - loss: 0.5266 - acc: 0.7588 - val_loss: 0.4799 - val_acc: 0.7700
#
# Epoch 3/10
#  - 2s - loss: 0.5107 - acc: 0.7667 - val_loss: 0.4602 - val_acc: 0.7900
#
# Epoch 4/10
#  - 2s - loss: 0.5093 - acc: 0.7745 - val_loss: 0.4395 - val_acc: 0.7700
#
# Epoch 5/10
#  - 2s - loss: 0.4853 - acc: 0.7798 - val_loss: 0.4372 - val_acc: 0.8100
#
# Epoch 6/10
#  - 2s - loss: 0.4765 - acc: 0.7878 - val_loss: 0.4826 - val_acc: 0.8100
#
# Epoch 7/10
#  - 2s - loss: 0.4706 - acc: 0.7931 - val_loss: 0.5087 - val_acc: 0.8100
#
# Epoch 8/10
#  - 2s - loss: 0.4729 - acc: 0.7954 - val_loss: 0.4613 - val_acc: 0.8000
#
# Epoch 9/10
#  - 2s - loss: 0.4498 - acc: 0.7986 - val_loss: 0.4323 - val_acc: 0.7900
#
# Epoch 10/10
#  - 2s - loss: 0.4491 - acc: 0.7967 - val_loss: 0.4355 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.7398 - acc: 0.7182 - val_loss: 0.4293 - val_acc: 0.7600
#
# Epoch 2/10
#  - 3s - loss: 0.5624 - acc: 0.7453 - val_loss: 0.5118 - val_acc: 0.7600
#
# Epoch 3/10
#  - 3s - loss: 0.5512 - acc: 0.7542 - val_loss: 0.4986 - val_acc: 0.7300
#
# Epoch 4/10
#  - 3s - loss: 0.5270 - acc: 0.7607 - val_loss: 0.4821 - val_acc: 0.7800
#
# Epoch 5/10
#  - 3s - loss: 0.5000 - acc: 0.7696 - val_loss: 0.4422 - val_acc: 0.8200
#
# Epoch 6/10
#  - 3s - loss: 0.4882 - acc: 0.7784 - val_loss: 0.4439 - val_acc: 0.8400
#
# Epoch 7/10
#  - 3s - loss: 0.4737 - acc: 0.7825 - val_loss: 0.4853 - val_acc: 0.8200
#
# Epoch 8/10
#  - 3s - loss: 0.4577 - acc: 0.7933 - val_loss: 0.4313 - val_acc: 0.7700
#
# Epoch 9/10
#  - 3s - loss: 0.4464 - acc: 0.7850 - val_loss: 0.5126 - val_acc: 0.8400
#
# Epoch 10/10
#  - 3s - loss: 0.4421 - acc: 0.7958 - val_loss: 0.4568 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.8432 - acc: 0.7274 - val_loss: 0.4628 - val_acc: 0.8000
#
# Epoch 2/10
#  - 3s - loss: 0.5670 - acc: 0.7581 - val_loss: 0.4648 - val_acc: 0.8000
#
# Epoch 3/10
#  - 3s - loss: 0.5338 - acc: 0.7676 - val_loss: 0.5527 - val_acc: 0.8000
#
# Epoch 4/10
#  - 3s - loss: 0.5150 - acc: 0.7685 - val_loss: 0.4502 - val_acc: 0.8000
#
# Epoch 5/10
#  - 3s - loss: 0.5035 - acc: 0.7761 - val_loss: 0.4849 - val_acc: 0.7900
#
# Epoch 6/10
#  - 3s - loss: 0.4894 - acc: 0.7806 - val_loss: 0.4677 - val_acc: 0.8200
#
# Epoch 7/10
#  - 3s - loss: 0.4707 - acc: 0.7889 - val_loss: 0.6022 - val_acc: 0.7700
#
# Epoch 8/10
#  - 3s - loss: 0.4552 - acc: 0.7915 - val_loss: 0.4478 - val_acc: 0.7800
#
# Epoch 9/10
#  - 3s - loss: 0.4545 - acc: 0.7958 - val_loss: 0.5402 - val_acc: 0.8100
#
# Epoch 10/10
#  - 3s - loss: 0.4404 - acc: 0.8025 - val_loss: 0.4690 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.6464 - acc: 0.7327 - val_loss: 0.5552 - val_acc: 0.7400
#
# Epoch 2/10
#  - 3s - loss: 0.4846 - acc: 0.7779 - val_loss: 0.5213 - val_acc: 0.8100
#
# Epoch 3/10
#  - 3s - loss: 0.4739 - acc: 0.7844 - val_loss: 0.4815 - val_acc: 0.8100
#
# Epoch 4/10
#  - 3s - loss: 0.4570 - acc: 0.7860 - val_loss: 0.5431 - val_acc: 0.7700
#
# Epoch 5/10
#  - 3s - loss: 0.4383 - acc: 0.7956 - val_loss: 0.5001 - val_acc: 0.7600
#
# Epoch 6/10
#  - 3s - loss: 0.4402 - acc: 0.8036 - val_loss: 0.6014 - val_acc: 0.7200
#
# Epoch 7/10
#  - 3s - loss: 0.4344 - acc: 0.8057 - val_loss: 0.5569 - val_acc: 0.7400
#
# Epoch 8/10
#  - 3s - loss: 0.4241 - acc: 0.8073 - val_loss: 0.4997 - val_acc: 0.7700
#
# Epoch 9/10
#  - 3s - loss: 0.4084 - acc: 0.8105 - val_loss: 0.4444 - val_acc: 0.7800
#
# Epoch 10/10
#  - 3s - loss: 0.4038 - acc: 0.8202 - val_loss: 0.6719 - val_acc: 0.7300
#
# Test accuracy:
# 0.73
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 0.8972 - acc: 0.7604 - val_loss: 0.5147 - val_acc: 0.7600
#
# Epoch 2/10
#  - 2s - loss: 0.4737 - acc: 0.7924 - val_loss: 0.5354 - val_acc: 0.8100
#
# Epoch 3/10
#  - 2s - loss: 0.4547 - acc: 0.7953 - val_loss: 0.5324 - val_acc: 0.8000
#
# Epoch 4/10
#  - 2s - loss: 0.4347 - acc: 0.8039 - val_loss: 0.5499 - val_acc: 0.8100
#
# Epoch 5/10
#  - 2s - loss: 0.4264 - acc: 0.8068 - val_loss: 0.4590 - val_acc: 0.8000
#
# Epoch 6/10
#  - 2s - loss: 0.4064 - acc: 0.8183 - val_loss: 0.4505 - val_acc: 0.8000
#
# Epoch 7/10
#  - 2s - loss: 0.3920 - acc: 0.8216 - val_loss: 0.4379 - val_acc: 0.7900
#
# Epoch 8/10
#  - 2s - loss: 0.3809 - acc: 0.8255 - val_loss: 0.4253 - val_acc: 0.8100
#
# Epoch 9/10
#  - 2s - loss: 0.3635 - acc: 0.8275 - val_loss: 0.4353 - val_acc: 0.8100
#
# Epoch 10/10
#  - 2s - loss: 0.3531 - acc: 0.8339 - val_loss: 0.4433 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 1.0581 - acc: 0.7194 - val_loss: 0.4575 - val_acc: 0.7800
#
# Epoch 2/10
#  - 3s - loss: 0.6632 - acc: 0.7400 - val_loss: 0.5650 - val_acc: 0.7700
#
# Epoch 3/10
#  - 3s - loss: 0.5954 - acc: 0.7604 - val_loss: 0.5307 - val_acc: 0.7900
#
# Epoch 4/10
#  - 3s - loss: 0.5746 - acc: 0.7529 - val_loss: 0.5474 - val_acc: 0.7900
#
# Epoch 5/10
#  - 3s - loss: 0.5560 - acc: 0.7674 - val_loss: 0.4572 - val_acc: 0.8100
#
# Epoch 6/10
#  - 3s - loss: 0.5535 - acc: 0.7710 - val_loss: 0.4415 - val_acc: 0.8200
#
# Epoch 7/10
#  - 3s - loss: 0.5301 - acc: 0.7744 - val_loss: 0.5124 - val_acc: 0.8100
#
# Epoch 8/10
#  - 3s - loss: 0.5193 - acc: 0.7795 - val_loss: 0.5534 - val_acc: 0.7800
#
# Epoch 9/10
#  - 3s - loss: 0.5100 - acc: 0.7758 - val_loss: 0.4648 - val_acc: 0.8300
#
# Epoch 10/10
#  - 3s - loss: 0.4987 - acc: 0.7811 - val_loss: 0.4561 - val_acc: 0.8400
#
# Test accuracy:
# 0.84
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 1.1002 - acc: 0.6847 - val_loss: 0.4619 - val_acc: 0.7900
#
# Epoch 2/10
#  - 3s - loss: 0.6702 - acc: 0.7442 - val_loss: 0.6523 - val_acc: 0.7600
#
# Epoch 3/10
#  - 3s - loss: 0.6010 - acc: 0.7481 - val_loss: 0.5259 - val_acc: 0.8100
#
# Epoch 4/10
#  - 3s - loss: 0.5847 - acc: 0.7536 - val_loss: 0.5450 - val_acc: 0.7900
#
# Epoch 5/10
#  - 3s - loss: 0.5621 - acc: 0.7607 - val_loss: 0.4366 - val_acc: 0.8200
#
# Epoch 6/10
#  - 3s - loss: 0.5408 - acc: 0.7674 - val_loss: 0.5964 - val_acc: 0.7600
#
# Epoch 7/10
#  - 3s - loss: 0.5332 - acc: 0.7712 - val_loss: 0.5403 - val_acc: 0.7900
#
# Epoch 8/10
#  - 3s - loss: 0.5107 - acc: 0.7742 - val_loss: 0.4779 - val_acc: 0.8100
#
# Epoch 9/10
#  - 3s - loss: 0.4982 - acc: 0.7758 - val_loss: 0.4984 - val_acc: 0.7800
#
# Epoch 10/10
#  - 3s - loss: 0.4998 - acc: 0.7738 - val_loss: 0.5117 - val_acc: 0.7600
#
# Test accuracy:
# 0.76
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 1.0032 - acc: 0.6893 - val_loss: 0.4571 - val_acc: 0.7400
#
# Epoch 2/10
#  - 3s - loss: 0.6196 - acc: 0.7145 - val_loss: 0.5255 - val_acc: 0.7500
#
# Epoch 3/10
#  - 3s - loss: 0.5592 - acc: 0.7453 - val_loss: 0.4360 - val_acc: 0.7600
#
# Epoch 4/10
#  - 3s - loss: 0.5668 - acc: 0.7492 - val_loss: 0.4690 - val_acc: 0.7700
#
# Epoch 5/10
#  - 3s - loss: 0.5291 - acc: 0.7657 - val_loss: 0.4619 - val_acc: 0.7900
#
# Epoch 6/10
#  - 3s - loss: 0.5101 - acc: 0.7724 - val_loss: 0.4815 - val_acc: 0.7600
#
# Epoch 7/10
#  - 3s - loss: 0.5194 - acc: 0.7745 - val_loss: 0.4367 - val_acc: 0.8300
#
# Epoch 8/10
#  - 3s - loss: 0.5008 - acc: 0.7793 - val_loss: 0.4693 - val_acc: 0.7600
#
# Epoch 9/10
#  - 3s - loss: 0.4911 - acc: 0.7891 - val_loss: 0.4420 - val_acc: 0.7900
#
# Epoch 10/10
#  - 3s - loss: 0.4760 - acc: 0.7905 - val_loss: 0.4372 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.1520 - acc: 0.7009 - val_loss: 0.5161 - val_acc: 0.7700
#
# Epoch 2/10
#  - 3s - loss: 0.6653 - acc: 0.7581 - val_loss: 0.4477 - val_acc: 0.8200
#
# Epoch 3/10
#  - 3s - loss: 0.6298 - acc: 0.7671 - val_loss: 0.5076 - val_acc: 0.7500
#
# Epoch 4/10
#  - 3s - loss: 0.5824 - acc: 0.7761 - val_loss: 0.4568 - val_acc: 0.7800
#
# Epoch 5/10
#  - 3s - loss: 0.5706 - acc: 0.7763 - val_loss: 0.5403 - val_acc: 0.7800
#
# Epoch 6/10
#  - 3s - loss: 0.5388 - acc: 0.7745 - val_loss: 0.4644 - val_acc: 0.7600
#
# Epoch 7/10
#  - 3s - loss: 0.5307 - acc: 0.7868 - val_loss: 0.4328 - val_acc: 0.7700
#
# Epoch 8/10
#  - 3s - loss: 0.5173 - acc: 0.7763 - val_loss: 0.4853 - val_acc: 0.7900
#
# Epoch 9/10
#  - 3s - loss: 0.4988 - acc: 0.7924 - val_loss: 0.4456 - val_acc: 0.7700
#
# Epoch 10/10
#  - 3s - loss: 0.4983 - acc: 0.7802 - val_loss: 0.4484 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.7959 - acc: 0.7260 - val_loss: 0.4408 - val_acc: 0.7800
#
# Epoch 2/10
#  - 3s - loss: 0.5563 - acc: 0.7384 - val_loss: 0.5009 - val_acc: 0.8200
#
# Epoch 3/10
#  - 3s - loss: 0.5199 - acc: 0.7667 - val_loss: 0.6102 - val_acc: 0.7300
#
# Epoch 4/10
#  - 3s - loss: 0.5219 - acc: 0.7777 - val_loss: 0.4847 - val_acc: 0.8200
#
# Epoch 5/10
#  - 3s - loss: 0.4959 - acc: 0.7878 - val_loss: 0.5206 - val_acc: 0.7700
#
# Epoch 6/10
#  - 3s - loss: 0.4848 - acc: 0.7942 - val_loss: 0.4567 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.4762 - acc: 0.7953 - val_loss: 0.4525 - val_acc: 0.8000
#
# Epoch 8/10
#  - 3s - loss: 0.4708 - acc: 0.8013 - val_loss: 0.5028 - val_acc: 0.7800
#
# Epoch 9/10
#  - 3s - loss: 0.4641 - acc: 0.8032 - val_loss: 0.4474 - val_acc: 0.7900
#
# Epoch 10/10
#  - 3s - loss: 0.4475 - acc: 0.8034 - val_loss: 0.5944 - val_acc: 0.7500
#
# Test accuracy:
# 0.75
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.8891 - acc: 0.7051 - val_loss: 0.5284 - val_acc: 0.7100
#
# Epoch 2/10
#  - 3s - loss: 0.6001 - acc: 0.7361 - val_loss: 0.4617 - val_acc: 0.7200
#
# Epoch 3/10
#  - 3s - loss: 0.5611 - acc: 0.7602 - val_loss: 0.5095 - val_acc: 0.8000
#
# Epoch 4/10
#  - 3s - loss: 0.5449 - acc: 0.7696 - val_loss: 0.4996 - val_acc: 0.7300
#
# Epoch 5/10
#  - 3s - loss: 0.5234 - acc: 0.7752 - val_loss: 0.4465 - val_acc: 0.8000
#
# Epoch 6/10
#  - 3s - loss: 0.4957 - acc: 0.7883 - val_loss: 0.4384 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.4987 - acc: 0.7921 - val_loss: 0.4431 - val_acc: 0.7900
#
# Epoch 8/10
#  - 3s - loss: 0.4723 - acc: 0.7944 - val_loss: 0.4655 - val_acc: 0.8100
#
# Epoch 9/10
#  - 3s - loss: 0.4664 - acc: 0.7953 - val_loss: 0.4565 - val_acc: 0.8000
#
# Epoch 10/10
#  - 3s - loss: 0.4530 - acc: 0.8016 - val_loss: 0.5061 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.7628 - acc: 0.7200 - val_loss: 0.4268 - val_acc: 0.8000
#
# Epoch 2/10
#  - 3s - loss: 0.5700 - acc: 0.7577 - val_loss: 0.4751 - val_acc: 0.8100
#
# Epoch 3/10
#  - 3s - loss: 0.5529 - acc: 0.7736 - val_loss: 0.4492 - val_acc: 0.7200
#
# Epoch 4/10
#  - 3s - loss: 0.5211 - acc: 0.7830 - val_loss: 0.4379 - val_acc: 0.7500
#
# Epoch 5/10
#  - 3s - loss: 0.4992 - acc: 0.7806 - val_loss: 0.5298 - val_acc: 0.7500
#
# Epoch 6/10
#  - 3s - loss: 0.5053 - acc: 0.7829 - val_loss: 0.4550 - val_acc: 0.7600
#
# Epoch 7/10
#  - 3s - loss: 0.4855 - acc: 0.7866 - val_loss: 0.4266 - val_acc: 0.8000
#
# Epoch 8/10
#  - 3s - loss: 0.4919 - acc: 0.7887 - val_loss: 0.4566 - val_acc: 0.8100
#
# Epoch 9/10
#  - 3s - loss: 0.4884 - acc: 0.7919 - val_loss: 0.4201 - val_acc: 0.7800
#
# Epoch 10/10
#  - 3s - loss: 0.4605 - acc: 0.7954 - val_loss: 0.4450 - val_acc: 0.8400
#
# Test accuracy:
# 0.84
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.0001 - acc: 0.6955 - val_loss: 0.5824 - val_acc: 0.7800
#
# Epoch 2/10
#  - 3s - loss: 0.6319 - acc: 0.7379 - val_loss: 0.5412 - val_acc: 0.8000
#
# Epoch 3/10
#  - 3s - loss: 0.5756 - acc: 0.7487 - val_loss: 0.4480 - val_acc: 0.8100
#
# Epoch 4/10
#  - 3s - loss: 0.5600 - acc: 0.7595 - val_loss: 0.4929 - val_acc: 0.7600
#
# Epoch 5/10
#  - 3s - loss: 0.5543 - acc: 0.7623 - val_loss: 0.4851 - val_acc: 0.7800
#
# Epoch 6/10
#  - 3s - loss: 0.5532 - acc: 0.7568 - val_loss: 0.4203 - val_acc: 0.8000
#
# Epoch 7/10
#  - 3s - loss: 0.5126 - acc: 0.7705 - val_loss: 0.4662 - val_acc: 0.8000
#
# Epoch 8/10
#  - 3s - loss: 0.5205 - acc: 0.7791 - val_loss: 0.5062 - val_acc: 0.8200
#
# Epoch 9/10
#  - 3s - loss: 0.5000 - acc: 0.7788 - val_loss: 0.5327 - val_acc: 0.8300
#
# Epoch 10/10
#  - 3s - loss: 0.4907 - acc: 0.7802 - val_loss: 0.5133 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 0.8385 - acc: 0.7207 - val_loss: 0.4953 - val_acc: 0.7800
#
# Epoch 2/10
#  - 3s - loss: 0.5867 - acc: 0.7524 - val_loss: 0.4876 - val_acc: 0.7600
#
# Epoch 3/10
#  - 3s - loss: 0.5351 - acc: 0.7767 - val_loss: 0.4757 - val_acc: 0.8100
#
# Epoch 4/10
#  - 3s - loss: 0.5098 - acc: 0.7800 - val_loss: 0.5244 - val_acc: 0.7500
#
# Epoch 5/10
#  - 3s - loss: 0.5020 - acc: 0.7821 - val_loss: 0.4785 - val_acc: 0.8300
#
# Epoch 6/10
#  - 3s - loss: 0.4848 - acc: 0.7868 - val_loss: 0.4379 - val_acc: 0.8400
#
# Epoch 7/10
#  - 3s - loss: 0.4756 - acc: 0.7922 - val_loss: 0.4467 - val_acc: 0.8200
#
# Epoch 8/10
#  - 3s - loss: 0.4696 - acc: 0.7864 - val_loss: 0.4230 - val_acc: 0.8100
#
# Epoch 9/10
#  - 3s - loss: 0.4608 - acc: 0.8000 - val_loss: 0.4082 - val_acc: 0.8400
#
# Epoch 10/10
#  - 3s - loss: 0.4492 - acc: 0.7988 - val_loss: 0.4793 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 5646 samples, validate on 100 samples
# Epoch 1/10
#  - 5s - loss: 1.1794 - acc: 0.6725 - val_loss: 0.4181 - val_acc: 0.7600
#
# Epoch 2/10
#  - 3s - loss: 0.7017 - acc: 0.6686 - val_loss: 0.4524 - val_acc: 0.7800
#
# Epoch 3/10
#  - 3s - loss: 0.6599 - acc: 0.6495 - val_loss: 0.4088 - val_acc: 0.7200
#
# Epoch 4/10
#  - 3s - loss: 0.6274 - acc: 0.7047 - val_loss: 0.4392 - val_acc: 0.7900
#
# Epoch 5/10
#  - 3s - loss: 0.6141 - acc: 0.7533 - val_loss: 0.4513 - val_acc: 0.8200
#
# Epoch 6/10
#  - 3s - loss: 0.5851 - acc: 0.7488 - val_loss: 0.4505 - val_acc: 0.7900
#
# Epoch 7/10
#  - 3s - loss: 0.5741 - acc: 0.7612 - val_loss: 0.5024 - val_acc: 0.7600
#
# Epoch 8/10
#  - 3s - loss: 0.5722 - acc: 0.7673 - val_loss: 0.4129 - val_acc: 0.8100
#
# Epoch 9/10
#  - 3s - loss: 0.5517 - acc: 0.7662 - val_loss: 0.4689 - val_acc: 0.7800
#
# Epoch 10/10
#  - 3s - loss: 0.5336 - acc: 0.7742 - val_loss: 0.4394 - val_acc: 0.8300
#
# Test accuracy:
# 0.83
# 100%|██████████| 30/30 [15:22<00:00, 29.11s/it, best loss: -0.84]
# Time on optimization: 15.404257253805797 minutes
#
# Summary of the best model: -----------------------
# Evalutation of best performing model:
# 100/100 [==============================] - 0s 292us/step
# [0.4561154294013977, 0.84]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_21 (InputLayer)        (None, 64, 64, 5, 1)      0
# _________________________________________________________________
# conv3d_21 (Conv3D)           (None, 62, 62, 3, 48)     1344
# _________________________________________________________________
# max_pooling3d_21 (MaxPooling (None, 31, 31, 1, 48)     0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 46128)             0
# _________________________________________________________________
# dense_61 (Dense)             (None, 64)                2952256
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_62 (Dense)             (None, 24)                1560
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 1)                 25
# =================================================================
# Total params: 2,955,185
# Trainable params: 2,955,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# Conv 1: 48 unidades
# Dense 1: 96 unidades
# Dense 2: 24 unidades
# Dropout 1: 0.41935233640034336
# Dropout 2: 0.4642243750136609
