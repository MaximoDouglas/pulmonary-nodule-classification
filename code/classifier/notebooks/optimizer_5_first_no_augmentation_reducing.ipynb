# %% [markdown]
# # Colab config

# %%
from google.colab import drive
drive.mount('drive', force_remount=True)

# %%
# !pip install hyperas

# %% [markdown]
# ## Imports

# %%
import os

import time

import gc

import numpy as np

from scipy import interp

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, roc_curve, auc

from keras import backend as K
from keras import optimizers
from keras.layers import Conv3D, MaxPool3D, Flatten, Dense, Dropout, Input
from keras.losses import binary_crossentropy
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.utils.vis_utils import plot_model, model_to_dot
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## GPU configuration

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 1
set_session(tf.Session(config=config))
session = tf.Session(config=config)

# %% [markdown]
# # Hyperparameters optimization
#
# Func **data()** required by Hyperas. It must return 4 arrays X_train, Y_train, X_test, Y_test.
#
# The data for optimization are on four numpy files, generated with the notebook **import_images.ipynb**.

# %%
'''5-first-no-augmentation'''

def data():
  prefix = "/content/drive/My Drive/Pesquisa - Dicom images/data/no_aug_nps_reducing/data-5-first"
  X_train = np.load(prefix + "/X_train.npy")
  X_test = np.load(prefix + "/X_test.npy")
  Y_train = np.load(prefix + "/Y_train.npy")
  Y_test = np.load(prefix + "/Y_test.npy")
  
  return X_train, Y_train, X_test, Y_test

# %% [markdown]
# ## Space of search definition
#
# * **conv_layer1**: [32, 48, 64, 96] unities
# * **dense_layer1**: [32, 64, 128, 256] unities
# * **dense_layer2**: [8, 16, 24, 32] unities
# * **dropout** on dense layers: between 0 and 0.5

# %%
conv1 = [32, 48, 64, 96]
dense1 = [64, 96, 128]
dense2 = [16, 24, 32]
    
def model(X_train, Y_train, X_test, Y_test):
    conv1 = {{choice([32, 48, 64, 96])}}
    dense1 = {{choice([32, 64, 128])}}
    dense2 = {{choice([16, 24, 32])}}
    
    input_layer = Input(X_train.shape[1:5])
    
    conv_layer1 = Conv3D(conv1, kernel_size=(3, 3, 3), activation='relu')(input_layer)
    pooling_layer1 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer1)
    
    flatten_layer = Flatten()(pooling_layer1)
    
    dense_layer1 = Dense(dense1, activation='relu')(flatten_layer)
    dense_layer1 = Dropout({{uniform(0, .5)}})(dense_layer1)
    
    dense_layer2 = Dense(dense2, activation='relu')(dense_layer1)
    dense_layer2 = Dropout({{uniform(0, .5)}})(dense_layer2)
    
    output_layer = Dense(units=1, activation='sigmoid')(dense_layer2)
    
    model = Model(inputs=input_layer, outputs=output_layer)
    
    opt = optimizers.RMSprop(lr=0.0001)
    
    model.compile(loss=binary_crossentropy, optimizer=opt, metrics=['acc'])
    
    model.fit(X_train, Y_train,
              batch_size=128,
              epochs=10,
              verbose=2,
              validation_data=(X_test, Y_test)
              )
    
    score, acc = model.evaluate(X_test, Y_test, verbose=0)
    
    print('Test accuracy:', acc)
    
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %% [markdown]
# ## Otimization

# %%
X_train, Y_train, X_test, Y_test = data()

start = time.time()

best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=30,
                                      trials=Trials(),
                                      verbose=False,
                                      notebook_name='drive/My Drive/Pesquisa - Dicom images/notebooks/optimizer_5_first_no_augmentation_reducing')
end = time.time()

print("Time on optimization:", (end - start)/60, "minutes")

print()
print('Summary of the best model: -----------------------')

print("Evalutation of best performing model:")
print(best_model.evaluate(X_test, Y_test))

print(best_model.summary())

c1 = conv1[best_run['conv1']]
d1 = dense1[best_run['dense1']]
d2 = dense2[best_run['dense2']]
drop1 = best_run['Dropout']
drop2 = best_run['Dropout_1']

print('Conv 1:', c1, 'unidades')
print('Dense 1:', d1, 'unidades')
print('Dense 2:', d2, 'unidades')
print('Dropout 1:', drop1)
print('Dropout 2:', drop2)
# Out:
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 1.8265 - acc: 0.6475 - val_loss: 0.7229 - val_acc: 0.7400
#
# Epoch 2/10
#  - 0s - loss: 1.0550 - acc: 0.7097 - val_loss: 0.5331 - val_acc: 0.7200
#
# Epoch 3/10
#  - 0s - loss: 0.9105 - acc: 0.7281 - val_loss: 0.5029 - val_acc: 0.7600
#
# Epoch 4/10
#  - 0s - loss: 0.8497 - acc: 0.7166 - val_loss: 0.4356 - val_acc: 0.8000
#
# Epoch 5/10
#  - 0s - loss: 0.7670 - acc: 0.7258 - val_loss: 0.4444 - val_acc: 0.7600
#
# Epoch 6/10
#  - 0s - loss: 0.6307 - acc: 0.7396 - val_loss: 0.4337 - val_acc: 0.7400
#
# Epoch 7/10
#  - 0s - loss: 0.6590 - acc: 0.7281 - val_loss: 0.4576 - val_acc: 0.7800
#
# Epoch 8/10
#  - 0s - loss: 0.6464 - acc: 0.7627 - val_loss: 0.4828 - val_acc: 0.7600
#
# Epoch 9/10
#  - 0s - loss: 0.7225 - acc: 0.7442 - val_loss: 0.4371 - val_acc: 0.7800
#
# Epoch 10/10
#  - 0s - loss: 0.5399 - acc: 0.7742 - val_loss: 0.4630 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 3.5825 - acc: 0.5899 - val_loss: 0.6021 - val_acc: 0.7600
#
# Epoch 2/10
#  - 0s - loss: 0.9377 - acc: 0.6889 - val_loss: 0.4678 - val_acc: 0.7800
#
# Epoch 3/10
#  - 0s - loss: 0.7168 - acc: 0.6935 - val_loss: 0.4112 - val_acc: 0.8100
#
# Epoch 4/10
#  - 0s - loss: 0.5905 - acc: 0.7235 - val_loss: 0.4091 - val_acc: 0.8200
#
# Epoch 5/10
#  - 0s - loss: 0.5978 - acc: 0.7696 - val_loss: 0.4219 - val_acc: 0.8300
#
# Epoch 6/10
#  - 0s - loss: 0.4939 - acc: 0.7558 - val_loss: 0.4670 - val_acc: 0.7900
#
# Epoch 7/10
#  - 0s - loss: 0.5748 - acc: 0.7350 - val_loss: 0.4275 - val_acc: 0.8200
#
# Epoch 8/10
#  - 0s - loss: 0.6055 - acc: 0.7304 - val_loss: 0.4208 - val_acc: 0.8400
#
# Epoch 9/10
#  - 0s - loss: 0.5255 - acc: 0.7834 - val_loss: 0.4221 - val_acc: 0.8400
#
# Epoch 10/10
#  - 0s - loss: 0.4517 - acc: 0.7673 - val_loss: 0.4198 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 2.3560 - acc: 0.6359 - val_loss: 0.7417 - val_acc: 0.7200
#
# Epoch 2/10
#  - 0s - loss: 1.0247 - acc: 0.7396 - val_loss: 0.4762 - val_acc: 0.7700
#
# Epoch 3/10
#  - 0s - loss: 0.8020 - acc: 0.7650 - val_loss: 0.5435 - val_acc: 0.7200
#
# Epoch 4/10
#  - 0s - loss: 0.8568 - acc: 0.7373 - val_loss: 0.4809 - val_acc: 0.7800
#
# Epoch 5/10
#  - 0s - loss: 0.8009 - acc: 0.7650 - val_loss: 0.4281 - val_acc: 0.8200
#
# Epoch 6/10
#  - 0s - loss: 0.6600 - acc: 0.7627 - val_loss: 0.4536 - val_acc: 0.8100
#
# Epoch 7/10
#  - 0s - loss: 0.6255 - acc: 0.7512 - val_loss: 0.4329 - val_acc: 0.8100
#
# Epoch 8/10
#  - 0s - loss: 0.5235 - acc: 0.7673 - val_loss: 0.4447 - val_acc: 0.7700
#
# Epoch 9/10
#  - 0s - loss: 0.6693 - acc: 0.7350 - val_loss: 0.4593 - val_acc: 0.8000
#
# Epoch 10/10
#  - 0s - loss: 0.5520 - acc: 0.7581 - val_loss: 0.4412 - val_acc: 0.7100
#
# Test accuracy:
# 0.71
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 2.7406 - acc: 0.6014 - val_loss: 0.7212 - val_acc: 0.7100
#
# Epoch 2/10
#  - 0s - loss: 1.0352 - acc: 0.6866 - val_loss: 0.5777 - val_acc: 0.7400
#
# Epoch 3/10
#  - 0s - loss: 0.7740 - acc: 0.7419 - val_loss: 0.5596 - val_acc: 0.7500
#
# Epoch 4/10
#  - 0s - loss: 0.6826 - acc: 0.7627 - val_loss: 0.4593 - val_acc: 0.7800
#
# Epoch 5/10
#  - 0s - loss: 0.5764 - acc: 0.7765 - val_loss: 0.5259 - val_acc: 0.7600
#
# Epoch 6/10
#  - 0s - loss: 0.6370 - acc: 0.7465 - val_loss: 0.4493 - val_acc: 0.7700
#
# Epoch 7/10
#  - 0s - loss: 0.5980 - acc: 0.7581 - val_loss: 0.5133 - val_acc: 0.8000
#
# Epoch 8/10
#  - 0s - loss: 0.5843 - acc: 0.7696 - val_loss: 0.5722 - val_acc: 0.7900
#
# Epoch 9/10
#  - 0s - loss: 0.5710 - acc: 0.7650 - val_loss: 0.4775 - val_acc: 0.7500
#
# Epoch 10/10
#  - 0s - loss: 0.5404 - acc: 0.7811 - val_loss: 0.4402 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 5.2157 - acc: 0.5161 - val_loss: 0.8668 - val_acc: 0.7500
#
# Epoch 2/10
#  - 0s - loss: 1.9664 - acc: 0.6544 - val_loss: 0.7862 - val_acc: 0.7400
#
# Epoch 3/10
#  - 0s - loss: 1.0463 - acc: 0.7581 - val_loss: 1.4835 - val_acc: 0.6500
#
# Epoch 4/10
#  - 0s - loss: 1.0493 - acc: 0.7097 - val_loss: 0.5823 - val_acc: 0.7300
#
# Epoch 5/10
#  - 0s - loss: 0.6331 - acc: 0.7535 - val_loss: 0.4728 - val_acc: 0.7300
#
# Epoch 6/10
#  - 0s - loss: 0.6225 - acc: 0.7650 - val_loss: 0.4722 - val_acc: 0.7400
#
# Epoch 7/10
#  - 0s - loss: 0.6201 - acc: 0.7535 - val_loss: 0.5191 - val_acc: 0.7200
#
# Epoch 8/10
#  - 0s - loss: 0.6067 - acc: 0.7488 - val_loss: 0.4472 - val_acc: 0.7100
#
# Epoch 9/10
#  - 0s - loss: 0.5828 - acc: 0.7212 - val_loss: 0.4113 - val_acc: 0.7300
#
# Epoch 10/10
#  - 0s - loss: 0.5293 - acc: 0.7742 - val_loss: 0.5674 - val_acc: 0.7400
#
# Test accuracy:
# 0.74
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 1.9363 - acc: 0.6313 - val_loss: 0.6559 - val_acc: 0.7900
#
# Epoch 2/10
#  - 0s - loss: 1.1152 - acc: 0.7558 - val_loss: 0.4823 - val_acc: 0.7800
#
# Epoch 3/10
#  - 0s - loss: 1.1073 - acc: 0.7051 - val_loss: 0.5021 - val_acc: 0.7900
#
# Epoch 4/10
#  - 0s - loss: 0.9994 - acc: 0.7442 - val_loss: 0.5752 - val_acc: 0.7500
#
# Epoch 5/10
#  - 0s - loss: 0.9301 - acc: 0.7627 - val_loss: 0.4512 - val_acc: 0.7700
#
# Epoch 6/10
#  - 0s - loss: 0.7333 - acc: 0.7581 - val_loss: 0.4505 - val_acc: 0.7500
#
# Epoch 7/10
#  - 0s - loss: 0.8110 - acc: 0.7304 - val_loss: 0.4205 - val_acc: 0.8000
#
# Epoch 8/10
#  - 0s - loss: 0.7393 - acc: 0.7350 - val_loss: 0.4170 - val_acc: 0.7800
#
# Epoch 9/10
#  - 0s - loss: 0.6730 - acc: 0.7143 - val_loss: 0.5012 - val_acc: 0.7700
#
# Epoch 10/10
#  - 0s - loss: 0.7413 - acc: 0.7581 - val_loss: 0.4236 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 1s - loss: 1.5290 - acc: 0.6060 - val_loss: 0.5636 - val_acc: 0.7700
#
# Epoch 2/10
#  - 0s - loss: 0.8430 - acc: 0.6290 - val_loss: 0.5088 - val_acc: 0.7200
#
# Epoch 3/10
#  - 0s - loss: 0.6295 - acc: 0.6382 - val_loss: 0.4463 - val_acc: 0.7800
#
# Epoch 4/10
#  - 0s - loss: 0.5708 - acc: 0.7442 - val_loss: 0.4355 - val_acc: 0.7700
#
# Epoch 5/10
#  - 0s - loss: 0.4878 - acc: 0.7696 - val_loss: 0.4457 - val_acc: 0.7900
#
# Epoch 6/10
#  - 0s - loss: 0.4922 - acc: 0.7396 - val_loss: 0.4874 - val_acc: 0.7100
#
# Epoch 7/10
#  - 0s - loss: 0.5556 - acc: 0.7235 - val_loss: 0.4392 - val_acc: 0.7900
#
# Epoch 8/10
#  - 0s - loss: 0.5293 - acc: 0.7465 - val_loss: 0.4497 - val_acc: 0.8000
#
# Epoch 9/10
#  - 0s - loss: 0.5234 - acc: 0.7419 - val_loss: 0.4272 - val_acc: 0.7900
#
# Epoch 10/10
#  - 0s - loss: 0.4664 - acc: 0.7765 - val_loss: 0.4318 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 2.1402 - acc: 0.6475 - val_loss: 0.6813 - val_acc: 0.7400
#
# Epoch 2/10
#  - 0s - loss: 0.9252 - acc: 0.7212 - val_loss: 0.6825 - val_acc: 0.6900
#
# Epoch 3/10
#  - 0s - loss: 0.7382 - acc: 0.7465 - val_loss: 0.4746 - val_acc: 0.7300
#
# Epoch 4/10
#  - 0s - loss: 0.5875 - acc: 0.7949 - val_loss: 0.4901 - val_acc: 0.7200
#
# Epoch 5/10
#  - 0s - loss: 0.5325 - acc: 0.7696 - val_loss: 0.4855 - val_acc: 0.7700
#
# Epoch 6/10
#  - 0s - loss: 0.6273 - acc: 0.7742 - val_loss: 0.4515 - val_acc: 0.7600
#
# Epoch 7/10
#  - 0s - loss: 0.4666 - acc: 0.8065 - val_loss: 0.4962 - val_acc: 0.7100
#
# Epoch 8/10
#  - 0s - loss: 0.4426 - acc: 0.8226 - val_loss: 0.4851 - val_acc: 0.7900
#
# Epoch 9/10
#  - 0s - loss: 0.5082 - acc: 0.7995 - val_loss: 0.6790 - val_acc: 0.7200
#
# Epoch 10/10
#  - 0s - loss: 0.4354 - acc: 0.8341 - val_loss: 0.4150 - val_acc: 0.7800
#
# Test accuracy:
# 0.78
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 2.4284 - acc: 0.6429 - val_loss: 0.6130 - val_acc: 0.7600
#
# Epoch 2/10
#  - 0s - loss: 0.7538 - acc: 0.7419 - val_loss: 0.5727 - val_acc: 0.7700
#
# Epoch 3/10
#  - 0s - loss: 0.6334 - acc: 0.7765 - val_loss: 0.5222 - val_acc: 0.7500
#
# Epoch 4/10
#  - 0s - loss: 0.5143 - acc: 0.7857 - val_loss: 0.4613 - val_acc: 0.7700
#
# Epoch 5/10
#  - 0s - loss: 0.5418 - acc: 0.7903 - val_loss: 0.6460 - val_acc: 0.6300
#
# Epoch 6/10
#  - 0s - loss: 0.5974 - acc: 0.7857 - val_loss: 0.5354 - val_acc: 0.7400
#
# Epoch 7/10
#  - 0s - loss: 0.4908 - acc: 0.8018 - val_loss: 0.4270 - val_acc: 0.8100
#
# Epoch 8/10
#  - 0s - loss: 0.5222 - acc: 0.7765 - val_loss: 0.4636 - val_acc: 0.7600
#
# Epoch 9/10
#  - 0s - loss: 0.4940 - acc: 0.7903 - val_loss: 0.4333 - val_acc: 0.7600
#
# Epoch 10/10
#  - 0s - loss: 0.4428 - acc: 0.8157 - val_loss: 0.4307 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.0913 - acc: 0.6774 - val_loss: 0.4852 - val_acc: 0.7600
#
# Epoch 2/10
#  - 0s - loss: 0.5509 - acc: 0.7765 - val_loss: 0.4538 - val_acc: 0.7000
#
# Epoch 3/10
#  - 0s - loss: 0.6061 - acc: 0.7535 - val_loss: 0.5096 - val_acc: 0.7000
#
# Epoch 4/10
#  - 0s - loss: 0.5085 - acc: 0.7742 - val_loss: 0.4375 - val_acc: 0.7400
#
# Epoch 5/10
#  - 0s - loss: 0.4429 - acc: 0.8065 - val_loss: 0.4479 - val_acc: 0.7800
#
# Epoch 6/10
#  - 0s - loss: 0.4219 - acc: 0.8088 - val_loss: 0.5662 - val_acc: 0.7300
#
# Epoch 7/10
#  - 0s - loss: 0.5969 - acc: 0.7350 - val_loss: 0.4385 - val_acc: 0.7800
#
# Epoch 8/10
#  - 0s - loss: 0.4258 - acc: 0.8249 - val_loss: 0.3980 - val_acc: 0.8000
#
# Epoch 9/10
#  - 0s - loss: 0.4633 - acc: 0.7995 - val_loss: 0.4502 - val_acc: 0.7900
#
# Epoch 10/10
#  - 0s - loss: 0.3603 - acc: 0.8249 - val_loss: 0.4202 - val_acc: 0.8100
#
# Test accuracy:
# 0.81
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.5802 - acc: 0.6959 - val_loss: 0.4482 - val_acc: 0.7700
#
# Epoch 2/10
#  - 0s - loss: 0.8159 - acc: 0.7465 - val_loss: 0.4488 - val_acc: 0.7700
#
# Epoch 3/10
#  - 0s - loss: 0.7650 - acc: 0.7419 - val_loss: 0.5837 - val_acc: 0.7600
#
# Epoch 4/10
#  - 0s - loss: 0.6114 - acc: 0.7834 - val_loss: 0.4419 - val_acc: 0.7800
#
# Epoch 5/10
#  - 0s - loss: 0.6169 - acc: 0.7719 - val_loss: 0.4428 - val_acc: 0.7500
#
# Epoch 6/10
#  - 0s - loss: 0.6239 - acc: 0.7604 - val_loss: 0.4388 - val_acc: 0.7200
#
# Epoch 7/10
#  - 0s - loss: 0.6321 - acc: 0.7419 - val_loss: 0.4385 - val_acc: 0.7800
#
# Epoch 8/10
#  - 0s - loss: 0.5779 - acc: 0.7650 - val_loss: 0.4473 - val_acc: 0.7300
#
# Epoch 9/10
#  - 0s - loss: 0.5912 - acc: 0.7742 - val_loss: 0.4859 - val_acc: 0.7700
#
# Epoch 10/10
#  - 0s - loss: 0.5482 - acc: 0.7880 - val_loss: 0.4757 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 2.0670 - acc: 0.6382 - val_loss: 0.6950 - val_acc: 0.7600
#
# Epoch 2/10
#  - 0s - loss: 0.9140 - acc: 0.7189 - val_loss: 0.6618 - val_acc: 0.7400
#
# Epoch 3/10
#  - 0s - loss: 0.7152 - acc: 0.7535 - val_loss: 0.5504 - val_acc: 0.7500
#
# Epoch 4/10
#  - 0s - loss: 0.5983 - acc: 0.7857 - val_loss: 0.5307 - val_acc: 0.7600
#
# Epoch 5/10
#  - 0s - loss: 0.6136 - acc: 0.7673 - val_loss: 0.4848 - val_acc: 0.7900
#
# Epoch 6/10
#  - 0s - loss: 0.5666 - acc: 0.7972 - val_loss: 0.4785 - val_acc: 0.7800
#
# Epoch 7/10
#  - 0s - loss: 0.4844 - acc: 0.8111 - val_loss: 0.4804 - val_acc: 0.8000
#
# Epoch 8/10
#  - 0s - loss: 0.4806 - acc: 0.8018 - val_loss: 0.5043 - val_acc: 0.7900
#
# Epoch 9/10
#  - 0s - loss: 0.4272 - acc: 0.8226 - val_loss: 0.6240 - val_acc: 0.7900
#
# Epoch 10/10
#  - 0s - loss: 0.5427 - acc: 0.8065 - val_loss: 0.5524 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 2.8111 - acc: 0.5714 - val_loss: 1.2819 - val_acc: 0.7500
#
# Epoch 2/10
#  - 0s - loss: 1.1704 - acc: 0.7742 - val_loss: 0.6334 - val_acc: 0.7300
#
# Epoch 3/10
#  - 0s - loss: 0.7543 - acc: 0.7673 - val_loss: 0.6108 - val_acc: 0.7800
#
# Epoch 4/10
#  - 0s - loss: 0.6880 - acc: 0.7765 - val_loss: 0.5435 - val_acc: 0.8100
#
# Epoch 5/10
#  - 0s - loss: 0.5736 - acc: 0.8088 - val_loss: 0.6372 - val_acc: 0.7600
#
# Epoch 6/10
#  - 0s - loss: 0.6998 - acc: 0.7834 - val_loss: 0.4794 - val_acc: 0.7400
#
# Epoch 7/10
#  - 0s - loss: 0.5559 - acc: 0.7857 - val_loss: 0.7880 - val_acc: 0.6200
#
# Epoch 8/10
#  - 0s - loss: 0.5699 - acc: 0.7627 - val_loss: 0.4710 - val_acc: 0.7400
#
# Epoch 9/10
#  - 0s - loss: 0.4838 - acc: 0.8065 - val_loss: 0.5330 - val_acc: 0.7400
#
# Epoch 10/10
#  - 0s - loss: 0.5349 - acc: 0.8018 - val_loss: 0.4583 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.9952 - acc: 0.5622 - val_loss: 0.5303 - val_acc: 0.7300
#
# Epoch 2/10
#  - 0s - loss: 0.7880 - acc: 0.7005 - val_loss: 0.4363 - val_acc: 0.7900
#
# Epoch 3/10
#  - 0s - loss: 0.6227 - acc: 0.7604 - val_loss: 0.4341 - val_acc: 0.7600
#
# Epoch 4/10
#  - 0s - loss: 0.5421 - acc: 0.7465 - val_loss: 0.4366 - val_acc: 0.7600
#
# Epoch 5/10
#  - 0s - loss: 0.5246 - acc: 0.7742 - val_loss: 0.4257 - val_acc: 0.7700
#
# Epoch 6/10
#  - 0s - loss: 0.4688 - acc: 0.8065 - val_loss: 0.4557 - val_acc: 0.7600
#
# Epoch 7/10
#  - 0s - loss: 0.5362 - acc: 0.7880 - val_loss: 0.4899 - val_acc: 0.7800
#
# Epoch 8/10
#  - 0s - loss: 0.4814 - acc: 0.7765 - val_loss: 0.4591 - val_acc: 0.7700
#
# Epoch 9/10
#  - 0s - loss: 0.4530 - acc: 0.7903 - val_loss: 0.4103 - val_acc: 0.7700
#
# Epoch 10/10
#  - 0s - loss: 0.4618 - acc: 0.8088 - val_loss: 0.4310 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.6217 - acc: 0.6152 - val_loss: 0.5709 - val_acc: 0.7400
#
# Epoch 2/10
#  - 0s - loss: 0.9226 - acc: 0.7097 - val_loss: 0.4495 - val_acc: 0.8000
#
# Epoch 3/10
#  - 0s - loss: 0.7422 - acc: 0.6797 - val_loss: 0.4878 - val_acc: 0.7600
#
# Epoch 4/10
#  - 0s - loss: 0.5422 - acc: 0.7258 - val_loss: 0.4909 - val_acc: 0.7400
#
# Epoch 5/10
#  - 0s - loss: 0.6407 - acc: 0.6774 - val_loss: 0.4396 - val_acc: 0.7700
#
# Epoch 6/10
#  - 0s - loss: 0.5923 - acc: 0.6889 - val_loss: 0.4240 - val_acc: 0.7700
#
# Epoch 7/10
#  - 0s - loss: 0.5267 - acc: 0.6935 - val_loss: 0.4333 - val_acc: 0.7500
#
# Epoch 8/10
#  - 0s - loss: 0.4900 - acc: 0.7327 - val_loss: 0.4434 - val_acc: 0.7500
#
# Epoch 9/10
#  - 0s - loss: 0.5656 - acc: 0.6982 - val_loss: 0.4196 - val_acc: 0.7900
#
# Epoch 10/10
#  - 0s - loss: 0.4830 - acc: 0.7512 - val_loss: 0.4193 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 2.2509 - acc: 0.6521 - val_loss: 0.6764 - val_acc: 0.7400
#
# Epoch 2/10
#  - 0s - loss: 1.1348 - acc: 0.6959 - val_loss: 0.5665 - val_acc: 0.7700
#
# Epoch 3/10
#  - 0s - loss: 1.0558 - acc: 0.7028 - val_loss: 0.5695 - val_acc: 0.8100
#
# Epoch 4/10
#  - 0s - loss: 0.7537 - acc: 0.7535 - val_loss: 0.5480 - val_acc: 0.8000
#
# Epoch 5/10
#  - 0s - loss: 0.7242 - acc: 0.7834 - val_loss: 0.5055 - val_acc: 0.8100
#
# Epoch 6/10
#  - 0s - loss: 0.7040 - acc: 0.7903 - val_loss: 0.4481 - val_acc: 0.7900
#
# Epoch 7/10
#  - 0s - loss: 0.6371 - acc: 0.7627 - val_loss: 0.4563 - val_acc: 0.7800
#
# Epoch 8/10
#  - 0s - loss: 0.5847 - acc: 0.7903 - val_loss: 0.4492 - val_acc: 0.7700
#
# Epoch 9/10
#  - 0s - loss: 0.4700 - acc: 0.7788 - val_loss: 0.4518 - val_acc: 0.7900
#
# Epoch 10/10
#  - 0s - loss: 0.5279 - acc: 0.7788 - val_loss: 0.5117 - val_acc: 0.7600
#
# Test accuracy:
# 0.76
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 2.1862 - acc: 0.5645 - val_loss: 0.7295 - val_acc: 0.8000
#
# Epoch 2/10
#  - 0s - loss: 0.8238 - acc: 0.7650 - val_loss: 0.4406 - val_acc: 0.7200
#
# Epoch 3/10
#  - 0s - loss: 0.6482 - acc: 0.7581 - val_loss: 0.4760 - val_acc: 0.7800
#
# Epoch 4/10
#  - 0s - loss: 0.6480 - acc: 0.7535 - val_loss: 0.4317 - val_acc: 0.7100
#
# Epoch 5/10
#  - 0s - loss: 0.6023 - acc: 0.7581 - val_loss: 0.4280 - val_acc: 0.8000
#
# Epoch 6/10
#  - 0s - loss: 0.5471 - acc: 0.7811 - val_loss: 0.4412 - val_acc: 0.7500
#
# Epoch 7/10
#  - 0s - loss: 0.5643 - acc: 0.7719 - val_loss: 0.4481 - val_acc: 0.7000
#
# Epoch 8/10
#  - 0s - loss: 0.5571 - acc: 0.7488 - val_loss: 0.4612 - val_acc: 0.7700
#
# Epoch 9/10
#  - 0s - loss: 0.5913 - acc: 0.7465 - val_loss: 0.4568 - val_acc: 0.7600
#
# Epoch 10/10
#  - 0s - loss: 0.5317 - acc: 0.7581 - val_loss: 0.4357 - val_acc: 0.7300
#
# Test accuracy:
# 0.73
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 2s - loss: 1.4116 - acc: 0.5392 - val_loss: 0.5079 - val_acc: 0.7100
#
# Epoch 2/10
#  - 0s - loss: 0.7586 - acc: 0.7258 - val_loss: 0.4649 - val_acc: 0.7800
#
# Epoch 3/10
#  - 0s - loss: 0.5802 - acc: 0.7604 - val_loss: 0.4789 - val_acc: 0.7900
#
# Epoch 4/10
#  - 0s - loss: 0.5652 - acc: 0.7857 - val_loss: 0.4487 - val_acc: 0.8200
#
# Epoch 5/10
#  - 0s - loss: 0.5174 - acc: 0.7696 - val_loss: 0.4548 - val_acc: 0.8000
#
# Epoch 6/10
#  - 0s - loss: 0.5200 - acc: 0.7788 - val_loss: 0.5895 - val_acc: 0.7700
#
# Epoch 7/10
#  - 0s - loss: 0.5163 - acc: 0.7834 - val_loss: 0.4544 - val_acc: 0.8000
#
# Epoch 8/10
#  - 0s - loss: 0.4941 - acc: 0.8041 - val_loss: 0.4534 - val_acc: 0.7400
#
# Epoch 9/10
#  - 0s - loss: 0.4494 - acc: 0.7742 - val_loss: 0.4312 - val_acc: 0.7900
#
# Epoch 10/10
#  - 0s - loss: 0.4378 - acc: 0.7926 - val_loss: 0.4521 - val_acc: 0.8200
#
# Test accuracy:
# 0.82
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.2497 - acc: 0.6060 - val_loss: 0.4513 - val_acc: 0.7500
#
# Epoch 2/10
#  - 0s - loss: 0.6379 - acc: 0.7350 - val_loss: 0.5168 - val_acc: 0.7600
#
# Epoch 3/10
#  - 0s - loss: 0.5872 - acc: 0.7673 - val_loss: 0.5017 - val_acc: 0.7600
#
# Epoch 4/10
#  - 0s - loss: 0.5774 - acc: 0.7673 - val_loss: 0.5153 - val_acc: 0.7900
#
# Epoch 5/10
#  - 0s - loss: 0.6456 - acc: 0.7765 - val_loss: 0.4313 - val_acc: 0.7400
#
# Epoch 6/10
#  - 0s - loss: 0.6560 - acc: 0.7765 - val_loss: 0.4777 - val_acc: 0.7500
#
# Epoch 7/10
#  - 0s - loss: 0.6196 - acc: 0.7350 - val_loss: 0.4301 - val_acc: 0.7700
#
# Epoch 8/10
#  - 0s - loss: 0.5566 - acc: 0.7696 - val_loss: 0.4735 - val_acc: 0.7700
#
# Epoch 9/10
#  - 0s - loss: 0.5419 - acc: 0.7880 - val_loss: 0.4477 - val_acc: 0.7500
#
# Epoch 10/10
#  - 0s - loss: 0.5405 - acc: 0.7926 - val_loss: 0.4404 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 3.5228 - acc: 0.6382 - val_loss: 1.9828 - val_acc: 0.7500
#
# Epoch 2/10
#  - 0s - loss: 2.0221 - acc: 0.7535 - val_loss: 1.4009 - val_acc: 0.7500
#
# Epoch 3/10
#  - 0s - loss: 1.7293 - acc: 0.7120 - val_loss: 1.5773 - val_acc: 0.7600
#
# Epoch 4/10
#  - 0s - loss: 1.1407 - acc: 0.8134 - val_loss: 0.9323 - val_acc: 0.7800
#
# Epoch 5/10
#  - 0s - loss: 0.8997 - acc: 0.8134 - val_loss: 1.3129 - val_acc: 0.7300
#
# Epoch 6/10
#  - 0s - loss: 0.9767 - acc: 0.7880 - val_loss: 0.8441 - val_acc: 0.7300
#
# Epoch 7/10
#  - 0s - loss: 0.8791 - acc: 0.7926 - val_loss: 0.8825 - val_acc: 0.7900
#
# Epoch 8/10
#  - 0s - loss: 0.6587 - acc: 0.8203 - val_loss: 0.6476 - val_acc: 0.7700
#
# Epoch 9/10
#  - 0s - loss: 0.7678 - acc: 0.7880 - val_loss: 1.3762 - val_acc: 0.7400
#
# Epoch 10/10
#  - 0s - loss: 0.8676 - acc: 0.7834 - val_loss: 0.6484 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 2.7522 - acc: 0.6060 - val_loss: 0.7898 - val_acc: 0.7300
#
# Epoch 2/10
#  - 0s - loss: 1.3092 - acc: 0.7166 - val_loss: 0.5908 - val_acc: 0.8000
#
# Epoch 3/10
#  - 0s - loss: 0.8927 - acc: 0.7512 - val_loss: 0.5421 - val_acc: 0.7700
#
# Epoch 4/10
#  - 0s - loss: 0.6834 - acc: 0.7719 - val_loss: 0.4901 - val_acc: 0.8000
#
# Epoch 5/10
#  - 0s - loss: 0.6298 - acc: 0.7604 - val_loss: 0.4328 - val_acc: 0.7300
#
# Epoch 6/10
#  - 0s - loss: 0.4432 - acc: 0.7857 - val_loss: 0.4336 - val_acc: 0.8000
#
# Epoch 7/10
#  - 0s - loss: 0.4340 - acc: 0.8111 - val_loss: 0.4027 - val_acc: 0.8100
#
# Epoch 8/10
#  - 0s - loss: 0.4159 - acc: 0.8111 - val_loss: 0.4005 - val_acc: 0.8100
#
# Epoch 9/10
#  - 0s - loss: 0.3878 - acc: 0.8295 - val_loss: 0.4296 - val_acc: 0.7500
#
# Epoch 10/10
#  - 0s - loss: 0.3916 - acc: 0.8295 - val_loss: 0.5191 - val_acc: 0.7400
#
# Test accuracy:
# 0.74
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.3084 - acc: 0.6774 - val_loss: 0.5885 - val_acc: 0.7200
#
# Epoch 2/10
#  - 0s - loss: 0.7576 - acc: 0.7465 - val_loss: 0.4647 - val_acc: 0.7400
#
# Epoch 3/10
#  - 0s - loss: 0.5624 - acc: 0.7442 - val_loss: 0.4609 - val_acc: 0.7700
#
# Epoch 4/10
#  - 0s - loss: 0.5674 - acc: 0.7120 - val_loss: 0.4356 - val_acc: 0.8000
#
# Epoch 5/10
#  - 0s - loss: 0.5087 - acc: 0.7811 - val_loss: 0.4393 - val_acc: 0.8000
#
# Epoch 6/10
#  - 0s - loss: 0.5401 - acc: 0.7581 - val_loss: 0.4891 - val_acc: 0.7500
#
# Epoch 7/10
#  - 0s - loss: 0.5414 - acc: 0.7673 - val_loss: 0.4353 - val_acc: 0.7600
#
# Epoch 8/10
#  - 0s - loss: 0.4496 - acc: 0.7765 - val_loss: 0.4069 - val_acc: 0.7900
#
# Epoch 9/10
#  - 0s - loss: 0.5086 - acc: 0.7834 - val_loss: 0.4363 - val_acc: 0.8000
#
# Epoch 10/10
#  - 0s - loss: 0.4812 - acc: 0.7903 - val_loss: 0.4297 - val_acc: 0.8200
#
# Test accuracy:
# 0.82
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.8321 - acc: 0.6106 - val_loss: 0.5639 - val_acc: 0.7500
#
# Epoch 2/10
#  - 0s - loss: 0.8465 - acc: 0.7120 - val_loss: 0.4824 - val_acc: 0.7100
#
# Epoch 3/10
#  - 0s - loss: 0.6690 - acc: 0.7604 - val_loss: 0.4778 - val_acc: 0.7300
#
# Epoch 4/10
#  - 0s - loss: 0.6837 - acc: 0.7488 - val_loss: 0.4736 - val_acc: 0.7100
#
# Epoch 5/10
#  - 0s - loss: 0.6077 - acc: 0.7281 - val_loss: 0.4605 - val_acc: 0.7300
#
# Epoch 6/10
#  - 0s - loss: 0.5704 - acc: 0.7097 - val_loss: 0.4666 - val_acc: 0.7800
#
# Epoch 7/10
#  - 0s - loss: 0.5643 - acc: 0.7258 - val_loss: 0.4583 - val_acc: 0.7000
#
# Epoch 8/10
#  - 0s - loss: 0.5026 - acc: 0.7604 - val_loss: 0.5512 - val_acc: 0.6800
#
# Epoch 9/10
#  - 0s - loss: 0.5616 - acc: 0.7281 - val_loss: 0.5472 - val_acc: 0.7000
#
# Epoch 10/10
#  - 0s - loss: 0.4826 - acc: 0.7834 - val_loss: 0.4366 - val_acc: 0.7400
#
# Test accuracy:
# 0.74
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.9306 - acc: 0.5369 - val_loss: 0.5329 - val_acc: 0.7400
#
# Epoch 2/10
#  - 0s - loss: 0.7039 - acc: 0.7558 - val_loss: 0.4860 - val_acc: 0.7500
#
# Epoch 3/10
#  - 0s - loss: 0.6277 - acc: 0.7581 - val_loss: 0.4558 - val_acc: 0.7400
#
# Epoch 4/10
#  - 0s - loss: 0.6249 - acc: 0.7604 - val_loss: 0.5255 - val_acc: 0.7200
#
# Epoch 5/10
#  - 0s - loss: 0.5451 - acc: 0.7650 - val_loss: 0.5214 - val_acc: 0.7600
#
# Epoch 6/10
#  - 0s - loss: 0.5330 - acc: 0.7627 - val_loss: 0.4670 - val_acc: 0.7300
#
# Epoch 7/10
#  - 0s - loss: 0.5675 - acc: 0.7488 - val_loss: 0.4643 - val_acc: 0.7200
#
# Epoch 8/10
#  - 0s - loss: 0.4913 - acc: 0.7903 - val_loss: 0.4768 - val_acc: 0.7400
#
# Epoch 9/10
#  - 0s - loss: 0.4354 - acc: 0.8134 - val_loss: 0.4578 - val_acc: 0.7900
#
# Epoch 10/10
#  - 0s - loss: 0.4457 - acc: 0.8226 - val_loss: 0.5548 - val_acc: 0.7000
#
# Test accuracy:
# 0.7
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 2.8101 - acc: 0.6014 - val_loss: 0.8099 - val_acc: 0.7500
#
# Epoch 2/10
#  - 0s - loss: 1.1838 - acc: 0.6774 - val_loss: 0.5371 - val_acc: 0.7200
#
# Epoch 3/10
#  - 0s - loss: 0.8969 - acc: 0.6728 - val_loss: 0.5081 - val_acc: 0.7400
#
# Epoch 4/10
#  - 0s - loss: 0.7811 - acc: 0.6636 - val_loss: 0.4856 - val_acc: 0.7300
#
# Epoch 5/10
#  - 0s - loss: 0.6956 - acc: 0.6613 - val_loss: 0.4859 - val_acc: 0.7100
#
# Epoch 6/10
#  - 0s - loss: 0.6304 - acc: 0.6866 - val_loss: 0.4585 - val_acc: 0.7600
#
# Epoch 7/10
#  - 0s - loss: 0.5477 - acc: 0.7258 - val_loss: 0.5215 - val_acc: 0.7100
#
# Epoch 8/10
#  - 0s - loss: 0.5742 - acc: 0.7304 - val_loss: 0.4680 - val_acc: 0.7300
#
# Epoch 9/10
#  - 0s - loss: 0.5701 - acc: 0.7512 - val_loss: 0.4729 - val_acc: 0.7600
#
# Epoch 10/10
#  - 0s - loss: 0.5766 - acc: 0.7488 - val_loss: 0.4655 - val_acc: 0.7200
#
# Test accuracy:
# 0.72
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 2.8436 - acc: 0.5829 - val_loss: 0.9502 - val_acc: 0.7400
#
# Epoch 2/10
#  - 0s - loss: 1.2353 - acc: 0.7442 - val_loss: 0.7976 - val_acc: 0.7600
#
# Epoch 3/10
#  - 0s - loss: 0.8164 - acc: 0.7581 - val_loss: 0.7936 - val_acc: 0.7700
#
# Epoch 4/10
#  - 0s - loss: 0.8523 - acc: 0.7604 - val_loss: 0.4509 - val_acc: 0.7500
#
# Epoch 5/10
#  - 0s - loss: 0.7477 - acc: 0.7327 - val_loss: 0.4602 - val_acc: 0.7700
#
# Epoch 6/10
#  - 0s - loss: 0.6882 - acc: 0.7442 - val_loss: 0.4464 - val_acc: 0.7300
#
# Epoch 7/10
#  - 0s - loss: 0.5994 - acc: 0.7488 - val_loss: 0.4309 - val_acc: 0.7700
#
# Epoch 8/10
#  - 0s - loss: 0.5837 - acc: 0.7673 - val_loss: 0.4280 - val_acc: 0.7500
#
# Epoch 9/10
#  - 0s - loss: 0.5803 - acc: 0.7604 - val_loss: 0.3949 - val_acc: 0.7700
#
# Epoch 10/10
#  - 0s - loss: 0.5164 - acc: 0.7995 - val_loss: 0.5526 - val_acc: 0.8000
#
# Test accuracy:
# 0.8
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.9238 - acc: 0.5737 - val_loss: 0.6098 - val_acc: 0.7500
#
# Epoch 2/10
#  - 0s - loss: 0.8224 - acc: 0.7212 - val_loss: 0.5130 - val_acc: 0.7600
#
# Epoch 3/10
#  - 0s - loss: 0.6806 - acc: 0.7535 - val_loss: 0.4373 - val_acc: 0.7600
#
# Epoch 4/10
#  - 0s - loss: 0.6209 - acc: 0.7488 - val_loss: 0.4163 - val_acc: 0.7800
#
# Epoch 5/10
#  - 0s - loss: 0.5437 - acc: 0.7350 - val_loss: 0.4294 - val_acc: 0.7800
#
# Epoch 6/10
#  - 0s - loss: 0.5026 - acc: 0.7581 - val_loss: 0.4377 - val_acc: 0.7800
#
# Epoch 7/10
#  - 0s - loss: 0.5133 - acc: 0.7396 - val_loss: 0.4097 - val_acc: 0.8100
#
# Epoch 8/10
#  - 0s - loss: 0.5405 - acc: 0.7419 - val_loss: 0.4705 - val_acc: 0.7500
#
# Epoch 9/10
#  - 0s - loss: 0.5237 - acc: 0.7857 - val_loss: 0.4353 - val_acc: 0.7500
#
# Epoch 10/10
#  - 0s - loss: 0.4050 - acc: 0.8180 - val_loss: 0.4275 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 3s - loss: 1.4440 - acc: 0.6244 - val_loss: 0.8120 - val_acc: 0.7400
#
# Epoch 2/10
#  - 0s - loss: 0.8819 - acc: 0.7143 - val_loss: 0.4710 - val_acc: 0.7400
#
# Epoch 3/10
#  - 0s - loss: 0.7549 - acc: 0.6935 - val_loss: 0.5013 - val_acc: 0.7000
#
# Epoch 4/10
#  - 0s - loss: 0.7021 - acc: 0.7558 - val_loss: 0.5168 - val_acc: 0.7300
#
# Epoch 5/10
#  - 0s - loss: 0.6114 - acc: 0.7558 - val_loss: 0.4650 - val_acc: 0.7500
#
# Epoch 6/10
#  - 0s - loss: 0.5845 - acc: 0.7650 - val_loss: 0.4859 - val_acc: 0.7200
#
# Epoch 7/10
#  - 0s - loss: 0.5394 - acc: 0.7350 - val_loss: 0.5419 - val_acc: 0.7500
#
# Epoch 8/10
#  - 0s - loss: 0.5695 - acc: 0.7696 - val_loss: 0.4974 - val_acc: 0.7100
#
# Epoch 9/10
#  - 0s - loss: 0.4995 - acc: 0.7972 - val_loss: 0.4835 - val_acc: 0.7100
#
# Epoch 10/10
#  - 0s - loss: 0.5017 - acc: 0.7926 - val_loss: 0.4682 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 1.8221 - acc: 0.6083 - val_loss: 0.6761 - val_acc: 0.7500
#
# Epoch 2/10
#  - 0s - loss: 0.8273 - acc: 0.7281 - val_loss: 0.5275 - val_acc: 0.7500
#
# Epoch 3/10
#  - 0s - loss: 0.6698 - acc: 0.7488 - val_loss: 0.6463 - val_acc: 0.7400
#
# Epoch 4/10
#  - 0s - loss: 0.6714 - acc: 0.7765 - val_loss: 0.4515 - val_acc: 0.7500
#
# Epoch 5/10
#  - 0s - loss: 0.5920 - acc: 0.7834 - val_loss: 0.4387 - val_acc: 0.7800
#
# Epoch 6/10
#  - 0s - loss: 0.5961 - acc: 0.7696 - val_loss: 0.4331 - val_acc: 0.7400
#
# Epoch 7/10
#  - 0s - loss: 0.5929 - acc: 0.7857 - val_loss: 0.5005 - val_acc: 0.7500
#
# Epoch 8/10
#  - 0s - loss: 0.6173 - acc: 0.7742 - val_loss: 0.4878 - val_acc: 0.7800
#
# Epoch 9/10
#  - 0s - loss: 0.5947 - acc: 0.7673 - val_loss: 0.4311 - val_acc: 0.7900
#
# Epoch 10/10
#  - 0s - loss: 0.5150 - acc: 0.8041 - val_loss: 0.4743 - val_acc: 0.7700
#
# Test accuracy:
# 0.77
# Train on 434 samples, validate on 100 samples
# Epoch 1/10
#  - 4s - loss: 2.1708 - acc: 0.5760 - val_loss: 0.5793 - val_acc: 0.7600
#
# Epoch 2/10
#  - 0s - loss: 1.4150 - acc: 0.6475 - val_loss: 0.4487 - val_acc: 0.7700
#
# Epoch 3/10
#  - 0s - loss: 1.0413 - acc: 0.6544 - val_loss: 0.4721 - val_acc: 0.7900
#
# Epoch 4/10
#  - 0s - loss: 0.7925 - acc: 0.6982 - val_loss: 0.5168 - val_acc: 0.7500
#
# Epoch 5/10
#  - 0s - loss: 0.8819 - acc: 0.6659 - val_loss: 0.4485 - val_acc: 0.7900
#
# Epoch 6/10
#  - 0s - loss: 0.7683 - acc: 0.7281 - val_loss: 0.4235 - val_acc: 0.8000
#
# Epoch 7/10
#  - 0s - loss: 0.6534 - acc: 0.7258 - val_loss: 0.4518 - val_acc: 0.7700
#
# Epoch 8/10
#  - 0s - loss: 0.7127 - acc: 0.6959 - val_loss: 0.5026 - val_acc: 0.7700
#
# Epoch 9/10
#  - 0s - loss: 0.6025 - acc: 0.6982 - val_loss: 0.4453 - val_acc: 0.7900
#
# Epoch 10/10
#  - 0s - loss: 0.6088 - acc: 0.7235 - val_loss: 0.4390 - val_acc: 0.7900
#
# Test accuracy:
# 0.79
# 100%|██████████| 30/30 [02:40<00:00,  6.26s/it, best loss: -0.82]
# Time on optimization: 2.6869601686795552 minutes
#
# Summary of the best model: -----------------------
# Evalutation of best performing model:
# 100/100 [==============================] - 0s 287us/step
# [0.4520971655845642, 0.82]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_21 (InputLayer)        (None, 64, 64, 5, 1)      0
# _________________________________________________________________
# conv3d_21 (Conv3D)           (None, 62, 62, 3, 48)     1344
# _________________________________________________________________
# max_pooling3d_21 (MaxPooling (None, 31, 31, 1, 48)     0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 46128)             0
# _________________________________________________________________
# dense_61 (Dense)             (None, 32)                1476128
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_62 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 1,478,017
# Trainable params: 1,478,017
# Non-trainable params: 0
# _________________________________________________________________
# None
# Conv 1: 48 unidades
# Dense 1: 64 unidades
# Dense 2: 16 unidades
# Dropout 1: 0.20240408382722602
# Dropout 2: 0.1274868501724017
